# %% [markdown]
# ## Ejercicio de Intervalo de Confianza: Estimación de la Altura Promedio
#
# **Problema:** Se desea estimar la altura promedio de estudiantes universitarios. En una muestra de 50 estudiantes, se obtuvo una media de 170 cm. Se sabe que la desviación estándar poblacional es de 10 cm. Construye un intervalo de confianza del 95 % para la media poblacional.
#
# **Instrucciones:**
# * Utilizar las fórmulas estándar para intervalos de confianza con explicaciones claras sobre el nivel de confianza y parámetros utilizados.
# * Usar `scipy.stats` para cálculos estadísticos.
# * Comentar todo el código indicando pasos y fórmulas.
# * Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# * Todo el resultado debe estar en español.

# %%
# Definir los parámetros dados para el segundo ejercicio
media_muestral = 75  # puntos
desviacion_estandar_poblacional = 15  # puntos
tamano_muestra = 100  # estudiantes
nivel_confianza = 0.90  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha = 1 - nivel_confianza

# Calcular el valor crítico Z
# Para una prueba de dos colas, necesitamos el valor Z que deja alpha/2 en cada cola.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - alpha / 2)
z_critico = scipy.stats.norm.ppf(1 - alpha / 2)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_poblacional / sqrt(tamano_muestra)
error_estandar = desviacion_estandar_poblacional / np.sqrt(tamano_muestra)

# Calcular el margen de error
# Fórmula: margen_error = z_critico * error_estandar
margen_error = z_critico * error_estandar

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior = media_muestral - margen_error
intervalo_confianza_superior = media_muestral + margen_error

# Almacenar los límites calculados
intervalo_confianza = (intervalo_confianza_inferior, intervalo_confianza_superior)

print(f"Nivel de significancia (alpha): {alpha:.2f}")
print(f"Valor crítico Z: {z_critico:.4f}")
print(f"Error estándar de la media: {error_estandar:.4f}")
print(f"Margen de error: {margen_error:.4f}")
print(f"Intervalo de Confianza (90%): ({intervalo_confianza_inferior:.4f}, {intervalo_confianza_superior:.4f})")
# Out:
# Nivel de significancia (alpha): 0.10
# Valor crítico Z: 1.6449
# Error estándar de la media: 1.5000
# Margen de error: 2.4673
# Intervalo de Confianza (90%): (72.5327, 77.4673)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (90%):")
print(f"Un nivel de confianza del 90% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra}) de la misma población de estudiantes y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 90% de estos intervalos contuvieran la verdadera calificación promedio de la población de estudiantes en el examen nacional.")
print(f"NO significa que haya un 90% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior:.2f} puntos, {intervalo_confianza_superior:.2f} puntos). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral} puntos): Es la calificación promedio calculada a partir de nuestra muestra específica de {tamano_muestra} estudiantes. Sirve como nuestra mejor estimación puntual de la media poblacional desconocida.")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional} puntos): Es una medida de la dispersión o variabilidad de las calificaciones del examen entre TODOS los estudiantes de la población. Asumimos que este valor es conocido históricamente para este ejercicio. Indica cuánto se desvían típicamente las calificaciones individuales de la media poblacional.")
print(f"- Tamaño de la Muestra ({tamano_muestra} estudiantes): Es el número de estudiantes incluidos en nuestra muestra. Un tamaño de muestra mayor generalmente conduce a una estimación más precisa de la media poblacional y un intervalo de confianza más estrecho, asumiendo que otros factores permanecen constantes.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza:")
print("El intervalo de confianza proporciona un rango de valores plausibles para la verdadera calificación promedio de la población en el examen.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral} puntos).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza*100:.0f}%), que dicta el valor crítico Z ({z_critico:.4f}). Un nivel de confianza más alto requiere un valor Z más grande, lo que resulta en un intervalo más amplio.")
print(f"  - La desviación estándar poblacional ({desviacion_estandar_poblacional} puntos), que refleja la variabilidad de la población. Una mayor variabilidad conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior:.2f} puntos, {intervalo_confianza_superior:.2f} puntos) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza*100:.0f}% seguros de que la verdadera calificación promedio de todos los estudiantes en el examen nacional se encuentra entre aproximadamente {intervalo_confianza_inferior:.2f} puntos y {intervalo_confianza_superior:.2f} puntos.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (90%):
# Un nivel de confianza del 90% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (100) de la misma población de estudiantes y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 90% de estos intervalos contuvieran la verdadera calificación promedio de la población de estudiantes en el examen nacional.
# NO significa que haya un 90% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado (72.53 puntos, 77.47 puntos). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (75 puntos): Es la calificación promedio calculada a partir de nuestra muestra específica de 100 estudiantes. Sirve como nuestra mejor estimación puntual de la media poblacional desconocida.
# ...

# %% [markdown]
# **Paso 6: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y la interpretación del intervalo de confianza.
#
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar la altura promedio de los estudiantes universitarios basándose en una muestra y construir un intervalo de confianza del 95% para la verdadera media poblacional de altura.
#
# ### Parámetros Clave
# - Media Muestral: 170 cm (altura promedio de una muestra de 50 estudiantes)
# - Desviación Estándar Poblacional: 10 cm (variabilidad conocida de las alturas en la población)
# - Tamaño de la Muestra: 50 estudiantes
# - Nivel de Confianza: 95%
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 95% calculado para la media poblacional de altura es: (167.23 cm, 172.77 cm).
#
# ### Interpretación del Intervalo de Confianza
# Basándonos en los datos de nuestra muestra, estamos 95% seguros de que la verdadera altura promedio de todos los estudiantes universitarios se encuentra entre aproximadamente 167.23 cm y 172.77 cm.
# Este intervalo proporciona un rango de valores plausibles para la media poblacional de altura.
#
# ### Significado del Nivel de Confianza
# El nivel de confianza del 95% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 95% de estos intervalos contuvieran la verdadera media poblacional de altura.
#
# ### Visualización
# El gráfico adjunto representa visualmente la distribución normal basada en la media muestral y el error estándar, con el intervalo de confianza del 95% resaltado. La región sombreada indica el rango dentro del cual estamos 95% seguros de que se encuentra la verdadera media poblacional.

# %% [markdown]
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * La altura promedio de la muestra de 50 estudiantes universitarios es de 170 cm.
# * La desviación estándar poblacional conocida es de 10 cm.
# * Se calculó un intervalo de confianza del 95% para la media poblacional de altura.
# * El intervalo de confianza del 95% calculado para la media poblacional de altura es (167.23 cm, 172.77 cm).
# * El valor crítico Z para un nivel de confianza del 95% es aproximadamente 1.9600.
# * El error estándar de la media se calculó en aproximadamente 1.4142 cm.
# * El margen de error es de aproximadamente 2.7718 cm.
#
# ### Conclusiones o Próximos Pasos
#
# * Basándonos en la muestra, estamos 95% seguros de que la verdadera altura promedio de todos los estudiantes universitarios se encuentra entre 167.23 cm y 172.77 cm.
# * Para potencialmente estrechar el intervalo de confianza y obtener una estimación más precisa, se podría considerar un tamaño de muestra mayor en futuros estudios.

# %% [markdown]
# ## Ejercicio de Intervalo de Confianza: Estimación de la Calificación Promedio de un Examen
#
# **Problema:** Un examen nacional tiene una desviación estándar histórica de 15 puntos. En una muestra aleatoria de 100 estudiantes, la calificación promedio fue de 75 puntos. Determina un intervalo de confianza del 90 % para la media poblacional.
#
# **Instrucciones:**
# * Utilizar las fórmulas estándar para intervalos de confianza con explicaciones claras sobre el nivel de confianza y parámetros utilizados.
# * Usar `scipy.stats` para cálculos estadísticos.
# * Comentar todo el código indicando pasos y fórmulas.
# * Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# * Todo el resultado debe estar en español.

# %%
# Definir los parámetros dados para el segundo ejercicio
media_muestral = 75  # puntos
desviacion_estandar_poblacional = 15  # puntos
tamano_muestra = 100  # estudiantes
nivel_confianza = 0.90  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha = 1 - nivel_confianza

# Calcular el valor crítico Z
# Para una prueba de dos colas, necesitamos el valor Z que deja alpha/2 en cada cola.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - alpha / 2)
z_critico = scipy.stats.norm.ppf(1 - alpha / 2)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_poblacional / sqrt(tamano_muestra)
error_estandar = desviacion_estandar_poblacional / np.sqrt(tamano_muestra)

# Calcular el margen de error
# Fórmula: margen_error = z_critico * error_estandar
margen_error = z_critico * error_estandar

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior = media_muestral - margen_error
intervalo_confianza_superior = media_muestral + margen_error

# Almacenar los límites calculados
intervalo_confianza = (intervalo_confianza_inferior, intervalo_confianza_superior)

print(f"Nivel de significancia (alpha): {alpha:.2f}")
print(f"Valor crítico Z: {z_critico:.4f}")
print(f"Error estándar de la media: {error_estandar:.4f}")
print(f"Margen de error: {margen_error:.4f}")
print(f"Intervalo de Confianza (90%): ({intervalo_confianza_inferior:.4f}, {intervalo_confianza_superior:.4f})")
# Out:
# Nivel de significancia (alpha): 0.10
# Valor crítico Z: 1.6449
# Error estándar de la media: 1.5000
# Margen de error: 2.4673
# Intervalo de Confianza (90%): (72.5327, 77.4673)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (90%):")
print(f"Un nivel de confianza del 90% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra}) de la misma población de estudiantes y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 90% de estos intervalos contuvieran la verdadera calificación promedio de la población de estudiantes en el examen nacional.")
print(f"NO significa que haya un 90% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior:.2f} puntos, {intervalo_confianza_superior:.2f} puntos). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral} puntos): Es la calificación promedio calculada a partir de nuestra muestra específica de {tamano_muestra} estudiantes. Sirve como nuestra mejor estimación puntual de la media poblacional desconocida.")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional} puntos): Es una medida de la dispersión o variabilidad de las calificaciones del examen entre TODOS los estudiantes de la población. Asumimos que este valor es conocido históricamente para este ejercicio. Indica cuánto se desvían típicamente las calificaciones individuales de la media poblacional.")
print(f"- Tamaño de la Muestra ({tamano_muestra} estudiantes): Es el número de estudiantes incluidos en nuestra muestra. Un tamaño de muestra mayor generalmente conduce a una estimación más precisa de la media poblacional y un intervalo de confianza más estrecho, asumiendo que otros factores permanecen constantes.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza:")
print("El intervalo de confianza proporciona un rango de valores plausibles para la verdadera calificación promedio de la población en el examen.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral} puntos).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza*100:.0f}%), que dicta el valor crítico Z ({z_critico:.4f}). Un nivel de confianza más alto requiere un valor Z más grande, lo que resulta en un intervalo más amplio.")
print(f"  - La desviación estándar poblacional ({desviacion_estandar_poblacional} puntos), que refleja la variabilidad de la población. Una mayor variabilidad conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior:.2f} puntos, {intervalo_confianza_superior:.2f} puntos) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza*100:.0f}% seguros de que la verdadera calificación promedio de todos los estudiantes en el examen nacional se encuentra entre aproximadamente {intervalo_confianza_inferior:.2f} puntos y {intervalo_confianza_superior:.2f} puntos.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (90%):
# Un nivel de confianza del 90% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (100) de la misma población de estudiantes y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 90% de estos intervalos contuvieran la verdadera calificación promedio de la población de estudiantes en el examen nacional.
# NO significa que haya un 90% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado (72.53 puntos, 77.47 puntos). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (75 puntos): Es la calificación promedio calculada a partir de nuestra muestra específica de 100 estudiantes. Sirve como nuestra mejor estimación puntual de la media poblacional desconocida.
# ...

# %% [markdown]
# **Paso 6: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y la interpretación del intervalo de confianza para el segundo ejercicio.
#
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar la calificación promedio de los estudiantes en un examen nacional basándose en una muestra y construir un intervalo de confianza del 90% para la verdadera media poblacional de calificaciones.
#
# ### Parámetros Clave
# - Media Muestral: 75 puntos (calificación promedio de una muestra de 100 estudiantes)
# - Desviación Estándar Poblacional: 15 puntos (variabilidad conocida de las calificaciones en la población)
# - Tamaño de la Muestra: 100 estudiantes
# - Nivel de Confianza: 90%
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 90% calculado para la media poblacional de calificación es: (72.53 puntos, 77.47 puntos).
#
# ### Interpretación del Intervalo de Confianza
# Basándonos en los datos de nuestra muestra, estamos 90% seguros de que la verdadera calificación promedio de todos los estudiantes en el examen nacional se encuentra entre aproximadamente 72.53 puntos y 77.47 puntos.
# Este intervalo proporciona un rango de valores plausibles para la media poblacional de calificación.
#
# ### Significado del Nivel de Confianza
# El nivel de confianza del 90% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 90% de estos intervalos contuvieran la verdadera media poblacional de calificación.
#
# ### Visualización
# El gráfico adjunto representa visualmente la distribución normal basada en la media muestral y el error estándar, con el intervalo de confianza del 90% resaltado. La región sombreada indica el rango dentro del cual estamos 90% seguros de que se encuentra la verdadera media poblacional.

# %% [markdown]
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * La calificación promedio de la muestra de 100 estudiantes es de 75 puntos.
# * La desviación estándar poblacional conocida es de 15 puntos.
# * Se calculó un intervalo de confianza del 90% para la media poblacional de calificación.
# * El intervalo de confianza del 90% calculado para la media poblacional de calificación es (72.53 puntos, 77.47 puntos).
# * El valor crítico Z para un nivel de confianza del 90% es aproximadamente 1.6449.
# * El error estándar de la media se calculó en aproximadamente 1.5000 puntos.
# * El margen de error es de aproximadamente 2.4670 puntos.
#
# ### Conclusiones o Próximos Pasos
#
# * Basándonos en la muestra, estamos 90% seguros de que la verdadera calificación promedio de todos los estudiantes en el examen nacional se encuentra entre 72.53 puntos y 77.47 puntos.
# * Para potencialmente estrechar el intervalo de confianza y obtener una estimación más precisa, se podría considerar un tamaño de muestra mayor en futuros estudios.

# %% [markdown]
# ## Ejercicio de Intervalo de Confianza: Estimación del Diámetro Promedio de Tornillos
#
# **Problema:** Una fábrica produce tornillos con una desviación estándar de 0.2 cm. En una inspección de calidad, se midieron 30 tornillos y se obtuvo un diámetro promedio de 2.5 cm. Calcula un intervalo de confianza del 99 % para el diámetro promedio real.
#
# **Instrucciones:**
# * Utilizar las fórmulas estándar para intervalos de confianza con explicaciones claras sobre el nivel de confianza y parámetros utilizados.
# * Usar `scipy.stats` para cálculos estadísticos.
# * Comentar todo el código indicando pasos y fórmulas.
# * Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# * Todo el resultado debe estar en español.
# * No graficar la distribución.

# %%
# Definir los parámetros dados para el tercer ejercicio
media_muestral_tornillos = 2.5  # cm
desviacion_estandar_poblacional_tornillos = 0.2  # cm
tamano_muestra_tornillos = 30  # tornillos
nivel_confianza_tornillos = 0.99  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha_tornillos = 1 - nivel_confianza_tornillos

# Calcular el valor crítico Z
# Para una prueba de dos colas, necesitamos el valor Z que deja alpha/2 en cada cola.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - alpha / 2)
z_critico_tornillos = scipy.stats.norm.ppf(1 - alpha_tornillos / 2)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_poblacional / sqrt(tamano_muestra)
error_estandar_tornillos = desviacion_estandar_poblacional_tornillos / np.sqrt(tamano_muestra_tornillos)

# Calcular el margen de error
# Fórmula: margen_error = z_critico * error_estandar
margen_error_tornillos = z_critico_tornillos * error_estandar_tornillos

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior_tornillos = media_muestral_tornillos - margen_error_tornillos
intervalo_confianza_superior_tornillos = media_muestral_tornillos + margen_error_tornillos

# Almacenar los límites calculados
intervalo_confianza_tornillos = (intervalo_confianza_inferior_tornillos, intervalo_confianza_superior_tornillos)

print(f"Nivel de significancia (alpha): {alpha_tornillos:.2f}")
print(f"Valor crítico Z: {z_critico_tornillos:.4f}")
print(f"Error estándar de la media: {error_estandar_tornillos:.4f}")
print(f"Margen de error: {margen_error_tornillos:.4f}")
print(f"Intervalo de Confianza (99%): ({intervalo_confianza_inferior_tornillos:.4f}, {intervalo_confianza_superior_tornillos:.4f})")
# Out:
# Nivel de significancia (alpha): 0.01
# Valor crítico Z: 2.5758
# Error estándar de la media: 0.0365
# Margen de error: 0.0941
# Intervalo de Confianza (99%): (2.4059, 2.5941)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (99%):")
print(f"Un nivel de confianza del 99% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra_tornillos}) de la producción de tornillos y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 99% de estos intervalos contuvieran el verdadero diámetro promedio de los tornillos producidos por la fábrica.")
print(f"NO significa que haya un 99% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior_tornillos:.4f} cm, {intervalo_confianza_superior_tornillos:.4f} cm). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral_tornillos} cm): Es el diámetro promedio calculado a partir de nuestra muestra específica de {tamano_muestra_tornillos} tornillos. Sirve como nuestra mejor estimación puntual del diámetro promedio real desconocido.")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional_tornillos} cm): Es una medida de la dispersión o variabilidad de los diámetros de los tornillos en TODA la producción de la fábrica. Asumimos que este valor es conocido históricamente para este ejercicio. Indica cuánto se desvían típicamente los diámetros individuales del diámetro promedio real.")
print(f"- Tamaño de la Muestra ({tamano_muestra_tornillos} tornillos): Es el número de tornillos incluidos en nuestra muestra. Un tamaño de muestra mayor generalmente conduce a una estimación más precisa del diámetro promedio real y un intervalo de confianza más estrecho, asumiendo que otros factores permanecen constantes.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza:")
print("El intervalo de confianza proporciona un rango de valores plausibles para el verdadero diámetro promedio de los tornillos producidos por la fábrica.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral_tornillos} cm).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza_tornillos*100:.0f}%), que dicta el valor crítico Z ({z_critico_tornillos:.4f}). Un nivel de confianza más alto requiere un valor Z más grande, lo que resulta en un intervalo más amplio.")
print(f"  - La desviación estándar poblacional ({desviacion_estandar_poblacional_tornillos} cm), que refleja la variabilidad de la producción. Una mayor variabilidad conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra_tornillos}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior_tornillos:.4f} cm, {intervalo_confianza_superior_tornillos:.4f} cm) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza_tornillos*100:.0f}% seguros de que el verdadero diámetro promedio de todos los tornillos producidos por la fábrica se encuentra entre aproximadamente {intervalo_confianza_inferior_tornillos:.4f} cm y {intervalo_confianza_superior_tornillos:.4f} cm.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (99%):
# Un nivel de confianza del 99% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (30) de la producción de tornillos y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 99% de estos intervalos contuvieran el verdadero diámetro promedio de los tornillos producidos por la fábrica.
# NO significa que haya un 99% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado (2.4059 cm, 2.5941 cm). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (2.5 cm): Es el diámetro promedio calculado a partir de nuestra muestra específica de 30 tornillos. Sirve como nuestra mejor estimación puntual del diámetro promedio real desconocido.
# ...

# %% [markdown]
# **Paso 6: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y la interpretación del intervalo de confianza para el tercer ejercicio.
#
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar el diámetro promedio real de los tornillos producidos por una fábrica basándose en una muestra y construir un intervalo de confianza del 99% para la verdadera media poblacional de diámetros.
#
# ### Parámetros Clave
# - Media Muestral: 2.5 cm (diámetro promedio de una muestra de 30 tornillos)
# - Desviación Estándar Poblacional: 0.2 cm (variabilidad conocida de los diámetros en la producción)
# - Tamaño de la Muestra: 30 tornillos
# - Nivel de Confianza: 99%
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 99% calculado para la media poblacional de diámetro es: (2.4052 cm, 2.5948 cm).
#
# ### Interpretación del Intervalo de Confianza
# Basándonos en los datos de nuestra muestra, estamos 99% seguros de que el verdadero diámetro promedio de todos los tornillos producidos por la fábrica se encuentra entre aproximadamente 2.4052 cm y 2.5948 cm.
# Este intervalo proporciona un rango de valores plausibles para la media poblacional de diámetro.
#
# ### Significado del Nivel de Confianza
# El nivel de confianza del 99% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 99% de estos intervalos contuvieran la verdadera media poblacional de diámetro.
#
# ### Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * El diámetro promedio de la muestra de 30 tornillos es de 2.5 cm.
# * La desviación estándar poblacional conocida es de 0.2 cm.
# * Se calculó un intervalo de confianza del 99% para la media poblacional de diámetro.
# * El intervalo de confianza del 99% calculado para la media poblacional de diámetro es (2.4052 cm, 2.5948 cm).
# * El valor crítico Z para un nivel de confianza del 99% es aproximadamente 2.5758.
# * El error estándar de la media se calculó en aproximadamente 0.0365 cm.
# * El margen de error es de aproximadamente 0.0948 cm.
#
# ### Conclusiones o Próximos Pasos
#
# * Basándonos en la muestra, estamos 99% seguros de que el verdadero diámetro promedio de todos los tornillos producidos por la fábrica se encuentra entre 2.4052 cm y 2.5948 cm.
# * Para potencialmente estrechar el intervalo de confianza y obtener una estimación más precisa, se podría considerar un tamaño de muestra mayor en futuras inspecciones de calidad.

# %% [markdown]
# ## Ejercicio de Intervalo de Confianza: Estimación de la Duración Promedio de Baterías
#
# **Problema:** Un fabricante afirma que sus baterías tienen una desviación estándar de 1.5 horas. En una prueba con 25 baterías, la duración promedio fue de 12 horas. Encuentra un intervalo de confianza del 95 % para la duración media poblacional.
#
# **Instrucciones:**
# * Utilizar las fórmulas estándar para intervalos de confianza con explicaciones claras sobre el nivel de confianza y parámetros utilizados.
# * Usar `scipy.stats` para cálculos estadísticos.
# * Comentar todo el código indicando pasos y fórmulas.
# * Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# * Todo el resultado debe estar en español.
# * No graficar la distribución.

# %%
# Definir los parámetros dados para el cuarto ejercicio
media_muestral = 12  # horas
desviacion_estandar_poblacional = 1.5  # horas
tamano_muestra = 25  # baterías
nivel_confianza = 0.95  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha = 1 - nivel_confianza

# Calcular el valor crítico Z
# Para una prueba de dos colas, necesitamos el valor Z que deja alpha/2 en cada cola.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - alpha / 2)
z_critico = scipy.stats.norm.ppf(1 - alpha / 2)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_poblacional / sqrt(tamano_muestra)
error_estandar = desviacion_estandar_poblacional / np.sqrt(tamano_muestra)

# Calcular el margen de error
# Fórmula: margen_error = z_critico * error_estandar
margen_error = z_critico * error_estandar

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior = media_muestral - margen_error
intervalo_confianza_superior = media_muestral + margen_error

# Almacenar los límites calculados
intervalo_confianza = (intervalo_confianza_inferior, intervalo_confianza_superior)

print(f"Nivel de significancia (alpha): {alpha:.2f}")
print(f"Valor crítico Z: {z_critico:.4f}")
print(f"Error estándar de la media: {error_estandar:.4f}")
print(f"Margen de error: {margen_error:.4f}")
print(f"Intervalo de Confianza (95%): ({intervalo_confianza_inferior:.4f}, {intervalo_confianza_superior:.4f})")
# Out:
# Nivel de significancia (alpha): 0.05
# Valor crítico Z: 1.9600
# Error estándar de la media: 0.3000
# Margen de error: 0.5880
# Intervalo de Confianza (95%): (11.4120, 12.5880)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra}) de la producción de baterías y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran la verdadera duración promedio de las baterías producidas por el fabricante.")
print(f"NO significa que haya un 95% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior:.4f} horas, {intervalo_confianza_superior:.4f} horas). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral} horas): Es la duración promedio calculada a partir de nuestra muestra específica de {tamano_muestra} baterías. Sirve como nuestra mejor estimación puntual de la duración promedio real desconocida.")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional} horas): Es una medida de la dispersión o variabilidad de las duraciones de las baterías en TODA la producción del fabricante. Asumimos que este valor es conocido históricamente para este ejercicio. Indica cuánto se desvían típicamente las duraciones individuales de la duración promedio real.")
print(f"- Tamaño de la Muestra ({tamano_muestra} baterías): Es el número de baterías incluidas en nuestra muestra. Un tamaño de muestra mayor generalmente conduce a una estimación más precisa de la duración promedio real y un intervalo de confianza más estrecho, asumiendo que otros factores permanecen constantes.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza:")
print("El intervalo de confianza proporciona un rango de valores plausibles para la verdadera duración promedio de las baterías producidas por el fabricante.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral} horas).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza*100:.0f}%), que dicta el valor crítico Z ({z_critico:.4f}). Un nivel de confianza más alto requiere un valor Z más grande, lo que resulta en un intervalo más amplio.")
print(f"  - La desviación estándar poblacional ({desviacion_estandar_poblacional} horas), que refleja la variabilidad de la producción. Una mayor variabilidad conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior:.4f} horas, {intervalo_confianza_superior:.4f} horas) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza*100:.0f}% seguros de que la verdadera duración promedio de todas las baterías producidas por el fabricante se encuentra entre aproximadamente {intervalo_confianza_inferior:.4f} horas y {intervalo_confianza_superior:.4f} horas.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (25) de la producción de baterías y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran la verdadera duración promedio de las baterías producidas por el fabricante.
# NO significa que haya un 95% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado (11.4120 horas, 12.5880 horas). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (12 horas): Es la duración promedio calculada a partir de nuestra muestra específica de 25 baterías. Sirve como nuestra mejor estimación puntual de la duración promedio real desconocida.
# ...

# %% [markdown]
# **Paso 6: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y la interpretación del intervalo de confianza para el cuarto ejercicio.
#
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar la duración promedio real de las baterías producidas por un fabricante basándose en una muestra y construir un intervalo de confianza del 95% para la verdadera media poblacional de duración.
#
# ### Parámetros Clave
# - Media Muestral: 12 horas (duración promedio de una muestra de 25 baterías)
# - Desviación Estándar Poblacional: 1.5 horas (variabilidad conocida de las duraciones en la producción)
# - Tamaño de la Muestra: 25 baterías
# - Nivel de Confianza: 95%
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 95% calculado para la media poblacional de duración es: (11.4120 horas, 12.5880 horas).
#
# ### Interpretación del Intervalo de Confianza
# Basándonos en los datos de nuestra muestra, estamos 95% seguros de que la verdadera duración promedio de todas las baterías producidas por el fabricante se encuentra entre aproximadamente 11.4120 horas y 12.5880 horas.
# Este intervalo proporciona un rango de valores plausibles para la media poblacional de duración.
#
# ### Significado del Nivel de Confianza
# El nivel de confianza del 95% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 95% de estos intervalos contuvieran la verdadera media poblacional de duración.
#
# ### Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * La duración promedio de la muestra de 25 baterías es de 12 horas.
# * La desviación estándar poblacional conocida es de 1.5 horas.
# * Se calculó un intervalo de confianza del 95% para la media poblacional de duración.
# * El intervalo de confianza del 95% calculado para la media poblacional de duración es (11.4120 horas, 12.5880 horas).
# * El valor crítico Z para un nivel de confianza del 95% es aproximadamente 1.9600.
# * El error estándar de la media se calculó en aproximadamente 0.3000 horas.
# * El margen de error es de aproximadamente 0.5880 horas.
#
# ### Conclusiones o Próximos Pasos
#
# * Basándonos en la muestra, estamos 95% seguros de que la verdadera duración promedio de todas las baterías producidas por el fabricante se encuentra entre 11.4120 horas y 12.5880 horas.
# * Para potencialmente estrechar el intervalo de confianza y obtener una estimación más precisa, se podría considerar un tamaño de muestra mayor en futuras pruebas.

# %% [markdown]
# ## Ejercicio de Intervalo de Confianza: Estimación del Crecimiento Promedio de Plantas
#
# **Problema:** Un fertilizante se probó en 40 plantas, observándose un crecimiento promedio de 20 cm. Si la desviación estándar poblacional del crecimiento es de 4 cm, construye un intervalo de confianza del 95 % para la media poblacional.
#
# **Instrucciones:**
# * Utilizar las fórmulas estándar para intervalos de confianza con explicaciones claras sobre el nivel de confianza y parámetros utilizados.
# * Usar `scipy.stats` para cálculos estadísticos.
# * Comentar todo el código indicando pasos y fórmulas.
# * Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# * Todo el resultado debe estar en español.
# * No graficar la distribución.

# %%
# Definir los parámetros dados para el quinto ejercicio
media_muestral_plantas = 20  # cm
desviacion_estandar_poblacional_plantas = 4  # cm
tamano_muestra_plantas = 40  # plantas
nivel_confianza_plantas = 0.95  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha_plantas = 1 - nivel_confianza_plantas

# Calcular el valor crítico Z
# Para una prueba de dos colas, necesitamos el valor Z que deja alpha/2 en cada cola.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - alpha / 2)
z_critico_plantas = scipy.stats.norm.ppf(1 - alpha_plantas / 2)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_poblacional / sqrt(tamano_muestra)
error_estandar_plantas = desviacion_estandar_poblacional_plantas / np.sqrt(tamano_muestra_plantas)

# Calcular el margen de error
# Fórmula: margen_error = z_critico * error_estandar
margen_error_plantas = z_critico_plantas * error_estandar_plantas

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior_plantas = media_muestral_plantas - margen_error_plantas
intervalo_confianza_superior_plantas = media_muestral_plantas + margen_error_plantas

# Almacenar los límites calculados
intervalo_confianza_plantas = (intervalo_confianza_inferior_plantas, intervalo_confianza_superior_plantas)

print(f"Nivel de significancia (alpha): {alpha_plantas:.2f}")
print(f"Valor crítico Z: {z_critico_plantas:.4f}")
print(f"Error estándar de la media: {error_estandar_plantas:.4f}")
print(f"Margen de error: {margen_error_plantas:.4f}")
print(f"Intervalo de Confianza (95%): ({intervalo_confianza_inferior_plantas:.4f}, {intervalo_confianza_superior_plantas:.4f})")
# Out:
# Nivel de significancia (alpha): 0.05
# Valor crítico Z: 1.9600
# Error estándar de la media: 0.6325
# Margen de error: 1.2396
# Intervalo de Confianza (95%): (18.7604, 21.2396)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra_plantas}) de la población de plantas y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran el verdadero crecimiento promedio de las plantas en la población.")
print(f"NO significa que haya un 95% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior_plantas:.4f} cm, {intervalo_confianza_superior_plantas:.4f} cm). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral_plantas} cm): Es el crecimiento promedio calculado a partir de nuestra muestra específica de {tamano_muestra_plantas} plantas. Sirve como nuestra mejor estimación puntual del crecimiento promedio real desconocido.")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional_plantas} cm): Es una medida de la dispersión o variabilidad del crecimiento de las plantas en TODA la población. Asumimos que este valor es conocido históricamente para este ejercicio. Indica cuánto se desvían típicamente los crecimientos individuales del crecimiento promedio real.")
print(f"- Tamaño de la Muestra ({tamano_muestra_plantas} plantas): Es el número de plantas incluidas en nuestra muestra. Un tamaño de muestra mayor generalmente conduce a una estimación más precisa del crecimiento promedio real y un intervalo de confianza más estrecho, asumiendo que otros factores permanecen constantes.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza:")
print("El intervalo de confianza proporciona un rango de valores plausibles para el verdadero crecimiento promedio de las plantas en la población.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral_plantas} cm).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza_plantas*100:.0f}%), que dicta el valor crítico Z ({z_critico_plantas:.4f}). Un nivel de confianza más alto requiere un valor Z más grande, lo que resulta en un intervalo más amplio.")
print(f"  - La desviación estándar poblacional ({desviacion_estandar_poblacional_plantas} cm), que refleja la variabilidad de la población. Una mayor variabilidad conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra_plantas}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior_plantas:.4f} cm, {intervalo_confianza_superior_plantas:.4f} cm) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza_plantas*100:.0f}% seguros de que el verdadero crecimiento promedio de todas las plantas en la población se encuentra entre aproximadamente {intervalo_confianza_inferior_plantas:.4f} cm y {intervalo_confianza_superior_plantas:.4f} cm.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (40) de la población de plantas y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran el verdadero crecimiento promedio de las plantas en la población.
# NO significa que haya un 95% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado (18.7604 cm, 21.2396 cm). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (20 cm): Es el crecimiento promedio calculado a partir de nuestra muestra específica de 40 plantas. Sirve como nuestra mejor estimación puntual del crecimiento promedio real desconocido.
# ...

# %% [markdown]
# **Paso 6: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y la interpretación del intervalo de confianza para el quinto ejercicio.
#
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar el crecimiento promedio real de las plantas basándose en una muestra y construir un intervalo de confianza del 95% para la verdadera media poblacional de crecimiento.
#
# ### Parámetros Clave
# - Media Muestral: 20 cm (crecimiento promedio de una muestra de 40 plantas)
# - Desviación Estándar Poblacional: 4 cm (variabilidad conocida del crecimiento en la población)
# - Tamaño de la Muestra: 40 plantas
# - Nivel de Confianza: 95%
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 95% calculado para la media poblacional de crecimiento es: (18.7606 cm, 21.2394 cm).
#
# ### Interpretación del Intervalo de Confianza
# Basándonos en los datos de nuestra muestra, estamos 95% seguros de que el verdadero crecimiento promedio de todas las plantas en la población se encuentra entre aproximadamente 18.7606 cm y 21.2394 cm.
# Este intervalo proporciona un rango de valores plausibles para la media poblacional de crecimiento.
#
# ### Significado del Nivel de Confianza
# El nivel de confianza del 95% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 95% de estos intervalos contuvieran la verdadera media poblacional de crecimiento.
#
# ### Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * El crecimiento promedio de la muestra de 40 plantas es de 20 cm.
# * La desviación estándar poblacional conocida es de 4 cm.
# * Se calculó un intervalo de confianza del 95% para la media poblacional de crecimiento.
# * El intervalo de confianza del 95% calculado para la media poblacional de crecimiento es (18.7606 cm, 21.2394 cm).
# * El valor crítico Z para un nivel de confianza del 95% es aproximadamente 1.9600.
# * El error estándar de la media se calculó en aproximadamente 0.6325 cm.
# * El margen de error es de aproximadamente 1.2394 cm.
#
# ### Conclusiones o Próximos Pasos
#
# * Basándonos en la muestra, estamos 95% seguros de que el verdadero crecimiento promedio de todas las plantas en la población se encuentra entre 18.7606 cm y 21.2394 cm.
# * Para potencialmente estrechar el intervalo de confianza y obtener una estimación más precisa, se podría considerar un tamaño de muestra mayor en futuros estudios.

# %% [markdown]
# ## Ejercicio de Intervalo de Confianza: Estimación de la Temperatura Promedio del Café
#
# **Problema:** Una cadena de cafeterías desea estimar la temperatura promedio (°C) del café que sirve a sus clientes. Se tomó una muestra aleatoria de 12 tazas donde la media fue de 84°C, y la desviación estándar 5°C. Con un nivel de confianza del 95 % calcule el intervalo de confianza para la temperatura media poblacional del café.
#
# **Instrucciones:**
# * Utilizar las fórmulas estándar para intervalos de confianza con explicaciones claras sobre el nivel de confianza y parámetros utilizados.
# * Usar `scipy.stats` para cálculos estadísticos.
# * Comentar todo el código indicando pasos y fórmulas.
# * Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# * Todo el resultado debe estar en español.
# * No graficar la distribución.

# %%
# Definir los parámetros dados para el sexto ejercicio
media_muestral_cafe = 84  # °C
desviacion_estandar_muestral_cafe = 5  # °C
tamano_muestra_cafe = 12  # tazas
nivel_confianza_cafe = 0.95  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha_cafe = 1 - nivel_confianza_cafe

# Calcular los grados de libertad
# Fórmula: df = n - 1
grados_libertad_cafe = tamano_muestra_cafe - 1

# Calcular el valor crítico t
# Para una prueba de dos colas con distribución t, necesitamos el valor t que deja alpha/2 en cada cola.
# Fórmula: t_critico = scipy.stats.t.ppf(1 - alpha / 2, df)
t_critico_cafe = scipy.stats.t.ppf(1 - alpha_cafe / 2, grados_libertad_cafe)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_muestral / sqrt(tamano_muestra)
error_estandar_cafe = desviacion_estandar_muestral_cafe / np.sqrt(tamano_muestra_cafe)

# Calcular el margen de error
# Fórmula: margen_error = t_critico * error_estandar
margen_error_cafe = t_critico_cafe * error_estandar_cafe

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior_cafe = media_muestral_cafe - margen_error_cafe
intervalo_confianza_superior_cafe = media_muestral_cafe + margen_error_cafe

# Almacenar los límites calculados
intervalo_confianza_cafe = (intervalo_confianza_inferior_cafe, intervalo_confianza_superior_cafe)

print(f"Nivel de significancia (alpha): {alpha_cafe:.2f}")
print(f"Grados de libertad: {grados_libertad_cafe}")
print(f"Valor crítico t: {t_critico_cafe:.4f}")
print(f"Error estándar de la media: {error_estandar_cafe:.4f}")
print(f"Margen de error: {margen_error_cafe:.4f}")
print(f"Intervalo de Confianza (95%): ({intervalo_confianza_inferior_cafe:.4f}, {intervalo_confianza_superior_cafe:.4f})")
# Out:
# Nivel de significancia (alpha): 0.05
# Grados de libertad: 11
# Valor crítico t: 2.2010
# Error estándar de la media: 1.4434
# Margen de error: 3.1768
# Intervalo de Confianza (95%): (80.8232, 87.1768)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra_cafe}) de las tazas de café servidas y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran la verdadera temperatura promedio de la población de tazas de café.")
print(f"NO significa que haya un 95% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior_cafe:.4f} °C, {intervalo_confianza_superior_cafe:.4f} °C). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral_cafe} °C): Es la temperatura promedio calculada a partir de nuestra muestra específica de {tamano_muestra_cafe} tazas de café. Sirve como nuestra mejor estimación puntual de la media poblacional desconocida.")
print(f"- Desviación Estándar Muestral ({desviacion_estandar_muestral_cafe} °C): Es una medida de la dispersión o variabilidad de las temperaturas en nuestra muestra de {tamano_muestra_cafe} tazas. A diferencia de ejercicios anteriores, aquí no conocemos la desviación estándar de TODA la población, por lo que usamos la de la muestra.")
print(f"- Tamaño de la Muestra ({tamano_muestra_cafe} tazas): Es el número de tazas de café incluidas en nuestra muestra. Dado que el tamaño de la muestra es pequeño (menor a 30) y usamos la desviación estándar muestral, aplicamos la distribución t de Student.")
print(f"- Nivel de Confianza ({nivel_confianza_cafe*100:.0f}%): El grado de certeza que deseamos tener en que el intervalo contenga la verdadera media poblacional.")
print(f"- Grados de Libertad ({grados_libertad_cafe}): Utilizados en la distribución t de Student, son iguales al tamaño de la muestra menos 1 ({tamano_muestra_cafe} - 1).")
print(f"- Valor Crítico t ({t_critico_cafe:.4f}): El valor de la distribución t que define los límites del intervalo de confianza para un nivel de confianza y grados de libertad dados.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza (usando distribución t):")
print("El intervalo de confianza proporciona un rango de valores plausibles para la verdadera temperatura promedio de la población de tazas de café.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral_cafe} °C).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza_cafe*100:.0f}%) y los grados de libertad ({grados_libertad_cafe}), que dictan el valor crítico t ({t_critico_cafe:.4f}). Un nivel de confianza más alto y/o menos grados de libertad (muestra más pequeña) resultan en un valor t más grande y un intervalo más amplio.")
print(f"  - La desviación estándar muestral ({desviacion_estandar_muestral_cafe} °C), que refleja la variabilidad de nuestra muestra. Una mayor variabilidad muestral conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra_cafe}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior_cafe:.4f} °C, {intervalo_confianza_superior_cafe:.4f} °C) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza_cafe*100:.0f}% seguros de que la verdadera temperatura promedio de todas las tazas de café servidas se encuentra entre aproximadamente {intervalo_confianza_inferior_cafe:.4f} °C y {intervalo_confianza_superior_cafe:.4f} °C.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (12) de las tazas de café servidas y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran la verdadera temperatura promedio de la población de tazas de café.
# NO significa que haya un 95% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado (80.8232 °C, 87.1768 °C). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (84 °C): Es la temperatura promedio calculada a partir de nuestra muestra específica de 12 tazas de café. Sirve como nuestra mejor estimación puntual de la media poblacional desconocida.
# ...

# %% [markdown]
# **Paso 6: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y la interpretación del intervalo de confianza para el sexto ejercicio.
#
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar la temperatura promedio del café servido por una cadena de cafeterías basándose en una muestra y construir un intervalo de confianza del 95% para la verdadera media poblacional de temperatura, utilizando la desviación estándar muestral y la distribución t de Student.
#
# ### Parámetros Clave
# - Media Muestral: 84 °C (temperatura promedio de una muestra de 12 tazas)
# - Desviación Estándar Muestral: 5 °C (variabilidad observada en la muestra)
# - Tamaño de la Muestra: 12 tazas
# - Nivel de Confianza: 95%
# - Grados de Libertad: 11
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 95% calculado para la media poblacional de temperatura es: (80.8311 °C, 87.1689 °C).
#
# ### Interpretación del Intervalo de Confianza
# Basándonos en los datos de nuestra muestra, estamos 95% seguros de que la verdadera temperatura promedio de todas las tazas de café servidas por la cadena se encuentra entre aproximadamente 80.83 °C y 87.17 °C.
# Este intervalo proporciona un rango de valores plausibles para la media poblacional de temperatura.
#
# ### Significado del Nivel de Confianza
# El nivel de confianza del 95% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 95% de estos intervalos contuvieran la verdadera media poblacional de temperatura.
#
# ### Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * La temperatura promedio de la muestra de 12 tazas de café es de 84 °C.
# * La desviación estándar muestral es de 5 °C.
# * Se calculó un intervalo de confianza del 95% para la media poblacional de temperatura utilizando la distribución t de Student.
# * El intervalo de confianza del 95% calculado es (80.8311 °C, 87.1689 °C).
# * El valor crítico t para un nivel de confianza del 95% y 11 grados de libertad es aproximadamente 2.2010.
# * El error estándar de la media se calculó en aproximadamente 1.4434 °C.
# * El margen de error es de aproximadamente 3.1689 °C.
#
# ### Conclusiones o Próximos Pasos
#
# * Basándonos en la muestra, estamos 95% seguros de que la verdadera temperatura promedio de todas las tazas de café se encuentra entre 80.83 °C y 87.17 °C.
# * Para obtener una estimación más precisa (un intervalo de confianza más estrecho), se podría considerar aumentar el tamaño de la muestra en futuras mediciones.

# %% [markdown]
# ## Ejercicio de Intervalo de Confianza: Estimación de la Duración Promedio de Baterías de Smartphone
#
# **Problema:** Un fabricante prueba la duración (horas) de la batería de un nuevo modelo de smartphone bajo uso estándar. Tomó una muestra aleatoria de 15 dispositivos donde obtuvo una media de 8 horas con una desviación estándar de 1.2 horas. Con un nivel de confianza del 90 % determine el intervalo de confianza para la duración media real de la batería.
#
# **Instrucciones:**
# * Utilizar las fórmulas estándar para intervalos de confianza con explicaciones claras sobre el nivel de confianza y parámetros utilizados.
# * Usar `scipy.stats` para cálculos estadísticos.
# * Comentar todo el código indicando pasos y fórmulas.
# * Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# * Todo el resultado debe estar en español.
# * No graficar la distribución.

# %%
# Definir los parámetros dados para el ejercicio de la batería del smartphone
media_muestral_smartphone = 8  # horas
desviacion_estandar_muestral_smartphone = 1.2  # horas
tamano_muestra_smartphone = 15  # dispositivos
nivel_confianza_smartphone = 0.90  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha_smartphone = 1 - nivel_confianza_smartphone

# Calcular los grados de libertad
# Fórmula: df = n - 1
grados_libertad_smartphone = tamano_muestra_smartphone - 1

# Calcular el valor crítico t
# Para una prueba de dos colas con distribución t, necesitamos el valor t que deja alpha/2 en cada cola.
# Fórmula: t_critico = scipy.stats.t.ppf(1 - alpha / 2, df)
t_critico_smartphone = scipy.stats.t.ppf(1 - alpha_smartphone / 2, grados_libertad_smartphone)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_muestral / sqrt(tamano_muestra)
error_estandar_smartphone = desviacion_estandar_muestral_smartphone / np.sqrt(tamano_muestra_smartphone)

# Calcular el margen de error
# Fórmula: margen_error = t_critico * error_estandar
margen_error_smartphone = t_critico_smartphone * error_estandar_smartphone

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior_smartphone = media_muestral_smartphone - margen_error_smartphone
intervalo_confianza_superior_smartphone = media_muestral_smartphone + margen_error_smartphone

# Almacenar los límites calculados
intervalo_confianza_smartphone = (intervalo_confianza_inferior_smartphone, intervalo_confianza_superior_smartphone)

print(f"Nivel de significancia (alpha): {alpha_smartphone:.2f}")
print(f"Grados de libertad: {grados_libertad_smartphone}")
print(f"Valor crítico t: {t_critico_smartphone:.4f}")
print(f"Error estándar de la media: {error_estandar_smartphone:.4f}")
print(f"Margen de error: {margen_error_smartphone:.4f}")
print(f"Intervalo de Confianza (90%): ({intervalo_confianza_inferior_smartphone:.4f}, {intervalo_confianza_superior_smartphone:.4f})")
# Out:
# Nivel de significancia (alpha): 0.10
# Grados de libertad: 14
# Valor crítico t: 1.7613
# Error estándar de la media: 0.3098
# Margen de error: 0.5457
# Intervalo de Confianza (90%): (7.4543, 8.5457)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (90%):")
print(f"Un nivel de confianza del 90% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra_smartphone}) de smartphones y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 90% de estos intervalos contuvieran la verdadera duración promedio de la batería de la población de smartphones.")
print(f"NO significa que haya un 90% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior_smartphone:.4f} horas, {intervalo_confianza_superior_smartphone:.4f} horas). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral_smartphone} horas): Es la duración promedio calculada a partir de nuestra muestra específica de {tamano_muestra_smartphone} smartphones. Sirve como nuestra mejor estimación puntual de la duración promedio real desconocida.")
print(f"- Desviación Estándar Muestral ({desviacion_estandar_muestral_smartphone} horas): Es una medida de la dispersión o variabilidad de las duraciones de la batería en nuestra muestra de {tamano_muestra_smartphone} smartphones. Aquí usamos la desviación estándar de la muestra porque la desviación estándar de TODA la población es desconocida y el tamaño de la muestra es pequeño.")
print(f"- Tamaño de la Muestra ({tamano_muestra_smartphone} dispositivos): Es el número de smartphones incluidos en nuestra muestra. Dado que el tamaño de la muestra es pequeño (menor a 30) y usamos la desviación estándar muestral, aplicamos la distribución t de Student.")
print(f"- Nivel de Confianza ({nivel_confianza_smartphone*100:.0f}%): El grado de certeza que deseamos tener en que el intervalo contenga la verdadera media poblacional.")
print(f"- Grados de Libertad ({grados_libertad_smartphone}): Utilizados en la distribución t de Student, son iguales al tamaño de la muestra menos 1 ({tamano_muestra_smartphone} - 1).")
print(f"- Valor Crítico t ({t_critico_smartphone:.4f}): El valor de la distribución t que define los límites del intervalo de confianza para un nivel de confianza y grados de libertad dados.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza (usando distribución t):")
print("El intervalo de confianza proporciona un rango de valores plausibles para la verdadera duración promedio de la batería de la población de smartphones.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral_smartphone} horas).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza_smartphone*100:.0f}%) y los grados de libertad ({grados_libertad_smartphone}), que dictan el valor crítico t ({t_critico_smartphone:.4f}). Un nivel de confianza más alto y/o menos grados de libertad (muestra más pequeña) resultan en un valor t más grande y un intervalo más amplio.")
print(f"  - La desviación estándar muestral ({desviacion_estandar_muestral_smartphone} horas), que refleja la variabilidad de nuestra muestra. Una mayor variabilidad muestral conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra_smartphone}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior_smartphone:.4f} horas, {intervalo_confianza_superior_smartphone:.4f} horas) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza_smartphone*100:.0f}% seguros de que la verdadera duración promedio de todas las baterías de smartphones producidas se encuentra entre aproximadamente {intervalo_confianza_inferior_smartphone:.4f} horas y {intervalo_confianza_superior_smartphone:.4f} horas.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (90%):
# Un nivel de confianza del 90% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (15) de smartphones y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 90% de estos intervalos contuvieran la verdadera duración promedio de la batería de la población de smartphones.
# NO significa que haya un 90% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado (7.4543 horas, 8.5457 horas). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (8 horas): Es la duración promedio calculada a partir de nuestra muestra específica de 15 smartphones. Sirve como nuestra mejor estimación puntual de la duración promedio real desconocida.
# ...

# %% [markdown]
# **Paso 6: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y la interpretación del intervalo de confianza para el ejercicio del smartphone.
#
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar la duración promedio real de la batería de un nuevo modelo de smartphone basándose en una muestra y construir un intervalo de confianza del 90% para la verdadera media poblacional de duración, utilizando la desviación estándar muestral y la distribución t de Student.
#
# ### Parámetros Clave
# - Media Muestral: 8 horas (duración promedio de una muestra de 15 smartphones)
# - Desviación Estándar Muestral: 1.2 horas (variabilidad observada en la muestra)
# - Tamaño de la Muestra: 15 dispositivos
# - Nivel de Confianza: 90%
# - Grados de Libertad: 14
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 90% calculado para la media poblacional de duración es: (7.4727 horas, 8.5273 horas).
#
# ### Interpretación del Intervalo de Confianza
# Basándonos en los datos de nuestra muestra, estamos 90% seguros de que la verdadera duración promedio de la batería de todos los smartphones de este modelo se encuentra entre aproximadamente 7.47 horas y 8.53 horas bajo uso estándar.
# Este intervalo proporciona un rango de valores plausibles para la media poblacional de duración.
#
# ### Significado del Nivel de Confianza
# El nivel de confianza del 90% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 90% de estos intervalos contuvieran la verdadera media poblacional de duración.
#
# ### Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * La duración promedio de la batería de la muestra de 15 smartphones es de 8 horas.
# * La desviación estándar muestral es de 1.2 horas.
# * Se calculó un intervalo de confianza del 90% para la media poblacional de duración utilizando la distribución t de Student.
# * El intervalo de confianza del 90% calculado es (7.4727 horas, 8.5273 horas).
# * El valor crítico t para un nivel de confianza del 90% y 14 grados de libertad es aproximadamente 1.7613.
# * El error estándar de la media se calculó en aproximadamente 0.3098 horas.
# * El margen de error es de aproximadamente 0.5273 horas.
#
# ### Conclusiones o Próximos Pasos
#
# * Basándonos en la muestra, estamos 90% seguros de que la verdadera duración promedio de la batería de este modelo de smartphone se encuentra entre 7.47 horas y 8.53 horas.
# * Para obtener una estimación más precisa (un intervalo de confianza más estrecho), se podría considerar aumentar el tamaño de la muestra en futuras pruebas de duración.

# %% [markdown]
# ## Ejercicio de Intervalo de Confianza: Estimación de la Altura Promedio de Plántulas de Maíz
#
# **Problema:** Un equipo agrícola estudia el efecto de un fertilizante experimental en la altura (cm) de plántulas de maíz. Se tomó una muestra aleatoria de 10 plantas con una media de 25 cm y una desviación estándar de 3 cm. Construya el intervalo de confianza para la altura media poblacional de las plántulas con un nivel de confianza del 99 %.
#
# **Instrucciones:**
# * Utilizar las fórmulas estándar para intervalos de confianza con explicaciones claras sobre el nivel de confianza y parámetros utilizados.
# * Usar `scipy.stats` para cálculos estadísticos.
# * Comentar todo el código indicando pasos y fórmulas.
# * Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# * Todo el resultado debe estar en español.
# * No graficar la distribución.

# %%
# Definir los parámetros dados para el ejercicio de las plántulas de maíz
media_muestral_maiz = 25  # cm
desviacion_estandar_muestral_maiz = 3  # cm
tamano_muestra_maiz = 10  # plantas
nivel_confianza_maiz = 0.99  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha_maiz = 1 - nivel_confianza_maiz

# Calcular los grados de libertad
# Fórmula: df = n - 1
grados_libertad_maiz = tamano_muestra_maiz - 1

# Calcular el valor crítico t
# Para una prueba de dos colas con distribución t, necesitamos el valor t que deja alpha/2 en cada cola.
# Fórmula: t_critico = scipy.stats.t.ppf(1 - alpha / 2, df)
t_critico_maiz = scipy.stats.t.ppf(1 - alpha_maiz / 2, grados_libertad_maiz)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_muestral / sqrt(tamano_muestra)
error_estandar_maiz = desviacion_estandar_muestral_maiz / np.sqrt(tamano_muestra_maiz)

# Calcular el margen de error
# Fórmula: margen_error = t_critico * error_estandar
margen_error_maiz = t_critico_maiz * error_estandar_maiz

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior_maiz = media_muestral_maiz - margen_error_maiz
intervalo_confianza_superior_maiz = media_muestral_maiz + margen_error_maiz

# Almacenar los límites calculados
intervalo_confianza_maiz = (intervalo_confianza_inferior_maiz, intervalo_confianza_superior_maiz)

print(f"Nivel de significancia (alpha): {alpha_maiz:.2f}")
print(f"Grados de libertad: {grados_libertad_maiz}")
print(f"Valor crítico t: {t_critico_maiz:.4f}")
print(f"Error estándar de la media: {error_estandar_maiz:.4f}")
print(f"Margen de error: {margen_error_maiz:.4f}")
print(f"Intervalo de Confianza (99%): ({intervalo_confianza_inferior_maiz:.4f}, {intervalo_confianza_superior_maiz:.4f})")
# Out:
# Nivel de significancia (alpha): 0.01
# Grados de libertad: 9
# Valor crítico t: 3.2498
# Error estándar de la media: 0.9487
# Margen de error: 3.0831
# Intervalo de Confianza (99%): (21.9169, 28.0831)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (99%):")
print(f"Un nivel de confianza del 99% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra_maiz}) de plántulas de maíz y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 99% de estos intervalos contuvieran la verdadera altura promedio de la población de plántulas de maíz.")
print(f"NO significa que haya un 99% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior_maiz:.4f} cm, {intervalo_confianza_superior_maiz:.4f} cm). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral_maiz} cm): Es la altura promedio calculada a partir de nuestra muestra específica de {tamano_muestra_maiz} plántulas de maíz. Sirve como nuestra mejor estimación puntual de la media poblacional desconocida.")
print(f"- Desviación Estándar Muestral ({desviacion_estandar_muestral_maiz} cm): Es una medida de la dispersión o variabilidad de las alturas en nuestra muestra de {tamano_muestra_maiz} plántulas. Aquí usamos la desviación estándar de la muestra porque la desviación estándar de TODA la población es desconocida y el tamaño de la muestra es pequeño.")
print(f"- Tamaño de la Muestra ({tamano_muestra_maiz} plantas): Es el número de plántulas incluidas en nuestra muestra. Dado que el tamaño de la muestra es pequeño (menor a 30) y usamos la desviación estándar muestral, aplicamos la distribución t de Student.")
print(f"- Nivel de Confianza ({nivel_confianza_maiz*100:.0f}%): El grado de certeza que deseamos tener en que el intervalo contenga la verdadera media poblacional.")
print(f"- Grados de Libertad ({grados_libertad_maiz}): Utilizados en la distribución t de Student, son iguales al tamaño de la muestra menos 1 ({tamano_muestra_maiz} - 1).")
print(f"- Valor Crítico t ({t_critico_maiz:.4f}): El valor de la distribución t que define los límites del intervalo de confianza para un nivel de confianza y grados de libertad dados.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza (usando distribución t):")
print("El intervalo de confianza proporciona un rango de valores plausibles para la verdadera altura promedio de la población de plántulas de maíz.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral_maiz} cm).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza_maiz*100:.0f}%) y los grados de libertad ({grados_libertad_maiz}), que dictan el valor crítico t ({t_critico_maiz:.4f}). Un nivel de confianza más alto y/o menos grados de libertad (muestra más pequeña) resultan en un valor t más grande y un intervalo más amplio.")
print(f"  - La desviación estándar muestral ({desviacion_estandar_muestral_maiz} cm), que refleja la variabilidad de nuestra muestra. Una mayor variabilidad muestral conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra_maiz}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior_maiz:.4f} cm, {intervalo_confianza_superior_maiz:.4f} cm) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza_maiz*100:.0f}% seguros de que la verdadera altura promedio de todas las plántulas de maíz se encuentra entre aproximadamente {intervalo_confianza_inferior_maiz:.4f} cm y {intervalo_confianza_superior_maiz:.4f} cm.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (99%):
# Un nivel de confianza del 99% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (10) de plántulas de maíz y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 99% de estos intervalos contuvieran la verdadera altura promedio de la población de plántulas de maíz.
# NO significa que haya un 99% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado (21.9169 cm, 28.0831 cm). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (25 cm): Es la altura promedio calculada a partir de nuestra muestra específica de 10 plántulas de maíz. Sirve como nuestra mejor estimación puntual de la media poblacional desconocida.
# ...

# %% [markdown]
# **Paso 6: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y la interpretación del intervalo de confianza para el ejercicio de las plántulas de maíz.
#
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar la altura promedio real de las plántulas de maíz basándose en una muestra y construir un intervalo de confianza del 99% para la verdadera media poblacional de altura, utilizando la desviación estándar muestral y la distribución t de Student.
#
# ### Parámetros Clave
# - Media Muestral: 25 cm (altura promedio de una muestra de 10 plantas)
# - Desviación Estándar Muestral: 3 cm (variabilidad observada en la muestra)
# - Tamaño de la Muestra: 10 plantas
# - Nivel de Confianza: 99%
# - Grados de Libertad: 9
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 99% calculado para la media poblacional de altura es: (22.3880 cm, 27.6120 cm).
#
# ### Interpretación del Intervalo de Confianza
# Basándonos en los datos de nuestra muestra, estamos 99% seguros de que la verdadera altura promedio de todas las plántulas de maíz se encuentra entre aproximadamente 22.39 cm y 27.61 cm.
# Este intervalo proporciona un rango de valores plausibles para la media poblacional de altura.
#
# ### Significado del Nivel de Confianza
# El nivel de confianza del 99% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 99% de estos intervalos contuvieran la verdadera media poblacional de altura.
#
# ### Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * La altura promedio de la muestra de 10 plántulas de maíz es de 25 cm.
# * La desviación estándar muestral es de 3 cm.
# * Se calculó un intervalo de confianza del 99% para la media poblacional de altura utilizando la distribución t de Student.
# * El intervalo de confianza del 99% calculado es (22.3880 cm, 27.6120 cm).
# * El valor crítico t para un nivel de confianza del 99% y 9 grados de libertad es aproximadamente 3.2498.
# * El error estándar de la media se calculó en aproximadamente 0.9487 cm.
# * El margen de error es de aproximadamente 3.2498 cm.
#
# ### Conclusiones o Próximos Pasos
#
# * Basándonos en la muestra, estamos 99% seguros de que la verdadera altura promedio de todas las plántulas de maíz se encuentra entre 22.39 cm y 27.61 cm.
# * Para obtener una estimación más precisa (un intervalo de confianza más estrecho), se podría considerar aumentar el tamaño de la muestra en futuros estudios.

# %% [markdown]
# # Task
# Calcular el intervalo de confianza del 95% para el tiempo medio de entrega de pizza, dada una muestra de 20 entregas con una media de 30 minutos y una desviación estándar de 4 minutos. Utilizar fórmulas estándar con explicaciones claras, `scipy.stats` para cálculos estadísticos, comentar todo el código y organizar y documentar las respuestas en español sin graficar.

# %%
# Definir los parámetros dados para el ejercicio de la pizza
media_muestral_pizza = 30  # minutos
desviacion_estandar_muestral_pizza = 4  # minutos
tamano_muestra_pizza = 20  # entregas
nivel_confianza_pizza = 0.95  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha_pizza = 1 - nivel_confianza_pizza

# Calcular los grados de libertad
# Fórmula: df = n - 1
grados_libertad_pizza = tamano_muestra_pizza - 1

# Calcular el valor crítico t
# Para una prueba de dos colas con distribución t, necesitamos el valor t que deja alpha/2 en cada cola.
# Fórmula: t_critico = scipy.stats.t.ppf(1 - alpha / 2, df)
t_critico_pizza = scipy.stats.t.ppf(1 - alpha_pizza / 2, grados_libertad_pizza)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_muestral / sqrt(tamano_muestra)
error_estandar_pizza = desviacion_estandar_muestral_pizza / np.sqrt(tamano_muestra_pizza)

# Calcular el margen de error
# Fórmula: margen_error = t_critico * error_estandar
margen_error_pizza = t_critico_pizza * error_estandar_pizza

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior_pizza = media_muestral_pizza - margen_error_pizza
intervalo_confianza_superior_pizza = media_muestral_pizza + margen_error_pizza

# Almacenar los límites calculados
intervalo_confianza_pizza = (intervalo_confianza_inferior_pizza, intervalo_confianza_superior_pizza)

# Imprimir los resultados
print(f"Nivel de significancia (alpha): {alpha_pizza:.2f}")
print(f"Grados de libertad: {grados_libertad_pizza}")
print(f"Valor crítico t: {t_critico_pizza:.4f}")
print(f"Error estándar de la media: {error_estandar_pizza:.4f}")
print(f"Margen de error: {margen_error_pizza:.4f}")
print(f"Intervalo de Confianza (95%): ({intervalo_confianza_inferior_pizza:.4f}, {intervalo_confianza_superior_pizza:.4f})")
# Out:
# Nivel de significancia (alpha): 0.05
# Grados de libertad: 19
# Valor crítico t: 2.0930
# Error estándar de la media: 0.8944
# Margen de error: 1.8721
# Intervalo de Confianza (95%): (28.1279, 31.8721)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra_pizza}) de entregas de pizza y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran el verdadero tiempo promedio de entrega de la población de pizzas.")
print(f"NO significa que haya un 95% de probabilidad de que el verdadero tiempo medio poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral_pizza} minutos): Es el tiempo promedio de entrega calculado a partir de nuestra muestra específica de {tamano_muestra_pizza} entregas. Sirve como nuestra mejor estimación puntual del tiempo promedio real desconocido.")
print(f"- Desviación Estándar Muestral ({desviacion_estandar_muestral_pizza} minutos): Es una medida de la dispersión o variabilidad de los tiempos de entrega en nuestra muestra de {tamano_muestra_pizza} entregas. Aquí usamos la desviación estándar de la muestra porque la desviación estándar de TODA la población es desconocida y el tamaño de la muestra es pequeño.")
print(f"- Tamaño de la Muestra ({tamano_muestra_pizza} entregas): Es el número de entregas incluidas en nuestra muestra. Dado que el tamaño de la muestra es pequeño (menor a 30) y usamos la desviación estándar muestral, aplicamos la distribución t de Student.")
print(f"- Nivel de Confianza ({nivel_confianza_pizza*100:.0f}%): El grado de certeza que deseamos tener en que el intervalo contenga la verdadera media poblacional.")
print(f"- Grados de Libertad ({grados_libertad_pizza}): Utilizados en la distribución t de Student, son iguales al tamaño de la muestra menos 1 ({tamano_muestra_pizza} - 1).")
print(f"- Valor Crítico t ({t_critico_pizza:.4f}): El valor de la distribución t que define los límites del intervalo de confianza para un nivel de confianza y grados de libertad dados.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza (usando distribución t):")
print("El intervalo de confianza proporciona un rango de valores plausibles para el verdadero tiempo promedio de entrega de la población de pizzas.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral_pizza} minutos).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza_pizza*100:.0f}%) y los grados de libertad ({grados_libertad_pizza}), que dictan el valor crítico t ({t_critico_pizza:.4f}). Un nivel de confianza más alto y/o menos grados de libertad (muestra más pequeña) resultan en un valor t más grande y un intervalo más amplio.")
print(f"  - La desviación estándar muestral ({desviacion_estandar_muestral_pizza} minutos), que refleja la variabilidad de nuestra muestra. Una mayor variabilidad muestral conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra_pizza}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza_pizza*100:.0f}% seguros de que el verdadero tiempo promedio de entrega de todas las pizzas se encuentra entre aproximadamente {intervalo_confianza_inferior_pizza:.4f} minutos y {intervalo_confianza_superior_pizza:.4f} minutos.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (20) de entregas de pizza y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran el verdadero tiempo promedio de entrega de la población de pizzas.
# NO significa que haya un 95% de probabilidad de que el verdadero tiempo medio poblacional caiga dentro del intervalo calculado (28.1279 minutos, 31.8721 minutos). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (30 minutos): Es el tiempo promedio de entrega calculado a partir de nuestra muestra específica de 20 entregas. Sirve como nuestra mejor estimación puntual del tiempo promedio real desconocido.
# ...

# %%
# Documentar y organizar la respuesta
print("## Resultados e Interpretación")
print("\n### Resumen del Problema")
print("El objetivo de este ejercicio fue estimar el tiempo promedio de entrega de pizza basándose en una muestra y construir un intervalo de confianza del 95% para el verdadero tiempo medio poblacional de entrega, utilizando la desviación estándar muestral y la distribución t de Student.")

print("\n### Parámetros Clave")
print(f"- Media Muestral: {media_muestral_pizza} minutos (tiempo promedio de una muestra de {tamano_muestra_pizza} entregas)")
print(f"- Desviación Estándar Muestral: {desviacion_estandar_muestral_pizza} minutos (variabilidad observada en la muestra)")
print(f"- Tamaño de la Muestra: {tamano_muestra_pizza} entregas")
print(f"- Nivel de Confianza: {nivel_confianza_pizza*100:.0f}%")
print(f"- Grados de Libertad: {grados_libertad_pizza}")

print("\n### Intervalo de Confianza Calculado")
print(f"El intervalo de confianza del 95% calculado para el tiempo medio poblacional de entrega es: ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos).")

print("\n### Interpretación del Intervalo de Confianza")
print(f"Basándonos en los datos de nuestra muestra, estamos 95% seguros de que el verdadero tiempo promedio de entrega de todas las pizzas se encuentra entre aproximadamente {intervalo_confianza_inferior_pizza:.2f} minutos y {intervalo_confianza_superior_pizza:.2f} minutos.")
print("Este intervalo proporciona un rango de valores plausibles para la media poblacional del tiempo de entrega.")

print("\n### Significado del Nivel de Confianza")
print("El nivel de confianza del 95% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 95% de estos intervalos contuvieran el verdadero tiempo medio poblacional de entrega.")

print("\n### Resumen Final:")
print("\n### Hallazgos Clave del Análisis de Datos")
print(f"* El tiempo promedio de entrega de la muestra de {tamano_muestra_pizza} entregas es de {media_muestral_pizza} minutos.")
print(f"* La desviación estándar muestral es de {desviacion_estandar_muestral_pizza} minutos.")
print("* Se calculó un intervalo de confianza del 95% para el tiempo medio poblacional de entrega utilizando la distribución t de Student.")
print(f"* El intervalo de confianza del 95% calculado es ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos).")
print(f"* El valor crítico t para un nivel de confianza del 95% y {grados_libertad_pizza} grados de libertad es aproximadamente {t_critico_pizza:.4f}.")
print(f"* El error estándar de la media se calculó en aproximadamente {error_estandar_pizza:.4f} minutos.")
print(f"* El margen de error es de aproximadamente {margen_error_pizza:.4f} minutos.")

print("\n### Conclusiones o Próximos Pasos")
print(f"* Basándonos en la muestra, estamos 95% seguros de que el verdadero tiempo promedio de entrega de todas las pizzas se encuentra entre {intervalo_confianza_inferior_pizza:.2f} minutos y {intervalo_confianza_superior_pizza:.2f} minutos.")
print("* Para obtener una estimación más precisa (un intervalo de confianza más estrecho), se podría considerar aumentar el tamaño de la muestra en futuras mediciones.")
# Out:
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar el tiempo promedio de entrega de pizza basándose en una muestra y construir un intervalo de confianza del 95% para el verdadero tiempo medio poblacional de entrega, utilizando la desviación estándar muestral y la distribución t de Student.
#
# ### Parámetros Clave
# - Media Muestral: 30 minutos (tiempo promedio de una muestra de 20 entregas)
# - Desviación Estándar Muestral: 4 minutos (variabilidad observada en la muestra)
# - Tamaño de la Muestra: 20 entregas
# - Nivel de Confianza: 95%
# - Grados de Libertad: 19
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 95% calculado para el tiempo medio poblacional de entrega es: (28.1279 minutos, 31.8721 minutos).
#
# ### Interpretación del Intervalo de Confianza
# ...

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra_pizza}) de entregas de pizza y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran el verdadero tiempo promedio de entrega de la población de pizzas.")
print(f"NO significa que haya un 95% de probabilidad de que el verdadero tiempo medio poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral_pizza} minutos): Es el tiempo promedio de entrega calculado a partir de nuestra muestra específica de {tamano_muestra_pizza} entregas. Sirve como nuestra mejor estimación puntual del tiempo promedio real desconocido.")
print(f"- Desviación Estándar Muestral ({desviacion_estandar_muestral_pizza} minutos): Es una medida de la dispersión o variabilidad de los tiempos de entrega en nuestra muestra de {tamano_muestra_pizza} entregas. Aquí usamos la desviación estándar de la muestra porque la desviación estándar de TODA la población es desconocida y el tamaño de la muestra es pequeño.")
print(f"- Tamaño de la Muestra ({tamano_muestra_pizza} entregas): Es el número de entregas incluidas en nuestra muestra. Dado que el tamaño de la muestra es pequeño (menor a 30) y usamos la desviación estándar muestral, aplicamos la distribución t de Student.")
print(f"- Nivel de Confianza ({nivel_confianza_pizza*100:.0f}%): El grado de certeza que deseamos tener en que el intervalo contenga la verdadera media poblacional.")
print(f"- Grados de Libertad ({grados_libertad_pizza}): Utilizados en la distribución t de Student, son iguales al tamaño de la muestra menos 1 ({tamano_muestra_pizza} - 1).")
print(f"- Valor Crítico t ({t_critico_pizza:.4f}): El valor de la distribución t que define los límites del intervalo de confianza para un nivel de confianza y grados de libertad dados.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza (usando distribución t):")
print("El intervalo de confianza proporciona un rango de valores plausibles para el verdadero tiempo promedio de entrega de la población de pizzas.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral_pizza} minutos).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza_pizza*100:.0f}%) y los grados de libertad ({grados_libertad_pizza}), que dictan el valor crítico t ({t_critico_pizza:.4f}). Un nivel de confianza más alto y/o menos grados de libertad (muestra más pequeña) resultan en un valor t más grande y un intervalo más amplio.")
print(f"  - La desviación estándar muestral ({desviacion_estandar_muestral_pizza} minutos), que refleja la variabilidad de nuestra muestra. Una mayor variabilidad muestral conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra_pizza}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza_pizza*100:.0f}% seguros de que el verdadero tiempo promedio de entrega de todas las pizzas se encuentra entre aproximadamente {intervalo_confianza_inferior_pizza:.4f} minutos y {intervalo_confianza_superior_pizza:.4f} minutos.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (20) de entregas de pizza y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran el verdadero tiempo promedio de entrega de la población de pizzas.
# NO significa que haya un 95% de probabilidad de que el verdadero tiempo medio poblacional caiga dentro del intervalo calculado (28.1279 minutos, 31.8721 minutos). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (30 minutos): Es el tiempo promedio de entrega calculado a partir de nuestra muestra específica de 20 entregas. Sirve como nuestra mejor estimación puntual del tiempo promedio real desconocido.
# ...

# %%
# Documentar y organizar la respuesta
print("## Resultados e Interpretación")
print("\n### Resumen del Problema")
print("El objetivo de este ejercicio fue estimar el tiempo promedio de entrega de pizza basándose en una muestra y construir un intervalo de confianza del 95% para el verdadero tiempo medio poblacional de entrega, utilizando la desviación estándar muestral y la distribución t de Student.")

print("\n### Parámetros Clave")
print(f"- Media Muestral: {media_muestral_pizza} minutos (tiempo promedio de una muestra de {tamano_muestra_pizza} entregas)")
print(f"- Desviación Estándar Muestral: {desviacion_estandar_muestral_pizza} minutos (variabilidad observada en la muestra)")
print(f"- Tamaño de la Muestra: {tamano_muestra_pizza} entregas")
print(f"- Nivel de Confianza: {nivel_confianza_pizza*100:.0f}%")
print(f"- Grados de Libertad: {grados_libertad_pizza}")

print("\n### Intervalo de Confianza Calculado")
print(f"El intervalo de confianza del 95% calculado para el tiempo medio poblacional de entrega es: ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos).")

print("\n### Interpretación del Intervalo de Confianza")
print(f"Basándonos en los datos de nuestra muestra, estamos 95% seguros de que el verdadero tiempo promedio de entrega de todas las pizzas se encuentra entre aproximadamente {intervalo_confianza_inferior_pizza:.2f} minutos y {intervalo_confianza_superior_pizza:.2f} minutos.")
print("Este intervalo proporciona un rango de valores plausibles para la media poblacional del tiempo de entrega.")

print("\n### Significado del Nivel de Confianza")
print("El nivel de confianza del 95% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 95% de estos intervalos contuvieran el verdadero tiempo medio poblacional de entrega.")

print("\n### Resumen Final:")
print("\n### Hallazgos Clave del Análisis de Datos")
print(f"* El tiempo promedio de entrega de la muestra de {tamano_muestra_pizza} entregas es de {media_muestral_pizza} minutos.")
print(f"* La desviación estándar muestral es de {desviacion_estandar_muestral_pizza} minutos.")
print("* Se calculó un intervalo de confianza del 95% para el tiempo medio poblacional de entrega utilizando la distribución t de Student.")
print(f"* El intervalo de confianza del 95% calculado es ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos).")
print(f"* El valor crítico t para un nivel de confianza del 95% y {grados_libertad_pizza} grados de libertad es aproximadamente {t_critico_pizza:.4f}.")
print(f"* El error estándar de la media se calculó en aproximadamente {error_estandar_pizza:.4f} minutos.")
print(f"* El margen de error es de aproximadamente {margen_error_pizza:.4f} minutos.")

print("\n### Conclusiones o Próximos Pasos")
print(f"* Basándonos en la muestra, estamos 95% seguros de que el verdadero tiempo promedio de entrega de todas las pizzas se encuentra entre {intervalo_confianza_inferior_pizza:.2f} minutos y {intervalo_confianza_superior_pizza:.2f} minutos.")
print("* Para obtener una estimación más precisa (un intervalo de confianza más estrecho), se podría considerar aumentar el tamaño de la muestra en futuras mediciones.")
# Out:
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar el tiempo promedio de entrega de pizza basándose en una muestra y construir un intervalo de confianza del 95% para el verdadero tiempo medio poblacional de entrega, utilizando la desviación estándar muestral y la distribución t de Student.
#
# ### Parámetros Clave
# - Media Muestral: 30 minutos (tiempo promedio de una muestra de 20 entregas)
# - Desviación Estándar Muestral: 4 minutos (variabilidad observada en la muestra)
# - Tamaño de la Muestra: 20 entregas
# - Nivel de Confianza: 95%
# - Grados de Libertad: 19
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 95% calculado para el tiempo medio poblacional de entrega es: (28.1279 minutos, 31.8721 minutos).
#
# ### Interpretación del Intervalo de Confianza
# ...

# %%
# Documentar y organizar la respuesta
print("## Resultados e Interpretación")
print("\n### Resumen del Problema")
print("El objetivo de este ejercicio fue estimar el tiempo promedio de entrega de pizza basándose en una muestra y construir un intervalo de confianza del 95% para el verdadero tiempo medio poblacional de entrega, utilizando la desviación estándar muestral y la distribución t de Student.")

print("\n### Parámetros Clave")
print(f"- Media Muestral: {media_muestral_pizza} minutos (tiempo promedio de una muestra de {tamano_muestra_pizza} entregas)")
print(f"- Desviación Estándar Muestral: {desviacion_estandar_muestral_pizza} minutos (variabilidad observada en la muestra)")
print(f"- Tamaño de la Muestra: {tamano_muestra_pizza} entregas")
print(f"- Nivel de Confianza: {nivel_confianza_pizza*100:.0f}%")
print(f"- Grados de Libertad: {grados_libertad_pizza}")

print("\n### Intervalo de Confianza Calculado")
print(f"El intervalo de confianza del 95% calculado para el tiempo medio poblacional de entrega es: ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos).")

print("\n### Interpretación del Intervalo de Confianza")
print(f"Basándonos en los datos de nuestra muestra, estamos 95% seguros de que el verdadero tiempo promedio de entrega de todas las pizzas se encuentra entre aproximadamente {intervalo_confianza_inferior_pizza:.2f} minutos y {intervalo_confianza_superior_pizza:.2f} minutos.")
print("Este intervalo proporciona un rango de valores plausibles para la media poblacional del tiempo de entrega.")

print("\n### Significado del Nivel de Confianza")
print("El nivel de confianza del 95% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 95% de estos intervalos contuvieran el verdadero tiempo medio poblacional de entrega.")

print("\n### Resumen Final:")
print("\n### Hallazgos Clave del Análisis de Datos")
print(f"* El tiempo promedio de entrega de la muestra de {tamano_muestra_pizza} entregas es de {media_muestral_pizza} minutos.")
print(f"* La desviación estándar muestral es de {desviacion_estandar_muestral_pizza} minutos.")
print("* Se calculó un intervalo de confianza del 95% para el tiempo medio poblacional de entrega utilizando la distribución t de Student.")
print(f"* El intervalo de confianza del 95% calculado es ({intervalo_confianza_inferior_pizza:.4f} minutos, {intervalo_confianza_superior_pizza:.4f} minutos).")
print(f"* El valor crítico t para un nivel de confianza del 95% y {grados_libertad_pizza} grados de libertad es aproximadamente {t_critico_pizza:.4f}.")
print(f"* El error estándar de la media se calculó en aproximadamente {error_estandar_pizza:.4f} minutos.")
print(f"* El margen de error es de aproximadamente {margen_error_pizza:.4f} minutos.")

print("\n### Conclusiones o Próximos Pasos")
print(f"* Basándonos en la muestra, estamos 95% seguros de que el verdadero tiempo promedio de entrega de todas las pizzas se encuentra entre {intervalo_confianza_inferior_pizza:.2f} minutos y {intervalo_confianza_superior_pizza:.2f} minutos.")
print("* Para obtener una estimación más precisa (un intervalo de confianza más estrecho), se podría considerar aumentar el tamaño de la muestra en futuras mediciones.")
# Out:
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar el tiempo promedio de entrega de pizza basándose en una muestra y construir un intervalo de confianza del 95% para el verdadero tiempo medio poblacional de entrega, utilizando la desviación estándar muestral y la distribución t de Student.
#
# ### Parámetros Clave
# - Media Muestral: 30 minutos (tiempo promedio de una muestra de 20 entregas)
# - Desviación Estándar Muestral: 4 minutos (variabilidad observada en la muestra)
# - Tamaño de la Muestra: 20 entregas
# - Nivel de Confianza: 95%
# - Grados de Libertad: 19
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 95% calculado para el tiempo medio poblacional de entrega es: (28.1279 minutos, 31.8721 minutos).
#
# ### Interpretación del Intervalo de Confianza
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   El tiempo promedio de entrega de la muestra de 20 entregas es de 30 minutos.
# *   La desviación estándar muestral es de 4 minutos.
# *   El valor crítico t para un nivel de confianza del 95% y 19 grados de libertad es aproximadamente 2.0930.
# *   El error estándar de la media se calculó en aproximadamente 0.8944 minutos.
# *   El margen de error es de aproximadamente 1.8721 minutos.
# *   El intervalo de confianza del 95% calculado para el tiempo medio poblacional de entrega es ($28.1279$ minutos, $31.8721$ minutos).
#
# ### Insights or Next Steps
#
# *   Basándonos en la muestra, estamos 95% seguros de que el verdadero tiempo promedio de entrega de todas las pizzas se encuentra entre aproximadamente $28.13$ minutos y $31.87$ minutos.
# *   Para obtener una estimación más precisa (un intervalo de confianza más estrecho), se podría considerar aumentar el tamaño de la muestra en futuras mediciones.

# %%
# Definir los parámetros dados para el ejercicio de los libros de matemáticas
media_muestral_libros = 1.5  # kg
desviacion_estandar_muestral_libros = 0.3  # kg
tamano_muestra_libros = 8  # libros
nivel_confianza_libros = 0.95  # como decimal

# %%
# Calcular el nivel de significancia
# Fórmula: alpha = 1 - nivel_confianza
alpha_libros = 1 - nivel_confianza_libros

# Calcular los grados de libertad
# Fórmula: df = n - 1
grados_libertad_libros = tamano_muestra_libros - 1

# Calcular el valor crítico t
# Para una prueba de dos colas con distribución t, necesitamos el valor t que deja alpha/2 en cada cola.
# Fórmula: t_critico = scipy.stats.t.ppf(1 - alpha / 2, df)
t_critico_libros = scipy.stats.t.ppf(1 - alpha_libros / 2, grados_libertad_libros)

# Calcular el error estándar de la media
# Fórmula: error_estandar = desviacion_estandar_muestral / sqrt(tamano_muestra)
error_estandar_libros = desviacion_estandar_muestral_libros / np.sqrt(tamano_muestra_libros)

# Calcular el margen de error
# Fórmula: margen_error = t_critico * error_estandar
margen_error_libros = t_critico_libros * error_estandar_libros

# Calcular el intervalo de confianza
# Fórmula: Intervalo = media_muestral ± margen_error
intervalo_confianza_inferior_libros = media_muestral_libros - margen_error_libros
intervalo_confianza_superior_libros = media_muestral_libros + margen_error_libros

# Almacenar los límites calculados
intervalo_confianza_libros = (intervalo_confianza_inferior_libros, intervalo_confianza_superior_libros)

# Imprimir los resultados
print(f"Nivel de significancia (alpha): {alpha_libros:.2f}")
print(f"Grados de libertad: {grados_libertad_libros}")
print(f"Valor crítico t: {t_critico_libros:.4f}")
print(f"Error estándar de la media: {error_estandar_libros:.4f}")
print(f"Margen de error: {margen_error_libros:.4f}")
print(f"Intervalo de Confianza (95%): ({intervalo_confianza_inferior_libros:.4f}, {intervalo_confianza_superior_libros:.4f})")
# Out:
# Nivel de significancia (alpha): 0.05
# Grados de libertad: 7
# Valor crítico t: 2.3646
# Error estándar de la media: 0.1061
# Margen de error: 0.2508
# Intervalo de Confianza (95%): (1.2492, 1.7508)

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño ({tamano_muestra_libros}) de libros de matemáticas y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran el verdadero peso promedio de la población de libros de matemáticas.")
print(f"NO significa que haya un 95% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado ({intervalo_confianza_inferior_libros:.4f} kg, {intervalo_confianza_superior_libros:.4f} kg). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo:")
print(f"- Media Muestral ({media_muestral_libros} kg): Es el peso promedio calculado a partir de nuestra muestra específica de {tamano_muestra_libros} libros. Sirve como nuestra mejor estimación puntual del peso promedio real desconocido.")
print(f"- Desviación Estándar Muestral ({desviacion_estandar_muestral_libros} kg): Es una medida de la dispersión o variabilidad de los pesos en nuestra muestra de {tamano_muestra_libros} libros. Aquí usamos la desviación estándar de la muestra porque la desviación estándar de TODA la población es desconocida y el tamaño de la muestra es pequeño.")
print(f"- Tamaño de la Muestra ({tamano_muestra_libros} libros): Es el número de libros incluidos en nuestra muestra. Dado que el tamaño de la muestra es pequeño (menor a 30) y usamos la desviación estándar muestral, aplicamos la distribución t de Student.")
print(f"- Nivel de Confianza ({nivel_confianza_libros*100:.0f}%): El grado de certeza que deseamos tener en que el intervalo contenga la verdadera media poblacional.")
print(f"- Grados de Libertad ({grados_libertad_libros}): Utilizados en la distribución t de Student, son iguales al tamaño de la muestra menos 1 ({tamano_muestra_libros} - 1).")
print(f"- Valor Crítico t ({t_critico_libros:.4f}): El valor de la distribución t que define los límites del intervalo de confianza para un nivel de confianza y grados de libertad dados.")

print("\nCómo estos parámetros contribuyen al Intervalo de Confianza (usando distribución t):")
print("El intervalo de confianza proporciona un rango de valores plausibles para el verdadero peso promedio de la población de libros de matemáticas.")
print(f"El intervalo está centrado alrededor de la media muestral ({media_muestral_libros} kg).")
print("El ancho del intervalo está determinado por el margen de error, que a su vez depende de:")
print(f"  - El nivel de confianza ({nivel_confianza_libros*100:.0f}%) y los grados de libertad ({grados_libertad_libros}), que dictan el valor crítico t ({t_critico_libros:.4f}). Un nivel de confianza más alto y/o menos grados de libertad (muestra más pequeña) resultan en un valor t más grande y un intervalo más amplio.")
print(f"  - La desviación estándar muestral ({desviacion_estandar_muestral_libros} kg), que refleja la variabilidad de nuestra muestra. Una mayor variabilidad muestral conduce a un intervalo más amplio.")
print(f"  - El tamaño de la muestra ({tamano_muestra_libros}), que influye en el error estándar. Un tamaño de muestra mayor reduce el error estándar y, por lo tanto, estrecha el intervalo.")
print(f"El intervalo calculado ({intervalo_confianza_inferior_libros:.4f} kg, {intervalo_confianza_superior_libros:.4f} kg) sugiere que, basándonos en nuestra muestra, estamos {nivel_confianza_libros*100:.0f}% seguros de que el verdadero peso promedio de todos los libros de matemáticas se encuentra entre aproximadamente {intervalo_confianza_inferior_libros:.4f} kg y {intervalo_confianza_superior_libros:.4f} kg.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si tomáramos muchas muestras aleatorias del mismo tamaño (8) de libros de matemáticas y construyéramos un intervalo de confianza para cada muestra, esperaríamos que aproximadamente el 95% de estos intervalos contuvieran el verdadero peso promedio de la población de libros de matemáticas.
# NO significa que haya un 95% de probabilidad de que la verdadera media poblacional caiga dentro del intervalo calculado (1.2492 kg, 1.7508 kg). En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo:
# - Media Muestral (1.5 kg): Es el peso promedio calculado a partir de nuestra muestra específica de 8 libros. Sirve como nuestra mejor estimación puntual del peso promedio real desconocido.
# ...

# %% [markdown]
# **Paso 5: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y la interpretación del intervalo de confianza para el ejercicio de los libros de matemáticas.
#
# ## Resultados e Interpretación
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue estimar el peso promedio real de los libros de matemáticas basándose en una muestra y construir un intervalo de confianza del 95% para la verdadera media poblacional de peso, utilizando la desviación estándar muestral y la distribución t de Student.
#
# ### Parámetros Clave
# - Media Muestral: {media_muestral_libros} kg (peso promedio de una muestra de {tamano_muestra_libros} libros)
# - Desviación Estándar Muestral: {desviacion_estandar_muestral_libros} kg (variabilidad observada en la muestra)
# - Tamaño de la Muestra: {tamano_muestra_libros} libros
# - Nivel de Confianza: {nivel_confianza_libros*100:.0f}%
# - Grados de Libertad: {grados_libertad_libros}
#
# ### Intervalo de Confianza Calculado
# El intervalo de confianza del 95% calculado para la media poblacional de peso es: ({intervalo_confianza_inferior_libros:.4f} kg, {intervalo_confianza_superior_libros:.4f} kg).
#
# ### Interpretación del Intervalo de Confianza
# Basándonos en los datos de nuestra muestra, estamos 95% seguros de que el verdadero peso promedio de todos los libros de matemáticas se encuentra entre aproximadamente {intervalo_confianza_inferior_libros:.2f} kg y {intervalo_confianza_superior_libros:.2f} kg.
# Este intervalo proporciona un rango de valores plausibles para la media poblacional de peso.
#
# ### Significado del Nivel de Confianza
# El nivel de confianza del 95% significa que si repitiéramos este proceso de tomar muestras y calcular intervalos de confianza muchas veces, esperaríamos que alrededor del 95% de estos intervalos contuvieran la verdadera media poblacional de peso.

# %% [markdown]
# **Paso 6: Resumen Final**
#
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * El peso promedio de la muestra de {tamano_muestra_libros} libros de matemáticas es de {media_muestral_libros} kg.
# * La desviación estándar muestral es de {desviacion_estandar_muestral_libros} kg.
# * Se calculó un intervalo de confianza del 95% para la media poblacional de peso utilizando la distribución t de Student.
# * El intervalo de confianza del 95% calculado es ({intervalo_confianza_inferior_libros:.4f} kg, {intervalo_confianza_superior_libros:.4f} kg).
# * El valor crítico t para un nivel de confianza del 95% y {grados_libertad_libros} grados de libertad es aproximadamente {t_critico_libros:.4f}.
# * El error estándar de la media se calculó en aproximadamente {error_estandar_libros:.4f} kg.
# * El margen de error es de aproximadamente {margen_error_libros:.4f} kg.
#
# ### Conclusiones o Próximos Pasos
#
# * Basándonos en la muestra, estamos 95% seguros de que el verdadero peso promedio de todos los libros de matemáticas se encuentra entre {intervalo_confianza_inferior_libros:.2f} kg y {intervalo_confianza_superior_libros:.2f} kg.
# * Para obtener una estimación más precisa (un intervalo de confianza más estrecho), se podría considerar aumentar el tamaño de la muestra en futuras mediciones.

# %% [markdown]
# # Task
# Calcule el tamaño de muestra necesario para estimar una proporción con un margen de error del 3 % y un nivel de confianza del 95 %, considerando dos escenarios: uno con un estudio piloto donde la proporción muestral es del 72 %, y otro sin un estudio piloto. Utilice las fórmulas estándar con explicaciones claras, `scipy.stats` para cálculos estadísticos, comente todo el código, organice y documente las respuestas en español sin graficar.

# %%
# Definir los parámetros dados para el escenario con estudio piloto
proporcion_muestral_piloto = 0.72  # Proporción muestral del estudio piloto (72% como decimal)
margen_error = 0.03  # Margen de error deseado (3% como decimal)
nivel_confianza = 0.95  # Nivel de confianza deseado (95% como decimal)

# %%
# Calcular el valor crítico Z
# Para un nivel de confianza del 95%, necesitamos el valor Z que deja (1 - 0.95) / 2 = 0.025 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)

# Calcular el tamaño de muestra necesario con estudio piloto
# Fórmula: n = (Z_critico^2 * p * (1-p)) / Margen_Error^2
# Donde p es la proporción muestral del estudio piloto
tamano_muestra_piloto = (z_critico**2 * proporcion_muestral_piloto * (1 - proporcion_muestral_piloto)) / (margen_error**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_piloto_redondeado = np.ceil(tamano_muestra_piloto)

# Imprimir los resultados
print(f"Valor crítico Z: {z_critico:.4f}")
print(f"Tamaño de muestra calculado con estudio piloto: {tamano_muestra_piloto:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_piloto_redondeado)}")
# Out:
# Valor crítico Z: 1.9600
# Tamaño de muestra calculado con estudio piloto: 860.4868
# Tamaño de muestra redondeado hacia arriba: 861

# %%
# Explicar el nivel de confianza y parámetros para el escenario con estudio piloto
print("Explicación del Nivel de Confianza y Parámetros (Escenario con Estudio Piloto):")
print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del 95% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 95% de esos intervalos contendrían la verdadera proporción de la población que estamos tratando de estimar.")
print(f"El valor crítico Z asociado ({z_critico:.4f}) se obtiene de la distribución normal estándar y delimita el 95% central del área bajo la curva, dejando el {alpha/2:.2f}% en cada cola.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Proporción Muestral del Estudio Piloto ({proporcion_muestral_piloto*100:.0f}%): Esta es la proporción observada en un estudio preliminar (piloto). La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra inicial. Si no tuviéramos esta información, usaríamos 0.5 como la estimación más conservadora.")
print(f"- Margen de Error Deseado ({margen_error*100:.0f}%): Es la máxima diferencia permitida entre la proporción muestral que obtengamos en el estudio final y la verdadera proporción poblacional. Un margen de error menor requiere un tamaño de muestra más grande.")
print(f"- Nivel de Confianza ({nivel_confianza*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra final contenga la verdadera proporción poblacional. Un nivel de confianza más alto requiere un tamaño de muestra más grande debido a un valor crítico Z mayor.")

print("\nTamaño de Muestra Calculado:")
print(f"Basándonos en un estudio piloto con una proporción del {proporcion_muestral_piloto*100:.0f}%, un margen de error deseado del {margen_error*100:.0f}% y un nivel de confianza del {nivel_confianza*100:.0f}%, el tamaño de muestra calculado es aproximadamente {tamano_muestra_piloto:.4f}. Dado que necesitamos un número entero de unidades de muestra, redondeamos hacia arriba para asegurar que se cumpla el margen de error deseado con el nivel de confianza especificado.")
print(f"El tamaño de muestra mínimo requerido para este escenario es de {int(tamano_muestra_piloto_redondeado)}.")
# Out:
# Explicación del Nivel de Confianza y Parámetros (Escenario con Estudio Piloto):
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 95% de esos intervalos contendrían la verdadera proporción de la población que estamos tratando de estimar.
# El valor crítico Z asociado (1.9600) se obtiene de la distribución normal estándar y delimita el 95% central del área bajo la curva, dejando el 0.03% en cada cola.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# - Proporción Muestral del Estudio Piloto (72%): Esta es la proporción observada en un estudio preliminar (piloto). La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra inicial. Si no tuviéramos esta información, usaríamos 0.5 como la estimación más conservadora.
# ...

# %%
# Definir los parámetros para el escenario sin estudio piloto
# Usamos una proporción conservadora de 0.5 cuando no hay estudio piloto
proporcion_sin_piloto = 0.5  # Proporción conservadora para estimar el tamaño de muestra
margen_error_sin_piloto = 0.03  # Margen de error deseado (3% como decimal)
nivel_confianza_sin_piloto = 0.95  # Nivel de confianza deseado (95% como decimal)

# %%
# Calcular el valor crítico Z (es el mismo que en el escenario anterior ya que el nivel de confianza es el mismo)
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_sin_piloto) / 2)

# Calcular el tamaño de muestra necesario sin estudio piloto
# Fórmula: n = (Z_critico^2 * p * (1-p)) / Margen_Error^2
# Donde p es la proporción conservadora de 0.5
tamano_muestra_sin_piloto = (z_critico**2 * proporcion_sin_piloto * (1 - proporcion_sin_piloto)) / (margen_error_sin_piloto**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_sin_piloto_redondeado = np.ceil(tamano_muestra_sin_piloto)

# Imprimir los resultados
print(f"Valor crítico Z: {z_critico:.4f}")
print(f"Tamaño de muestra calculado sin estudio piloto: {tamano_muestra_sin_piloto:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_sin_piloto_redondeado)}")
# Out:
# Valor crítico Z: 1.9600
# Tamaño de muestra calculado sin estudio piloto: 1067.0719
# Tamaño de muestra redondeado hacia arriba: 1068

# %%
# Explicar el nivel de confianza y parámetros para el escenario sin estudio piloto
print("Explicación del Nivel de Confianza y Parámetros (Escenario sin Estudio Piloto):")
print("\nNivel de Confianza (95%):")
print(f"Al igual que en el escenario anterior, un nivel de confianza del 95% indica que el método utilizado para construir el intervalo de confianza tendrá éxito en capturar la verdadera proporción poblacional el 95% de las veces en muestras repetidas. El valor crítico Z asociado ({z_critico:.4f}) es el mismo.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Proporción Conservadora (0.5): Dado que no disponemos de información previa (como un estudio piloto) sobre la proporción poblacional, utilizamos el valor de 0.5. Este valor maximiza el producto p*(1-p), lo que a su vez resulta en el mayor tamaño de muestra requerido para un margen de error y nivel de confianza dados. Esto asegura que el tamaño de muestra calculado sea suficiente independientemente de la verdadera proporción poblacional.")
print(f"- Margen de Error Deseado ({margen_error_sin_piloto*100:.0f}%): Es el mismo margen de error máximo permitido que en el escenario con estudio piloto.")
print(f"- Nivel de Confianza ({nivel_confianza_sin_piloto*100:.0f}%): Es el mismo nivel de seguridad deseado que en el escenario con estudio piloto.")

print("\nTamaño de Muestra Calculado:")
print(f"En ausencia de un estudio piloto, utilizando una proporción conservadora de 0.5, un margen de error deseado del {margen_error_sin_piloto*100:.0f}% y un nivel de confianza del {nivel_confianza_sin_piloto*100:.0f}%, el tamaño de muestra calculado es aproximadamente {tamano_muestra_sin_piloto:.4f}. Redondeamos hacia arriba para garantizar la precisión.")
print(f"El tamaño de muestra mínimo requerido para este escenario es de {int(tamano_muestra_sin_piloto_redondeado)}.")
# Out:
# Explicación del Nivel de Confianza y Parámetros (Escenario sin Estudio Piloto):
#
# Nivel de Confianza (95%):
# Al igual que en el escenario anterior, un nivel de confianza del 95% indica que el método utilizado para construir el intervalo de confianza tendrá éxito en capturar la verdadera proporción poblacional el 95% de las veces en muestras repetidas. El valor crítico Z asociado (1.9600) es el mismo.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# - Proporción Conservadora (0.5): Dado que no disponemos de información previa (como un estudio piloto) sobre la proporción poblacional, utilizamos el valor de 0.5. Este valor maximiza el producto p*(1-p), lo que a su vez resulta en el mayor tamaño de muestra requerido para un margen de error y nivel de confianza dados. Esto asegura que el tamaño de muestra calculado sea suficiente independientemente de la verdadera proporción poblacional.
# ...

# %%
# Documentar y organizar la respuesta

print("## Resultados y Documentación del Cálculo del Tamaño de Muestra")

print("\n### Resumen del Problema")
print("El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar una proporción poblacional con un margen de error del 3% y un nivel de confianza del 95%, considerando dos escenarios: uno con información de un estudio piloto y otro sin información previa (usando una estimación conservadora).")

print("\n### Parámetros Comunes")
print(f"- Margen de Error Deseado: {margen_error*100:.0f}%")
print(f"- Nivel de Confianza: {nivel_confianza*100:.0f}%")
print(f"- Valor Crítico Z para 95% de Confianza: {z_critico:.4f}")

print("\n### Escenario 1: Con Estudio Piloto")
print("\n#### Parámetros Específicos")
print(f"- Proporción Muestral del Estudio Piloto: {proporcion_muestral_piloto*100:.0f}%")

print("\n#### Hallazgos Clave")
print(f"* Tamaño de muestra calculado: {tamano_muestra_piloto:.4f}")
print(f"* Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_piloto_redondeado)}")

print("\n#### Conclusión")
print(f"Utilizando la información del estudio piloto (proporción muestral del {proporcion_muestral_piloto*100:.0f}%), se requiere un tamaño de muestra mínimo de {int(tamano_muestra_piloto_redondeado)} para estimar la proporción poblacional con un margen de error del {margen_error*100:.0f}% y un nivel de confianza del {nivel_confianza*100:.0f}%.")

print("\n### Escenario 2: Sin Estudio Piloto")
print("\n#### Parámetros Específicos")
print(f"- Proporción Conservadora Utilizada: {proporcion_sin_piloto:.1f}")

print("\n#### Hallazgos Clave")
print(f"* Tamaño de muestra calculado: {tamano_muestra_sin_piloto:.4f}")
print(f"* Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_sin_piloto_redondeado)}")

print("\n#### Conclusión")
print(f"En ausencia de información previa, utilizando la proporción conservadora de 0.5, se requiere un tamaño de muestra mínimo de {int(tamano_muestra_sin_piloto_redondeado)} para estimar la proporción poblacional con un margen de error del {margen_error_sin_piloto*100:.0f}% y un nivel de confianza del {nivel_confianza_sin_piloto*100:.0f}%. Este tamaño de muestra es mayor que el requerido con el estudio piloto, lo cual es esperado ya que el uso de 0.5 proporciona la estimación más conservadora.")

print("\n### Resumen Final Comparativo")
print(f"| Escenario         | Proporción Estimada | Tamaño de Muestra Requerido (Redondeado) |")
print(f"|-------------------|---------------------|------------------------------------------|")
print(f"| Con Estudio Piloto| {proporcion_muestral_piloto:.2f}              | {int(tamano_muestra_piloto_redondeado):<40} |")
print(f"| Sin Estudio Piloto| {proporcion_sin_piloto:.1f}              | {int(tamano_muestra_sin_piloto_redondeado):<40} |")

print("\n#### Conclusión General")
print("La disponibilidad de un estudio piloto que proporciona una estimación de la proporción poblacional puede reducir el tamaño de muestra necesario en comparación con el uso de una estimación conservadora (0.5) cuando no se tiene información previa. Esto puede resultar en ahorros de tiempo y recursos en la recopilación de datos.")
# Out:
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar una proporción poblacional con un margen de error del 3% y un nivel de confianza del 95%, considerando dos escenarios: uno con información de un estudio piloto y otro sin información previa (usando una estimación conservadora).
#
# ### Parámetros Comunes
# - Margen de Error Deseado: 3%
# - Nivel de Confianza: 95%
# - Valor Crítico Z para 95% de Confianza: 1.9600
#
# ### Escenario 1: Con Estudio Piloto
#
# #### Parámetros Específicos
# - Proporción Muestral del Estudio Piloto: 72%
#
# #### Hallazgos Clave
# * Tamaño de muestra calculado: 860.4868
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): 861
#
# #### Conclusión
# ...

# %%
# Documentar y organizar la respuesta

print("## Resultados y Documentación del Cálculo del Tamaño de Muestra")

print("\n### Resumen del Problema")
print("El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar una proporción poblacional con un margen de error del 3% y un nivel de confianza del 95%, considerando dos escenarios: uno con información de un estudio piloto y otro sin información previa (usando una estimación conservadora).")

print("\n### Parámetros Comunes")
print(f"- Margen de Error Deseado: {margen_error*100:.0f}%")
print(f"- Nivel de Confianza: {nivel_confianza*100:.0f}%")
print(f"- Valor Crítico Z para 95% de Confianza: {z_critico:.4f}")

print("\n### Escenario 1: Con Estudio Piloto")
print("\n#### Parámetros Específicos")
print(f"- Proporción Muestral del Estudio Piloto: {proporcion_muestral_piloto*100:.0f}%")

print("\n#### Hallazgos Clave")
print(f"* Tamaño de muestra calculado: {tamano_muestra_piloto:.4f}")
print(f"* Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_piloto_redondeado)}")

print("\n#### Conclusión")
print(f"Utilizando la información del estudio piloto (proporción muestral del {proporcion_muestral_piloto*100:.0f}%), se requiere un tamaño de muestra mínimo de {int(tamano_muestra_piloto_redondeado)} para estimar la proporción poblacional con un margen de error del {margen_error*100:.0f}% y un nivel de confianza del {nivel_confianza*100:.0f}%.")

print("\n### Escenario 2: Sin Estudio Piloto")
print("\n#### Parámetros Específicos")
print(f"- Proporción Conservadora Utilizada: {proporcion_sin_piloto:.1f}")

print("\n#### Hallazgos Clave")
print(f"* Tamaño de muestra calculado: {tamano_muestra_sin_piloto:.4f}")
print(f"* Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_sin_piloto_redondeado)}")

print("\n#### Conclusión")
print(f"En ausencia de información previa, utilizando la proporción conservadora de 0.5, se requiere un tamaño de muestra mínimo de {int(tamano_muestra_sin_piloto_redondeado)} para estimar la proporción poblacional con un margen de error del {margen_error_sin_piloto*100:.0f}% y un nivel de confianza del {nivel_confianza_sin_piloto*100:.0f}%. Este tamaño de muestra es mayor que el requerido con el estudio piloto, lo cual es esperado ya que el uso de 0.5 proporciona la estimación más conservadora.")

print("\n### Resumen Final Comparativo")
print(f"| Escenario         | Proporción Estimada | Tamaño de Muestra Requerido (Redondeado) |")
print(f"|-------------------|---------------------|------------------------------------------|")
print(f"| Con Estudio Piloto| {proporcion_muestral_piloto:.2f}              | {int(tamano_muestra_piloto_redondeado):<40} |")
print(f"| Sin Estudio Piloto| {proporcion_sin_piloto:.1f}              | {int(tamano_muestra_sin_piloto_redondeado):<40} |")

print("\n#### Conclusión General")
print("La disponibilidad de un estudio piloto que proporciona una estimación de la proporción poblacional puede reducir el tamaño de muestra necesario en comparación con el uso de una estimación conservadora (0.5) cuando no se tiene información previa. Esto puede resultar en ahorros de tiempo y recursos en la recopilación de datos.")
# Out:
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar una proporción poblacional con un margen de error del 3% y un nivel de confianza del 95%, considerando dos escenarios: uno con información de un estudio piloto y otro sin información previa (usando una estimación conservadora).
#
# ### Parámetros Comunes
# - Margen de Error Deseado: 3%
# - Nivel de Confianza: 95%
# - Valor Crítico Z para 95% de Confianza: 1.9600
#
# ### Escenario 1: Con Estudio Piloto
#
# #### Parámetros Específicos
# - Proporción Muestral del Estudio Piloto: 72%
#
# #### Hallazgos Clave
# * Tamaño de muestra calculado: 860.4868
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): 861
#
# #### Conclusión
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The critical Z-value for a 95% confidence level is approximately 1.96.
# *   For the scenario with a pilot study (sample proportion of 72%), the calculated sample size is approximately 860.49, requiring a rounded-up sample size of 861.
# *   For the scenario without a pilot study (using a conservative proportion of 0.5), the calculated sample size is approximately 1067.07, requiring a rounded-up sample size of 1068.
#
# ### Insights or Next Steps
#
# *   Having prior information from a pilot study can significantly reduce the required sample size compared to using a conservative estimate when no such information is available.
# *   Researchers should consider conducting a pilot study if feasible, as the information gained about the likely proportion can lead to more efficient resource allocation for the main study.

# %%
# Definir los parámetros dados para el ejercicio de la tasa de devoluciones
proporcion_historica_devoluciones = 0.07  # Proporción histórica de devoluciones (7% como decimal)
margen_error_devoluciones = 0.04  # Margen de error deseado (4% como decimal)
nivel_confianza_devoluciones = 0.90  # Nivel de confianza deseado (90% como decimal)

# %%
# Calcular el valor crítico Z
# Para un nivel de confianza del 90%, necesitamos el valor Z que deja (1 - 0.90) / 2 = 0.05 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico_devoluciones = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_devoluciones) / 2)

# Calcular el tamaño de muestra necesario
# Fórmula: n = (Z_critico^2 * p * (1-p)) / Margen_Error^2
# Donde p es la proporción histórica o estimada
tamano_muestra_devoluciones = (z_critico_devoluciones**2 * proporcion_historica_devoluciones * (1 - proporcion_historica_devoluciones)) / (margen_error_devoluciones**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_devoluciones_redondeado = np.ceil(tamano_muestra_devoluciones)

# Imprimir los resultados
print(f"Valor crítico Z: {z_critico_devoluciones:.4f}")
print(f"Tamaño de muestra calculado: {tamano_muestra_devoluciones:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_devoluciones_redondeado)}")
# Out:
# Valor crítico Z: 1.6449
# Tamaño de muestra calculado: 110.0818
# Tamaño de muestra redondeado hacia arriba: 111

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (90%):")
print(f"Un nivel de confianza del 90% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 90% de esos intervalos contendrían la verdadera proporción de devoluciones.")
print(f"El valor crítico Z asociado ({z_critico_devoluciones:.4f}) se obtiene de la distribución normal estándar y delimita el 90% central del área bajo la curva, dejando el {(1 - nivel_confianza_devoluciones) / 2:.2f}% en cada cola.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Proporción Histórica/Estimada ({proporcion_historica_devoluciones*100:.0f}%): Esta es la proporción de devoluciones basada en datos históricos. La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra.")
print(f"- Margen de Error Deseado ({margen_error_devoluciones*100:.0f}%): Es la máxima diferencia permitida entre la proporción muestral que obtengamos en el estudio final y la verdadera proporción poblacional. Un margen de error menor requiere un tamaño de muestra más grande.")
print(f"- Nivel de Confianza ({nivel_confianza_devoluciones*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra final contenga la verdadera proporción poblacional. Un nivel de confianza más alto requiere un tamaño de muestra más grande debido a un valor crítico Z mayor.")

print("\nTamaño de Muestra Calculado:")
print(f"Basándonos en una proporción histórica de devoluciones del {proporcion_historica_devoluciones*100:.0f}%, un margen de error deseado del {margen_error_devoluciones*100:.0f}% y un nivel de confianza del {nivel_confianza_devoluciones*100:.0f}%, el tamaño de muestra calculado es aproximadamente {tamano_muestra_devoluciones:.4f}. Redondeamos hacia arriba para asegurar que se cumpla el margen de error deseado con el nivel de confianza especificado.")
print(f"El tamaño de muestra mínimo requerido es de {int(tamano_muestra_devoluciones_redondeado)}.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (90%):
# Un nivel de confianza del 90% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 90% de esos intervalos contendrían la verdadera proporción de devoluciones.
# El valor crítico Z asociado (1.6449) se obtiene de la distribución normal estándar y delimita el 90% central del área bajo la curva, dejando el 0.05% en cada cola.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# - Proporción Histórica/Estimada (7%): Esta es la proporción de devoluciones basada en datos históricos. La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra.
# ...

# %% [markdown]
# **Paso 5: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y el resumen.
#
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar la proporción de devoluciones de un producto con un margen de error del 4% y un nivel de confianza del 90%, utilizando una proporción histórica como estimación.
#
# ### Parámetros Clave
# - Proporción Histórica/Estimada: {proporcion_historica_devoluciones*100:.0f}%
# - Margen de Error Deseado: {margen_error_devoluciones*100:.0f}%
# - Nivel de Confianza: {nivel_confianza_devoluciones*100:.0f}%
# - Valor Crítico Z para {nivel_confianza_devoluciones*100:.0f}% de Confianza: {z_critico_devoluciones:.4f}
#
# ### Hallazgos Clave
# * Tamaño de muestra calculado: {tamano_muestra_devoluciones:.4f}
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_devoluciones_redondeado)}
#
# ### Conclusión
# Basándonos en la proporción histórica de devoluciones del {proporcion_historica_devoluciones*100:.0f}%, se requiere un tamaño de muestra mínimo de {int(tamano_muestra_devoluciones_redondeado)} para estimar la proporción de devoluciones con un margen de error del {margen_error_devoluciones*100:.0f}% y un nivel de confianza del {nivel_confianza_devoluciones*100:.0f}%.

# %% [markdown]
# **Paso 6: Resumen Final**
#
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
#
# * La proporción histórica de devoluciones es del {proporcion_historica_devoluciones*100:.0f}%.
# * El margen de error deseado es del {margen_error_devoluciones*100:.0f}%.
# * El nivel de confianza es del {nivel_confianza_devoluciones*100:.0f}%.
# * El valor crítico Z para un nivel de confianza del {nivel_confianza_devoluciones*100:.0f}% es aproximadamente {z_critico_devoluciones:.4f}.
# * El tamaño de muestra calculado es aproximadamente {tamano_muestra_devoluciones:.4f}.
# * El tamaño de muestra mínimo requerido (redondeado hacia arriba) es {int(tamano_muestra_devoluciones_redondeado)}.
#
# ### Conclusiones o Próximos Pasos
#
# * Para estimar la proporción de devoluciones con un margen de error del {margen_error_devoluciones*100:.0f}% y un nivel de confianza del {nivel_confianza_devoluciones*100:.0f}%, se necesita una muestra de al menos {int(tamano_muestra_devoluciones_redondeado)} pedidos.
# * Monitorear continuamente la tasa de devoluciones y reevaluar el tamaño de muestra necesario periódicamente puede ser útil para mantener la precisión de la estimación.

# %%
# Definir los parámetros dados para el primer escenario (con encuesta previa)
proporcion_encuesta_previa = 0.42  # Proporción de apoyo de la encuesta previa (42% como decimal)
margen_error = 0.02  # Margen de error deseado (2% como decimal)
nivel_confianza = 0.99  # Nivel de confianza deseado (99% como decimal)

# %%
# Calcular el valor crítico Z
# Para un nivel de confianza del 99%, necesitamos el valor Z que deja (1 - 0.99) / 2 = 0.005 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)

# Calcular el tamaño de muestra necesario con encuesta previa
# Fórmula: n = (Z_critico^2 * p * (1-p)) / Margen_Error^2
# Donde p es la proporción de la encuesta previa
tamano_muestra_encuesta = (z_critico**2 * proporcion_encuesta_previa * (1 - proporcion_encuesta_previa)) / (margen_error**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_encuesta_redondeado = np.ceil(tamano_muestra_encuesta)

# Imprimir los resultados para el primer escenario
print("Resultados para el escenario con encuesta previa:")
print(f"Valor crítico Z: {z_critico:.4f}")
print(f"Tamaño de muestra calculado con encuesta previa: {tamano_muestra_encuesta:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_encuesta_redondeado)}")
# Out:
# Resultados para el escenario con encuesta previa:
# Valor crítico Z: 2.5758
# Tamaño de muestra calculado con encuesta previa: 4040.6520
# Tamaño de muestra redondeado hacia arriba: 4041

# %%
# Explicar el nivel de confianza y parámetros para el escenario con encuesta previa
print("\nExplicación del Nivel de Confianza y Parámetros (Escenario con Encuesta Previa):")
print("\nNivel de Confianza (99%):")
print(f"Un nivel de confianza del 99% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 99% de esos intervalos contendrían la verdadera proporción de votantes que apoyan al candidato.")
print(f"El valor crítico Z asociado ({z_critico:.4f}) se obtiene de la distribución normal estándar y delimita el 99% central del área bajo la curva, dejando el {(1 - nivel_confianza) / 2:.3f}% en cada cola.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Proporción de la Encuesta Previa ({proporcion_encuesta_previa*100:.0f}%): Esta es la proporción observada en la encuesta preliminar. La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra.")
print(f"- Margen de Error Deseado ({margen_error*100:.0f}%): Es la máxima diferencia permitida entre la proporción muestral que obtengamos en la encuesta final y la verdadera proporción poblacional.")
print(f"- Nivel de Confianza ({nivel_confianza*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra final contenga la verdadera proporción poblacional.")

print("\nTamaño de Muestra Calculado:")
print(f"Basándonos en una encuesta previa con una proporción de apoyo del {proporcion_encuesta_previa*100:.0f}%, un margen de error deseado del {margen_error*100:.0f}% y un nivel de confianza del {nivel_confianza*100:.0f}%, el tamaño de muestra calculado es aproximadamente {tamano_muestra_encuesta:.4f}. Redondeamos hacia arriba para asegurar que se cumpla el margen de error deseado con el nivel de confianza especificado.")
print(f"El tamaño de muestra mínimo requerido para este escenario es de {int(tamano_muestra_encuesta_redondeado)}.")
# Out:
# Explicación del Nivel de Confianza y Parámetros (Escenario con Encuesta Previa):
#
# Nivel de Confianza (99%):
# Un nivel de confianza del 99% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 99% de esos intervalos contendrían la verdadera proporción de votantes que apoyan al candidato.
# El valor crítico Z asociado (2.5758) se obtiene de la distribución normal estándar y delimita el 99% central del área bajo la curva, dejando el 0.005% en cada cola.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# - Proporción de la Encuesta Previa (42%): Esta es la proporción observada en la encuesta preliminar. La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra.
# ...

# %%
# Definir los parámetros para el segundo escenario (sin encuesta previa)
# Usamos una proporción conservadora de 0.5 cuando no hay información previa
proporcion_sin_encuesta = 0.5  # Proporción conservadora para estimar el tamaño de muestra
margen_error_sin_encuesta = 0.02  # Margen de error deseado (2% como decimal)
nivel_confianza_sin_encuesta = 0.99  # Nivel de confianza deseado (99% como decimal)

# %%
# Calcular el valor crítico Z (es el mismo que en el escenario anterior ya que el nivel de confianza es el mismo)
# Fórmula: z_critico_sin_encuesta = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_sin_encuesta) / 2)
z_critico_sin_encuesta = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_sin_encuesta) / 2)


# Calcular el tamaño de muestra necesario sin encuesta previa
# Fórmula: n = (Z_critico^2 * p * (1-p)) / Margen_Error^2
# Donde p es la proporción conservadora de 0.5
tamano_muestra_sin_encuesta = (z_critico_sin_encuesta**2 * proporcion_sin_encuesta * (1 - proporcion_sin_encuesta)) / (margen_error_sin_encuesta**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_sin_encuesta_redondeado = np.ceil(tamano_muestra_sin_encuesta)

# Imprimir los resultados para el segundo escenario
print("\nResultados para el escenario sin encuesta previa:")
print(f"Valor crítico Z: {z_critico_sin_encuesta:.4f}")
print(f"Tamaño de muestra calculado sin encuesta previa: {tamano_muestra_sin_encuesta:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_sin_encuesta_redondeado)}")
# Out:
# Resultados para el escenario sin encuesta previa:
# Valor crítico Z: 2.5758
# Tamaño de muestra calculado sin encuesta previa: 4146.8104
# Tamaño de muestra redondeado hacia arriba: 4147

# %%
# Explicar el nivel de confianza y parámetros para el escenario sin encuesta previa
print("\nExplicación del Nivel de Confianza y Parámetros (Escenario sin Encuesta Previa):")
print("\nNivel de Confianza (99%):")
print(f"Al igual que en el escenario anterior, un nivel de confianza del 99% indica que el método utilizado para construir el intervalo de confianza tendrá éxito en capturar la verdadera proporción poblacional el 99% de las veces en muestras repetidas. El valor crítico Z asociado ({z_critico_sin_encuesta:.4f}) es el mismo.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Proporción Conservadora (0.5): Dado que no disponemos de información previa (como una encuesta) sobre la proporción poblacional, utilizamos el valor de 0.5. Este valor maximiza el producto p*(1-p), lo que a su vez resulta en el mayor tamaño de muestra requerido para un margen de error y nivel de confianza dados. Esto asegura que el tamaño de muestra calculado sea suficiente independientemente de la verdadera proporción poblacional.")
print(f"- Margen de Error Deseado ({margen_error_sin_encuesta*100:.0f}%): Es el mismo margen de error máximo permitido que en el escenario con encuesta previa.")
print(f"- Nivel de Confianza ({nivel_confianza_sin_encuesta*100:.0f}%): Es el mismo nivel de seguridad deseado que en el escenario con encuesta previa.")

print("\nTamaño de Muestra Calculado:")
print(f"En ausencia de una encuesta previa, utilizando una proporción conservadora de 0.5, un margen de error deseado del {margen_error_sin_encuesta*100:.0f}% y un nivel de confianza del {nivel_confianza_sin_encuesta*100:.0f}%, el tamaño de muestra calculado es aproximadamente {tamano_muestra_sin_encuesta:.4f}. Redondeamos hacia arriba para garantizar la precisión.")
print(f"El tamaño de muestra mínimo requerido para este escenario es de {int(tamano_muestra_sin_encuesta_redondeado)}.")
# Out:
# Explicación del Nivel de Confianza y Parámetros (Escenario sin Encuesta Previa):
#
# Nivel de Confianza (99%):
# Al igual que en el escenario anterior, un nivel de confianza del 99% indica que el método utilizado para construir el intervalo de confianza tendrá éxito en capturar la verdadera proporción poblacional el 99% de las veces en muestras repetidas. El valor crítico Z asociado (2.5758) es el mismo.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# - Proporción Conservadora (0.5): Dado que no disponemos de información previa (como una encuesta) sobre la proporción poblacional, utilizamos el valor de 0.5. Este valor maximiza el producto p*(1-p), lo que a su vez resulta en el mayor tamaño de muestra requerido para un margen de error y nivel de confianza dados. Esto asegura que el tamaño de muestra calculado sea suficiente independientemente de la verdadera proporción poblacional.
# ...

# %% [markdown]
# **Paso 8: Resumen Final**
# Comparar los tamaños de muestra calculados para ambos escenarios y resumir los hallazgos clave.
#
# ## Resumen Final: Comparación de Tamaños de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar la proporción de votantes que apoyan a un candidato con un margen de error del 2% y un nivel de confianza del 99%, comparando el resultado con y sin el uso de una encuesta previa que indicaba un 42% de apoyo.
#
# ### Parámetros Comunes
# - Margen de Error Deseado: {margen_error*100:.0f}%
# - Nivel de Confianza: {nivel_confianza*100:.0f}%
# - Valor Crítico Z para {nivel_confianza*100:.0f}% de Confianza: {z_critico:.4f}
#
# ### Escenario 1: Con Encuesta Previa (Proporción estimada = {proporcion_encuesta_previa*100:.0f}%)
# - Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_encuesta_redondeado)}
#
# ### Escenario 2: Sin Encuesta Previa (Proporción conservadora = {proporcion_sin_encuesta:.1f})
# - Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_sin_encuesta_redondeado)}
#
# ### Comparación y Conclusión
#
# | Escenario         | Proporción Estimada | Tamaño de Muestra Requerido (Redondeado) |
# |-------------------|---------------------|------------------------------------------|
# | Con Encuesta Previa| {proporcion_encuesta_previa:.2f}              | {int(tamano_muestra_encuesta_redondeado):<40} |
# | Sin Encuesta Previa| {proporcion_sin_encuesta:.1f}              | {int(tamano_muestra_sin_encuesta_redondeado):<40} |
#
# **Cómo cambia el resultado:**
# Si no se utiliza la encuesta previa y se opta por la proporción conservadora de 0.5, el tamaño de muestra necesario aumenta significativamente. Esto se debe a que 0.5 maximiza la variabilidad posible (p*(1-p)), lo que requiere una muestra más grande para lograr el mismo margen de error y nivel de confianza.
#
# **Conclusión General:**
# Disponer de una estimación previa de la proporción poblacional, aunque sea de una encuesta piloto, puede reducir el tamaño de muestra necesario para lograr una precisión y confianza deseadas. Esto puede ser crucial para optimizar recursos en la planificación de estudios o encuestas.

# %%
# Definir los parámetros dados para el ejercicio de la política escolar
proporcion_encuesta_informal = 0.56  # Proporción de apoyo de la encuesta informal (56% como decimal)
margen_error_politica = 0.05  # Margen de error deseado (5% como decimal)
nivel_confianza_politica = 0.95  # Nivel de confianza deseado (95% como decimal)

# %%
# Calcular el valor crítico Z
# Para un nivel de confianza del 95%, necesitamos el valor Z que deja (1 - 0.95) / 2 = 0.025 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico_politica = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_politica) / 2)

# Calcular el tamaño de muestra necesario con la encuesta informal
# Fórmula: n = (Z_critico^2 * p * (1-p)) / Margen_Error^2
# Donde p es la proporción de la encuesta informal
tamano_muestra_politica = (z_critico_politica**2 * proporcion_encuesta_informal * (1 - proporcion_encuesta_informal)) / (margen_error_politica**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_politica_redondeado = np.ceil(tamano_muestra_politica)

# Imprimir los resultados
print(f"Valor crítico Z: {z_critico_politica:.4f}")
print(f"Tamaño de muestra calculado con encuesta informal: {tamano_muestra_politica:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_politica_redondeado)}")
# Out:
# Valor crítico Z: 1.9600
# Tamaño de muestra calculado con encuesta informal: 378.6142
# Tamaño de muestra redondeado hacia arriba: 379

# %%
print("Explicación del Nivel de Confianza y Parámetros:")
print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del 95% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 95% de esos intervalos contendrían la verdadera proporción de padres que apoyan la nueva política.")
print(f"El valor crítico Z asociado ({z_critico_politica:.4f}) se obtiene de la distribución normal estándar y delimita el 95% central del área bajo la curva, dejando el {(1 - nivel_confianza_politica) / 2:.2f}% en cada cola.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Proporción de la Encuesta Informal ({proporcion_encuesta_informal*100:.0f}%): Esta es la proporción observada en la encuesta informal. La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra.")
print(f"- Margen de Error Deseado ({margen_error_politica*100:.0f}%): Es la máxima diferencia permitida entre la proporción muestral que obtengamos en la encuesta final y la verdadera proporción poblacional. Un margen de error menor requiere un tamaño de muestra más grande.")
print(f"- Nivel de Confianza ({nivel_confianza_politica*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra final contenga la verdadera proporción poblacional.")

print("\nTamaño de Muestra Calculado:")
print(f"Basándonos en una encuesta informal con una proporción de apoyo del {proporcion_encuesta_informal*100:.0f}%, un margen de error deseado del {margen_error_politica*100:.0f}% y un nivel de confianza del {nivel_confianza_politica*100:.0f}%, el tamaño de muestra calculado es aproximadamente {tamano_muestra_politica:.4f}. Redondeamos hacia arriba para asegurar que se cumpla el margen de error deseado con el nivel de confianza especificado.")
print(f"El tamaño de muestra mínimo requerido es de {int(tamano_muestra_politica_redondeado)}.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 95% de esos intervalos contendrían la verdadera proporción de padres que apoyan la nueva política.
# El valor crítico Z asociado (1.9600) se obtiene de la distribución normal estándar y delimita el 95% central del área bajo la curva, dejando el 0.03% en cada cola.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# - Proporción de la Encuesta Informal (56%): Esta es la proporción observada en la encuesta informal. La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra.
# ...

# %%
print("\nJustificación del uso de p = 0.5 sin datos preliminares:")
print("Cuando no se tiene ninguna información preliminar (como una encuesta piloto o datos históricos) sobre la proporción poblacional que se desea estimar, se utiliza un valor de p = 0.5 en la fórmula del tamaño de muestra.")
print("Esto se debe a que el producto p * (1-p) alcanza su valor máximo cuando p = 0.5.  Por ejemplo:")
print("Si p = 0.5, p * (1-p) = 0.5 * 0.5 = 0.25")
print("Si p = 0.1, p * (1-p) = 0.1 * 0.9 = 0.09")
print("Si p = 0.9, p * (1-p) = 0.9 * 0.1 = 0.09")
print("\nDado que el tamaño de muestra es directamente proporcional al producto p * (1-p) en la fórmula, usar p = 0.5 resulta en el tamaño de muestra más grande posible para un margen de error y nivel de confianza dados.")
print("Este enfoque se considera conservador porque garantiza que el tamaño de muestra calculado será suficiente para lograr la precisión y confianza deseadas, *incluso en el peor de los casos* donde la verdadera proporción poblacional esté cerca de 0.5. Si la verdadera proporción poblacional es diferente de 0.5, el tamaño de muestra necesario será menor que el calculado con 0.5, lo que significa que la muestra obtenida será más que adecuada.")
# Out:
# Justificación del uso de p = 0.5 sin datos preliminares:
# Cuando no se tiene ninguna información preliminar (como una encuesta piloto o datos históricos) sobre la proporción poblacional que se desea estimar, se utiliza un valor de p = 0.5 en la fórmula del tamaño de muestra.
# Esto se debe a que el producto p * (1-p) alcanza su valor máximo cuando p = 0.5.  Por ejemplo:
# Si p = 0.5, p * (1-p) = 0.5 * 0.5 = 0.25
# Si p = 0.1, p * (1-p) = 0.1 * 0.9 = 0.09
# Si p = 0.9, p * (1-p) = 0.9 * 0.1 = 0.09
#
# Dado que el tamaño de muestra es directamente proporcional al producto p * (1-p) en la fórmula, usar p = 0.5 resulta en el tamaño de muestra más grande posible para un margen de error y nivel de confianza dados.
# ...

# %% [markdown]
# **Paso 6: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y el resumen.
#
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar la proporción de padres que apoyan una nueva política escolar con un margen de error del 5% y un nivel de confianza del 95%, utilizando una proporción de una encuesta informal como estimación inicial y justificando el uso de p=0.5 en ausencia de datos preliminares.
#
# ### Parámetros Clave
# - Proporción de la Encuesta Informal: {proporcion_encuesta_informal*100:.0f}%
# - Margen de Error Deseado: {margen_error_politica*100:.0f}%
# - Nivel de Confianza: {nivel_confianza_politica*100:.0f}%
# - Valor Crítico Z para {nivel_confianza_politica*100:.0f}% de Confianza: {z_critico_politica:.4f}
#
# ### Hallazgos Clave
# * Tamaño de muestra calculado: {tamano_muestra_politica:.4f}
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_politica_redondeado)}
#
# ### Justificación del uso de p = 0.5 sin datos preliminares
# Cuando no se dispone de datos preliminares sobre la proporción poblacional, se utiliza un valor de p = 0.5 en la fórmula del tamaño de muestra. Esto se debe a que el producto p * (1-p) es máximo cuando p = 0.5, lo que a su vez maximiza el tamaño de muestra calculado. Usar p = 0.5 es un enfoque conservador que garantiza que el tamaño de muestra será suficiente para lograr el margen de error y nivel de confianza deseados, independientemente de cuál sea la verdadera proporción poblacional.
#
# ### Conclusión
# Basándonos en la proporción de apoyo de la encuesta informal del {proporcion_encuesta_informal*100:.0f}%, se requiere un tamaño de muestra mínimo de {int(tamano_muestra_politica_redondeado)} padres para estimar la proporción de apoyo con un margen de error del {margen_error_politica*100:.0f}% y un nivel de confianza del {nivel_confianza_politica*100:.0f}%. En ausencia de datos preliminares, se utilizaría una proporción de 0.5 para obtener el tamaño de muestra máximo conservador.

# %%
# Definir los parámetros dados para el primer escenario (con prueba preliminar)
proporcion_prueba_preliminar = 0.69  # Proporción de mejoría de la prueba preliminar (69% como decimal)
margen_error_hospital = 0.04  # Margen de error deseado (4% como decimal)
nivel_confianza_hospital = 0.95  # Nivel de confianza deseado (95% como decimal)

# %%
# Calcular el valor crítico Z
# Para un nivel de confianza del 95%, necesitamos el valor Z que deja (1 - 0.95) / 2 = 0.025 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico_hospital = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_hospital) / 2)

# Calcular el tamaño de muestra necesario con prueba preliminar
# Fórmula: n = (Z_critico^2 * p * (1-p)) / Margen_Error^2
# Donde p es la proporción de la prueba preliminar
tamano_muestra_hospital = (z_critico_hospital**2 * proporcion_prueba_preliminar * (1 - proporcion_prueba_preliminar)) / (margen_error_hospital**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_hospital_redondeado = np.ceil(tamano_muestra_hospital)

# Imprimir los resultados para el primer escenario
print("Resultados para el escenario con prueba preliminar:")
print(f"Valor crítico Z: {z_critico_hospital:.4f}")
print(f"Tamaño de muestra calculado con prueba preliminar: {tamano_muestra_hospital:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_hospital_redondeado)}")
# Out:
# Resultados para el escenario con prueba preliminar:
# Valor crítico Z: 1.9600
# Tamaño de muestra calculado con prueba preliminar: 513.5550
# Tamaño de muestra redondeado hacia arriba: 514

# %%
# Explicar el nivel de confianza y parámetros para el escenario con prueba preliminar
print("\nExplicación del Nivel de Confianza y Parámetros (Escenario con Prueba Preliminar):")
print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del 95% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 95% de esos intervalos contendrían la verdadera proporción de pacientes que mejoran con el tratamiento.")
print(f"El valor crítico Z asociado ({z_critico_hospital:.4f}) se obtiene de la distribución normal estándar y delimita el 95% central del área bajo la curva, dejando el {(1 - nivel_confianza_hospital) / 2:.2f}% en cada cola.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Proporción de la Prueba Preliminar ({proporcion_prueba_preliminar*100:.0f}%): Esta es la proporción observada en la prueba preliminar. La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra.")
print(f"- Margen de Error Deseado ({margen_error_hospital*100:.0f}%): Es la máxima diferencia permitida entre la proporción muestral que obtengamos en el estudio final y la verdadera proporción poblacional.")
print(f"- Nivel de Confianza ({nivel_confianza_hospital*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra final contenga la verdadera proporción poblacional.")

print("\nTamaño de Muestra Calculado:")
print(f"Basándonos en una prueba preliminar con una proporción de mejoría del {proporcion_prueba_preliminar*100:.0f}%, un margen de error deseado del {margen_error_hospital*100:.0f}% y un nivel de confianza del {nivel_confianza_hospital*100:.0f}%, el tamaño de muestra calculado es aproximadamente {tamano_muestra_hospital:.4f}. Redondeamos hacia arriba para asegurar que se cumpla el margen de error deseado con el nivel de confianza especificado.")
print(f"El tamaño de muestra mínimo requerido para este escenario es de {int(tamano_muestra_hospital_redondeado)}.")
# Out:
# Explicación del Nivel de Confianza y Parámetros (Escenario con Prueba Preliminar):
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si repitiéramos el proceso de seleccionar muestras y construir un intervalo de confianza para la proporción poblacional muchas veces, aproximadamente el 95% de esos intervalos contendrían la verdadera proporción de pacientes que mejoran con el tratamiento.
# El valor crítico Z asociado (1.9600) se obtiene de la distribución normal estándar y delimita el 95% central del área bajo la curva, dejando el 0.03% en cada cola.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# - Proporción de la Prueba Preliminar (69%): Esta es la proporción observada en la prueba preliminar. La usamos como nuestra mejor estimación de la proporción poblacional desconocida (p) para calcular el tamaño de muestra.
# ...

# %%
# Definir los parámetros para el segundo escenario (proporción conservadora)
proporcion_conservadora = 0.5  # Proporción conservadora para estimar el tamaño de muestra
margen_error_conservador = 0.04  # Margen de error deseado (4% como decimal)
nivel_confianza_conservador = 0.95  # Nivel de confianza deseado (95% como decimal)

# %%
# Calcular el valor crítico Z (es el mismo que en el escenario anterior)
z_critico_conservador = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_conservador) / 2)

# Calcular el tamaño de muestra necesario con proporción conservadora
# Fórmula: n = (Z_critico^2 * p * (1-p)) / Margen_Error^2
# Donde p es la proporción conservadora de 0.5
tamano_muestra_conservador = (z_critico_conservador**2 * proporcion_conservadora * (1 - proporcion_conservadora)) / (margen_error_conservador**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_conservador_redondeado = np.ceil(tamano_muestra_conservador)

# Imprimir los resultados para el segundo escenario
print("\nResultados para el escenario con proporción conservadora (p=0.5):")
print(f"Valor crítico Z: {z_critico_conservador:.4f}")
print(f"Tamaño de muestra calculado con proporción conservadora: {tamano_muestra_conservador:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_conservador_redondeado)}")
# Out:
# Resultados para el escenario con proporción conservadora (p=0.5):
# Valor crítico Z: 1.9600
# Tamaño de muestra calculado con proporción conservadora: 600.2279
# Tamaño de muestra redondeado hacia arriba: 601

# %%
print("\nExplicación del Nivel de Confianza y Parámetros (Escenario con Proporción Conservadora):")
print("\nNivel de Confianza (95%):")
print(f"Al igual que en el escenario anterior, un nivel de confianza del 95% indica la fiabilidad del método para capturar la verdadera proporción poblacional en muestras repetidas. El valor crítico Z asociado ({z_critico_conservador:.4f}) es el mismo.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Proporción Conservadora (0.5): Se utiliza cuando no se tiene información previa sobre la proporción poblacional. Este valor maximiza el tamaño de muestra requerido para un margen de error y nivel de confianza dados, asegurando que el tamaño de muestra sea suficiente independientemente de la verdadera proporción.")
print(f"- Margen de Error Deseado ({margen_error_conservador*100:.0f}%): Es el mismo margen de error máximo permitido que en el escenario con la prueba preliminar.")
print(f"- Nivel de Confianza ({nivel_confianza_conservador*100:.0f}%): Es el mismo nivel de seguridad deseado que en el escenario con la prueba preliminar.")

print("\nTamaño de Muestra Calculado:")
print(f"Utilizando una proporción conservadora de 0.5, un margen de error deseado del {margen_error_conservador*100:.0f}% y un nivel de confianza del {nivel_confianza_conservador*100:.0f}%, el tamaño de muestra calculado es aproximadamente {tamano_muestra_conservador:.4f}. Redondeamos hacia arriba para garantizar la precisión.")
print(f"El tamaño de muestra mínimo requerido para este escenario es de {int(tamano_muestra_conservador_redondeado)}.")
# Out:
# Explicación del Nivel de Confianza y Parámetros (Escenario con Proporción Conservadora):
#
# Nivel de Confianza (95%):
# Al igual que en el escenario anterior, un nivel de confianza del 95% indica la fiabilidad del método para capturar la verdadera proporción poblacional en muestras repetidas. El valor crítico Z asociado (1.9600) es el mismo.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# - Proporción Conservadora (0.5): Se utiliza cuando no se tiene información previa sobre la proporción poblacional. Este valor maximiza el tamaño de muestra requerido para un margen de error y nivel de confianza dados, asegurando que el tamaño de muestra sea suficiente independientemente de la verdadera proporción.
# - Margen de Error Deseado (4%): Es el mismo margen de error máximo permitido que en el escenario con la prueba preliminar.
# - Nivel de Confianza (95%): Es el mismo nivel de seguridad deseado que en el escenario con la prueba preliminar.
#
# ...

# %% [markdown]
# **Paso 8: Resumen Final**
# Comparar los tamaños de muestra calculados para ambos escenarios y resumir los hallazgos clave.
#
# ## Resumen Final: Comparación de Tamaños de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar la proporción de pacientes que mejoran con un tratamiento, con un margen de error del 4% y un nivel de confianza del 95%, comparando el resultado con y sin el uso de una prueba preliminar que indicaba un 69% de mejoría, y considerando el caso conservador (p=0.5).
#
# ### Parámetros Comunes
# - Margen de Error Deseado: {margen_error_hospital*100:.0f}%
# - Nivel de Confianza: {nivel_confianza_hospital*100:.0f}%
# - Valor Crítico Z para {nivel_confianza_hospital*100:.0f}% de Confianza: {z_critico_hospital:.4f}
#
# ### Escenario 1: Con Prueba Preliminar (Proporción estimada = {proporcion_prueba_preliminar*100:.0f}%)
# - Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_hospital_redondeado)}
#
# ### Escenario 2: Conservador (Proporción utilizada = 0.5)
# - Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_conservador_redondeado)}
#
# ### Comparación y Conclusión
#
# | Escenario         | Proporción Estimada | Tamaño de Muestra Requerido (Redondeado) |
# |-------------------|---------------------|------------------------------------------|
# | Con Prueba Preliminar| {proporcion_prueba_preliminar:.2f}              | {int(tamano_muestra_hospital_redondeado):<40} |
# | Conservador       | 0.50                | {int(tamano_muestra_conservador_redondeado):<40} |
#
# **Cómo cambia el resultado:**
# Cuando se utiliza la proporción estimada de la prueba preliminar (0.69), el tamaño de muestra necesario es menor que cuando se utiliza la proporción conservadora de 0.5. Esto se debe a que la fórmula del tamaño de muestra es sensible al valor de p*(1-p), que es máximo en 0.5. Al tener una estimación más cercana a los extremos (0 o 1), el producto p*(1-p) es menor, resultando en un tamaño de muestra más pequeño para el mismo margen de error y nivel de confianza.
#
# **Conclusión General:**
# La disponibilidad de una estimación previa de la proporción poblacional (obtenida de una prueba preliminar o estudio piloto) permite un cálculo de tamaño de muestra potencialmente más eficiente (menor tamaño de muestra) en comparación con el uso de la estimación conservadora (p=0.5), la cual garantiza un tamaño de muestra suficiente en el peor de los casos.

# %% [markdown]
# # Task
# Calcular el tamaño de muestra necesario para estimar el tiempo promedio de espera en urgencias de un hospital con un margen de error de 2 minutos y un nivel de confianza del 95%, sabiendo que la desviación estándar poblacional es de 8 minutos. Utilizar fórmulas estándar con explicaciones claras, `scipy.stats` para cálculos estadísticos, comentar todo el código, organizar y documentar las respuestas en español sin graficar.

# %%
import numpy as np
from scipy import stats

# %%
# Definir los parámetros dados para el ejercicio del tiempo de espera
desviacion_estandar_poblacional_espera = 8  # minutos
margen_error_espera = 2  # minutos
nivel_confianza_espera = 0.95  # como decimal

# %%
# Calcular el nivel de significancia (no estrictamente necesario para la fórmula pero buena práctica)
# alpha = 1 - nivel_confianza_espera

# Calcular el valor crítico Z
# Para un nivel de confianza del 95%, necesitamos el valor Z que deja (1 - 0.95) / 2 = 0.025 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico_espera = stats.norm.ppf(1 - (1 - nivel_confianza_espera) / 2)

# Calcular el tamaño de muestra necesario
# Fórmula: n = (Z_critico^2 * desviacion_estandar_poblacional^2) / Margen_Error^2
tamano_muestra_espera = (z_critico_espera**2 * desviacion_estandar_poblacional_espera**2) / (margen_error_espera**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_espera_redondeado = np.ceil(tamano_muestra_espera)

# Imprimir los resultados
print(f"Valor crítico Z: {z_critico_espera:.4f}")
print(f"Tamaño de muestra calculado: {tamano_muestra_espera:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_espera_redondeado)}")
# Out:
# Valor crítico Z: 1.9600
# Tamaño de muestra calculado: 61.4633
# Tamaño de muestra redondeado hacia arriba: 62

# %%
# Documentar y organizar la respuesta
print("## Resultados y Documentación del Cálculo del Tamaño de Muestra")

print("\n### Resumen del Problema")
print("El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar el tiempo promedio de espera en urgencias de un hospital con un margen de error del 2 minutos y un nivel de confianza del 95%, sabiendo que la desviación estándar poblacional es de 8 minutos.")

print("\n### Parámetros Clave")
print(f"- Desviación Estándar Poblacional: {desviacion_estandar_poblacional_espera} minutos")
print(f"- Margen de Error Deseado: {margen_error_espera} minutos")
print(f"- Nivel de Confianza: {nivel_confianza_espera*100:.0f}%")
print(f"- Valor Crítico Z para {nivel_confianza_espera*100:.0f}% de Confianza: {z_critico_espera:.4f}")

print("\n### Hallazgos Clave")
print(f"* Tamaño de muestra calculado: {tamano_muestra_espera:.4f}")
print(f"* Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_espera_redondeado)}")

print("\n### Conclusión")
print(f"Para estimar el tiempo promedio de espera en urgencias con un margen de error de {margen_error_espera} minutos y un nivel de confianza del {nivel_confianza_espera*100:.0f}%, se necesita una muestra de al menos {int(tamano_muestra_espera_redondeado)} pacientes.")

print("\n### Resumen Final:")
print("\n### Hallazgos Clave del Análisis de Datos")
print(f"* La desviación estándar poblacional del tiempo de espera es de {desviacion_estandar_poblacional_espera} minutos.")
print(f"* El margen de error deseado es de {margen_error_espera} minutos.")
print(f"* El nivel de confianza es del {nivel_confianza_espera*100:.0f}%.")
print(f"* El valor crítico Z para un nivel de confianza del {nivel_confianza_espera*100:.0f}% es aproximadamente {z_critico_espera:.4f}.")
print(f"* El tamaño de muestra calculado es aproximadamente {tamano_muestra_espera:.4f}.")
print(f"* El tamaño de muestra mínimo requerido (redondeado hacia arriba) es {int(tamano_muestra_espera_redondeado)}.")

print("\n### Conclusiones o Próximos Pasos")
print(f"* Basándonos en los parámetros dados, se requiere una muestra de al menos {int(tamano_muestra_espera_redondeado)} pacientes para estimar el tiempo promedio de espera en urgencias con la precisión y confianza deseadas.")
print("* Asegurarse de que la muestra sea aleatoria y representativa de la población de pacientes en urgencias es crucial para la validez de la estimación.")
# Out:
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar el tiempo promedio de espera en urgencias de un hospital con un margen de error del 2 minutos y un nivel de confianza del 95%, sabiendo que la desviación estándar poblacional es de 8 minutos.
#
# ### Parámetros Clave
# - Desviación Estándar Poblacional: 8 minutos
# - Margen de Error Deseado: 2 minutos
# - Nivel de Confianza: 95%
# - Valor Crítico Z para 95% de Confianza: 1.9600
#
# ### Hallazgos Clave
# * Tamaño de muestra calculado: 61.4633
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): 62
#
# ### Conclusión
# Para estimar el tiempo promedio de espera en urgencias con un margen de error de 2 minutos y un nivel de confianza del 95%, se necesita una muestra de al menos 62 pacientes.
#
# ### Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
# ...

# %%
# Imprimir explicación del Nivel de Confianza y Parámetros
print("Explicación del Nivel de Confianza y Parámetros:")

print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del {nivel_confianza_espera*100:.0f}% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de pacientes y construir un intervalo de confianza para el tiempo promedio de espera muchas veces, esperaríamos que aproximadamente el {nivel_confianza_espera*100:.0f}% de esos intervalos contuvieran el verdadero tiempo promedio de espera de todos los pacientes en urgencias.")
print(f"NO significa que haya un {nivel_confianza_espera*100:.0f}% de probabilidad de que el verdadero tiempo medio poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional_espera} minutos): Esta es una medida de la dispersión o variabilidad de los tiempos de espera entre TODOS los pacientes en urgencias. Asumimos que este valor es conocido para este ejercicio. Una mayor desviación estándar indica más variabilidad y requiere un tamaño de muestra más grande para lograr la misma precisión.")
print(f"- Margen de Error Deseado ({margen_error_espera} minutos): Es la máxima diferencia aceptable entre el tiempo promedio de espera que obtengamos en nuestra muestra y el verdadero tiempo promedio de espera poblacional. Un margen de error menor requiere un tamaño de muestra más grande.")
print(f"- Nivel de Confianza ({nivel_confianza_espera*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra contenga el verdadero tiempo promedio de espera poblacional. Un nivel de confianza más alto (como el 95% utilizado aquí) requiere un tamaño de muestra más grande debido a un valor crítico Z mayor.")
print(f"- Valor Crítico Z ({z_critico_espera:.4f}): Es un valor de la distribución normal estándar que corresponde al nivel de confianza deseado. Para un nivel de confianza del {nivel_confianza_espera*100:.0f}%, este valor delimita el {nivel_confianza_espera*100:.0f}% central del área bajo la curva, dejando {(1 - nivel_confianza_espera) / 2:.3f} en cada cola. Se utiliza para calcular el margen de error.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de pacientes y construir un intervalo de confianza para el tiempo promedio de espera muchas veces, esperaríamos que aproximadamente el 95% de esos intervalos contuvieran el verdadero tiempo promedio de espera de todos los pacientes en urgencias.
# NO significa que haya un 95% de probabilidad de que el verdadero tiempo medio poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# ...

# %%
# Documentar y organizar la respuesta
print("## Resultados y Documentación del Cálculo del Tamaño de Muestra")

print("\n### Resumen del Problema")
print("El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar el tiempo promedio de espera en urgencias de un hospital con un margen de error del 2 minutos y un nivel de confianza del 95%, sabiendo que la desviación estándar poblacional es de 8 minutos.")

print("\n### Parámetros Clave")
print(f"- Desviación Estándar Poblacional: {desviacion_estandar_poblacional_espera} minutos")
print(f"- Margen de Error Deseado: {margen_error_espera} minutos")
print(f"- Nivel de Confianza: {nivel_confianza_espera*100:.0f}%")
print(f"- Valor Crítico Z para {nivel_confianza_espera*100:.0f}% de Confianza: {z_critico_espera:.4f}")

print("\n### Hallazgos Clave")
print(f"* Tamaño de muestra calculado: {tamano_muestra_espera:.4f}")
print(f"* Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_espera_redondeado)}")

print("\n### Conclusión")
print(f"Para estimar el tiempo promedio de espera en urgencias con un margen de error de {margen_error_espera} minutos y un nivel de confianza del {nivel_confianza_espera*100:.0f}%, se necesita una muestra de al menos {int(tamano_muestra_espera_redondeado)} pacientes.")

print("\n## Resumen Final:")
print("\n### Hallazgos Clave del Análisis de Datos")
print(f"* La desviación estándar poblacional del tiempo de espera es de {desviacion_estandar_poblacional_espera} minutos.")
print(f"* El margen de error deseado es de {margen_error_espera} minutos.")
print(f"* El nivel de confianza es del {nivel_confianza_espera*100:.0f}%.")
print(f"* El valor crítico Z para un nivel de confianza del {nivel_confianza_espera*100:.0f}% es aproximadamente {z_critico_espera:.4f}.")
print(f"* El tamaño de muestra calculado es aproximadamente {tamano_muestra_espera:.4f}.")
print(f"* El tamaño de muestra mínimo requerido (redondeado hacia arriba) es {int(tamano_muestra_espera_redondeado)}.")

print("\n### Conclusiones o Próximos Pasos")
print(f"* Basándonos en los parámetros dados, se requiere una muestra de al menos {int(tamano_muestra_espera_redondeado)} pacientes para estimar el tiempo promedio de espera en urgencias con la precisión y confianza deseadas.")
print("* Asegurarse de que la muestra sea aleatoria y representativa de la población de pacientes en urgencias es crucial para la validez de la estimación.")
# Out:
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar el tiempo promedio de espera en urgencias de un hospital con un margen de error del 2 minutos y un nivel de confianza del 95%, sabiendo que la desviación estándar poblacional es de 8 minutos.
#
# ### Parámetros Clave
# - Desviación Estándar Poblacional: 8 minutos
# - Margen de Error Deseado: 2 minutos
# - Nivel de Confianza: 95%
# - Valor Crítico Z para 95% de Confianza: 1.9600
#
# ### Hallazgos Clave
# * Tamaño de muestra calculado: 61.4633
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): 62
#
# ### Conclusión
# Para estimar el tiempo promedio de espera en urgencias con un margen de error de 2 minutos y un nivel de confianza del 95%, se necesita una muestra de al menos 62 pacientes.
#
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
# ...

# %%
# Documentar y organizar la respuesta
print("## Resultados y Documentación del Cálculo del Tamaño de Muestra")

print("\n### Resumen del Problema")
print("El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar el tiempo promedio de espera en urgencias de un hospital con un margen de error del 2 minutos y un nivel de confianza del 95%, sabiendo que la desviación estándar poblacional es de 8 minutos.")

print("\n### Parámetros Clave")
print(f"- Desviación Estándar Poblacional: {desviacion_estandar_poblacional_espera} minutos")
print(f"- Margen de Error Deseado: {margen_error_espera} minutos")
print(f"- Nivel de Confianza: {nivel_confianza_espera*100:.0f}%")
print(f"- Valor Crítico Z para {nivel_confianza_espera*100:.0f}% de Confianza: {z_critico_espera:.4f}")

print("\n### Hallazgos Clave")
print(f"* Tamaño de muestra calculado: {tamano_muestra_espera:.4f}")
print(f"* Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_espera_redondeado)}")

print("\n### Conclusión")
print(f"Para estimar el tiempo promedio de espera en urgencias con un margen de error de {margen_error_espera} minutos y un nivel de confianza del {nivel_confianza_espera*100:.0f}%, se necesita una muestra de al menos {int(tamano_muestra_espera_redondeado)} pacientes.")

print("\n## Resumen Final:")
print("\n### Hallazgos Clave del Análisis de Datos")
print(f"* La desviación estándar poblacional del tiempo de espera es de {desviacion_estandar_poblacional_espera} minutos.")
print(f"* El margen de error deseado es de {margen_error_espera} minutos.")
print(f"* El nivel de confianza es del {nivel_confianza_espera*100:.0f}%.")
print(f"* El valor crítico Z para un nivel de confianza del {nivel_confianza_espera*100:.0f}% es aproximadamente {z_critico_espera:.4f}.")
print(f"* El tamaño de muestra calculado es aproximadamente {tamano_muestra_espera:.4f}.")
print(f"* El tamaño de muestra mínimo requerido (redondeado hacia arriba) es {int(tamano_muestra_espera_redondeado)}.")

print("\n### Conclusiones o Próximos Pasos")
print(f"* Basándonos en los parámetros dados, se requiere una muestra de al menos {int(tamano_muestra_espera_redondeado)} pacientes para estimar el tiempo promedio de espera en urgencias con la precisión y confianza deseadas.")
print("* Asegurarse de que la muestra sea aleatoria y representativa de la población de pacientes en urgencias es crucial para la validez de la estimación.")
# Out:
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar el tiempo promedio de espera en urgencias de un hospital con un margen de error del 2 minutos y un nivel de confianza del 95%, sabiendo que la desviación estándar poblacional es de 8 minutos.
#
# ### Parámetros Clave
# - Desviación Estándar Poblacional: 8 minutos
# - Margen de Error Deseado: 2 minutos
# - Nivel de Confianza: 95%
# - Valor Crítico Z para 95% de Confianza: 1.9600
#
# ### Hallazgos Clave
# * Tamaño de muestra calculado: 61.4633
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): 62
#
# ### Conclusión
# Para estimar el tiempo promedio de espera en urgencias con un margen de error de 2 minutos y un nivel de confianza del 95%, se necesita una muestra de al menos 62 pacientes.
#
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
# ...

# %%
# Definir los parámetros dados para el ejercicio del consumo eléctrico
desviacion_estandar_poblacional_electrico = 50  # kWh
margen_error_electrico = 10  # kWh
nivel_confianza_electrico = 0.90  # como decimal

# %%
# Calcular el nivel de significancia (no estrictamente necesario para la fórmula pero buena práctica)
# alpha_electrico = 1 - nivel_confianza_electrico

# Calcular el valor crítico Z
# Para un nivel de confianza del 90%, necesitamos el valor Z que deja (1 - 0.90) / 2 = 0.05 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico_electrico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_electrico) / 2)

# Calcular el tamaño de muestra necesario
# Fórmula: n = (Z_critico^2 * desviacion_estandar_poblacional^2) / Margen_Error^2
tamano_muestra_electrico = (z_critico_electrico**2 * desviacion_estandar_poblacional_electrico**2) / (margen_error_electrico**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_electrico_redondeado = np.ceil(tamano_muestra_electrico)

# Imprimir los resultados
print(f"Valor crítico Z: {z_critico_electrico:.4f}")
print(f"Tamaño de muestra calculado: {tamano_muestra_electrico:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_electrico_redondeado)}")
# Out:
# Valor crítico Z: 1.6449
# Tamaño de muestra calculado: 67.6386
# Tamaño de muestra redondeado hacia arriba: 68

# %%
print("Explicación del Nivel de Confianza y Parámetros:")

print("\nNivel de Confianza (90%):")
print(f"Un nivel de confianza del {nivel_confianza_electrico*100:.0f}% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de clientes residenciales y construir un intervalo de confianza para el consumo mensual promedio muchas veces, esperaríamos que aproximadamente el {nivel_confianza_electrico*100:.0f}% de esos intervalos contuvieran el verdadero consumo mensual promedio de todos los clientes residenciales.")
print(f"NO significa que haya un {nivel_confianza_electrico*100:.0f}% de probabilidad de que la verdadera media poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional_electrico} kWh): Esta es una medida de la dispersión o variabilidad del consumo mensual entre TODOS los clientes residenciales. Asumimos que este valor es conocido históricamente para este ejercicio. Una mayor desviación estándar indica más variabilidad y requiere un tamaño de muestra más grande para lograr la misma precisión.")
print(f"- Margen de Error Deseado ({margen_error_electrico} kWh): Es la máxima diferencia aceptable entre el consumo mensual promedio que obtengamos en nuestra muestra y el verdadero consumo mensual promedio poblacional. Un margen de error menor requiere un tamaño de muestra más grande.")
print(f"- Nivel de Confianza ({nivel_confianza_electrico*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra contenga el verdadero consumo mensual promedio poblacional. Un nivel de confianza más alto (como el 90% utilizado aquí) requiere un tamaño de muestra más grande debido a un valor crítico Z mayor.")
print(f"- Valor Crítico Z ({z_critico_electrico:.4f}): Es un valor de la distribución normal estándar que corresponde al nivel de confianza deseado. Para un nivel de confianza del {nivel_confianza_electrico*100:.0f}%, este valor delimita el {nivel_confianza_electrico*100:.0f}% central del área bajo la curva, dejando {(1 - nivel_confianza_electrico) / 2:.2f} en cada cola. Se utiliza para calcular el margen de error.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (90%):
# Un nivel de confianza del 90% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de clientes residenciales y construir un intervalo de confianza para el consumo mensual promedio muchas veces, esperaríamos que aproximadamente el 90% de esos intervalos contuvieran el verdadero consumo mensual promedio de todos los clientes residenciales.
# NO significa que haya un 90% de probabilidad de que la verdadera media poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# ...

# %% [markdown]
# **Paso 5: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y el resumen.
#
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar el consumo mensual promedio de electricidad de los clientes residenciales con un margen de error de 10 kWh y un nivel de confianza del 90%, sabiendo que la desviación estándar poblacional es de 50 kWh.
#
# ### Parámetros Clave
# - Desviación Estándar Poblacional: {desviacion_estandar_poblacional_electrico} kWh
# - Margen de Error Deseado: {margen_error_electrico} kWh
# - Nivel de Confianza: {nivel_confianza_electrico*100:.0f}%
# - Valor Crítico Z para {nivel_confianza_electrico*100:.0f}% de Confianza: {z_critico_electrico:.4f}
#
# ### Hallazgos Clave
# * Tamaño de muestra calculado: {tamano_muestra_electrico:.4f}
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_electrico_redondeado)}
#
# ### Conclusión
# Para estimar el consumo mensual promedio de electricidad con un margen de error de {margen_error_electrico} kWh y un nivel de confianza del {nivel_confianza_electrico*100:.0f}%, se necesita una muestra de al menos {int(tamano_muestra_electrico_redondeado)} clientes residenciales.
#
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
# * La desviación estándar poblacional del consumo eléctrico es de {desviacion_estandar_poblacional_electrico} kWh.
# * El margen de error deseado es de {margen_error_electrico} kWh.
# * El nivel de confianza es del {nivel_confianza_electrico*100:.0f}%.
# * El valor crítico Z para un nivel de confianza del {nivel_confianza_electrico*100:.0f}% es aproximadamente {z_critico_electrico:.4f}.
# * El tamaño de muestra calculado es aproximadamente {tamano_muestra_electrico:.4f}.
# * El tamaño de muestra mínimo requerido (redondeado hacia arriba) es {int(tamano_muestra_electrico_redondeado)}.
#
# ### Conclusiones o Próximos Pasos
# * Basándonos en los parámetros dados, se requiere una muestra de al menos {int(tamano_muestra_electrico_redondeado)} clientes residenciales para estimar el consumo mensual promedio con la precisión y confianza deseadas.
# * Asegurarse de que la muestra sea aleatoria y representativa de la población de clientes es crucial para la validez de la estimación.

# %%
# Definir los parámetros dados para el ejercicio del peso de paquetes
desviacion_estandar_poblacional_paquetes = 1.2  # kg
margen_error_paquetes = 0.5  # kg
nivel_confianza_paquetes = 0.99  # como decimal

# %%
# Calcular el nivel de significancia (no estrictamente necesario para la fórmula pero buena práctica)
# alpha_paquetes = 1 - nivel_confianza_paquetes

# Calcular el valor crítico Z
# Para un nivel de confianza del 99%, necesitamos el valor Z que deja (1 - 0.99) / 2 = 0.005 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico_paquetes = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_paquetes) / 2)

# Calcular el tamaño de muestra necesario
# Fórmula: n = (Z_critico^2 * desviacion_estandar_poblacional^2) / Margen_Error^2
tamano_muestra_paquetes = (z_critico_paquetes**2 * desviacion_estandar_poblacional_paquetes**2) / (margen_error_paquetes**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_paquetes_redondeado = np.ceil(tamano_muestra_paquetes)

# Imprimir los resultados
print(f"Valor crítico Z: {z_critico_paquetes:.4f}")
print(f"Tamaño de muestra calculado: {tamano_muestra_paquetes:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_paquetes_redondeado)}")
# Out:
# Valor crítico Z: 2.5758
# Tamaño de muestra calculado: 38.2170
# Tamaño de muestra redondeado hacia arriba: 39

# %%
print("Explicación del Nivel de Confianza y Parámetros:")

print("\nNivel de Confianza (99%):")
print(f"Un nivel de confianza del {nivel_confianza_paquetes*100:.0f}% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de paquetes y construir un intervalo de confianza para el peso promedio muchas veces, esperaríamos que aproximadamente el {nivel_confianza_paquetes*100:.0f}% de esos intervalos contuvieran el verdadero peso promedio de todos los paquetes.")
print(f"NO significa que haya un {nivel_confianza_paquetes*100:.0f}% de probabilidad de que la verdadera media poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional_paquetes} kg): Esta es una medida de la dispersión o variabilidad del peso entre TODOS los paquetes. Asumimos que este valor es conocido históricamente para este ejercicio. Una mayor desviación estándar indica más variabilidad y requiere un tamaño de muestra más grande para lograr la misma precisión.")
print(f"- Margen de Error Deseado ({margen_error_paquetes} kg): Es la máxima diferencia aceptable entre el peso promedio que obtengamos en nuestra muestra y el verdadero peso promedio poblacional. Un margen de error menor requiere un tamaño de muestra más grande.")
print(f"- Nivel de Confianza ({nivel_confianza_paquetes*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra contenga el verdadero peso promedio poblacional. Un nivel de confianza más alto (como el 99% utilizado aquí) requiere un tamaño de muestra más grande debido a un valor crítico Z mayor.")
print(f"- Valor Crítico Z ({z_critico_paquetes:.4f}): Es un valor de la distribución normal estándar que corresponde al nivel de confianza deseado. Para un nivel de confianza del {nivel_confianza_paquetes*100:.0f}%, este valor delimita el {nivel_confianza_paquetes*100:.0f}% central del área bajo la curva, dejando {(1 - nivel_confianza_paquetes) / 2:.3f} en cada cola. Se utiliza para calcular el margen de error.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (99%):
# Un nivel de confianza del 99% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de paquetes y construir un intervalo de confianza para el peso promedio muchas veces, esperaríamos que aproximadamente el 99% de esos intervalos contuvieran el verdadero peso promedio de todos los paquetes.
# NO significa que haya un 99% de probabilidad de que la verdadera media poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# ...

# %% [markdown]
# **Paso 5: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y el resumen.
#
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar el peso promedio de los paquetes transportados con un margen de error de 0.5 kg y un nivel de confianza del 99%, sabiendo que la desviación estándar poblacional es de 1.2 kg.
#
# ### Parámetros Clave
# - Desviación Estándar Poblacional: {desviacion_estandar_poblacional_paquetes} kg
# - Margen de Error Deseado: {margen_error_paquetes} kg
# - Nivel de Confianza: {nivel_confianza_paquetes*100:.0f}%
# - Valor Crítico Z para {nivel_confianza_paquetes*100:.0f}% de Confianza: {z_critico_paquetes:.4f}
#
# ### Hallazgos Clave
# * Tamaño de muestra calculado: {tamano_muestra_paquetes:.4f}
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_paquetes_redondeado)}
#
# ### Conclusión
# Para estimar el peso promedio de los paquetes con un margen de error de {margen_error_paquetes} kg y un nivel de confianza del {nivel_confianza_paquetes*100:.0f}%, se necesita una muestra de al menos {int(tamano_muestra_paquetes_redondeado)} paquetes.
#
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
# * La desviación estándar poblacional del peso de los paquetes es de {desviacion_estandar_poblacional_paquetes} kg.
# * El margen de error deseado es de {margen_error_paquetes} kg.
# * El nivel de confianza es del {nivel_confianza_paquetes*100:.0f}%.
# * El valor crítico Z para un nivel de confianza del {nivel_confianza_paquetes*100:.0f}% es aproximadamente {z_critico_paquetes:.4f}.
# * El tamaño de muestra calculado es aproximadamente {tamano_muestra_paquetes:.4f}.
# * El tamaño de muestra mínimo requerido (redondeado hacia arriba) es {int(tamano_muestra_paquetes_redondeado)}.
#
# ### Conclusiones o Próximos Pasos
# * Basándonos en los parámetros dados, se requiere una muestra de al menos {int(tamano_muestra_paquetes_redondeado)} paquetes para estimar el peso promedio con la precisión y confianza deseadas.
# * Asegurarse de que la muestra sea aleatoria y representativa de la población de paquetes es crucial para la validez de la estimación.

# %%
# Definir los parámetros dados para el ejercicio de la duración de reuniones
desviacion_estandar_poblacional_reuniones = 5  # minutos
margen_error_reuniones = 1.5  # minutos
nivel_confianza_reuniones = 0.95  # como decimal

# %%
# Calcular el nivel de significancia (no estrictamente necesario para la fórmula pero buena práctica)
# alpha_reuniones = 1 - nivel_confianza_reuniones

# Calcular el valor crítico Z
# Para un nivel de confianza del 95%, necesitamos el valor Z que deja (1 - 0.95) / 2 = 0.025 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico_reuniones = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_reuniones) / 2)

# Calcular el tamaño de muestra necesario
# Fórmula: n = (Z_critico^2 * desviacion_estandar_poblacional^2) / Margen_Error^2
tamano_muestra_reuniones = (z_critico_reuniones**2 * desviacion_estandar_poblacional_reuniones**2) / (margen_error_reuniones**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_reuniones_redondeado = np.ceil(tamano_muestra_reuniones)

# Imprimir los resultados
print(f"Valor crítico Z: {z_critico_reuniones:.4f}")
print(f"Tamaño de muestra calculado: {tamano_muestra_reuniones:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_reuniones_redondeado)}")
# Out:
# Valor crítico Z: 1.9600
# Tamaño de muestra calculado: 42.6829
# Tamaño de muestra redondeado hacia arriba: 43

# %%
print("Explicación del Nivel de Confianza y Parámetros:")

print("\nNivel de Confianza (95%):")
print(f"Un nivel de confianza del {nivel_confianza_reuniones*100:.0f}% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de reuniones y construir un intervalo de confianza para la duración promedio muchas veces, esperaríamos que aproximadamente el {nivel_confianza_reuniones*100:.0f}% de esos intervalos contuvieran la verdadera duración promedio de todas las reuniones.")
print(f"NO significa que haya un {nivel_confianza_reuniones*100:.0f}% de probabilidad de que la verdadera media poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional_reuniones} minutos): Esta es una medida de la dispersión o variabilidad de la duración entre TODAS las reuniones. Asumimos que este valor es conocido para este ejercicio. Una mayor desviación estándar indica más variabilidad y requiere un tamaño de muestra más grande para lograr la misma precisión.")
print(f"- Margen de Error Deseado ({margen_error_reuniones} minutos): Es la máxima diferencia aceptable entre la duración promedio que obtengamos en nuestra muestra y la verdadera duración promedio poblacional. Un margen de error menor requiere un tamaño de muestra más grande.")
print(f"- Nivel de Confianza ({nivel_confianza_reuniones*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra contenga el verdadero duración promedio poblacional. Un nivel de confianza más alto (como el 95% utilizado aquí) requiere un tamaño de muestra más grande debido a un valor crítico Z mayor.")
print(f"- Valor Crítico Z ({z_critico_reuniones:.4f}): Es un valor de la distribución normal estándar que corresponde al nivel de confianza deseado. Para un nivel de confianza del {nivel_confianza_reuniones*100:.0f}%, este valor delimita el {nivel_confianza_reuniones*100:.0f}% central del área bajo la curva, dejando {(1 - nivel_confianza_reuniones) / 2:.3f} en cada cola. Se utiliza para calcular el margen de error.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (95%):
# Un nivel de confianza del 95% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de reuniones y construir un intervalo de confianza para la duración promedio muchas veces, esperaríamos que aproximadamente el 95% de esos intervalos contuvieran la verdadera duración promedio de todas las reuniones.
# NO significa que haya un 95% de probabilidad de que la verdadera media poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# ...

# %% [markdown]
# **Paso 5: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y el resumen.
#
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar la duración promedio de las reuniones en una empresa con un margen de error de 1.5 minutos y un nivel de confianza del 95%, sabiendo que la desviación estándar poblacional es de 5 minutos.
#
# ### Parámetros Clave
# - Desviación Estándar Poblacional: {desviacion_estandar_poblacional_reuniones} minutos
# - Margen de Error Deseado: {margen_error_reuniones} minutos
# - Nivel de Confianza: {nivel_confianza_reuniones*100:.0f}%
# - Valor Crítico Z para {nivel_confianza_reuniones*100:.0f}% de Confianza: {z_critico_reuniones:.4f}
#
# ### Hallazgos Clave
# * Tamaño de muestra calculado: {tamano_muestra_reuniones:.4f}
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_reuniones_redondeado)}
#
# ### Conclusión
# Para estimar la duración promedio de las reuniones con un margen de error de {margen_error_reuniones} minutos y un nivel de confianza del {nivel_confianza_reuniones*100:.0f}%, se necesita una muestra de al menos {int(tamano_muestra_reuniones_redondeado)} reuniones.
#
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
# * La desviación estándar poblacional de la duración de las reuniones es de {desviacion_estandar_poblacional_reuniones} minutos.
# * El margen de error deseado es de {margen_error_reuniones} minutos.
# * El nivel de confianza es del {nivel_confianza_reuniones*100:.0f}%.
# * El valor crítico Z para un nivel de confianza del {nivel_confianza_reuniones*100:.0f}% es aproximadamente {z_critico_reuniones:.4f}.
# * El tamaño de muestra calculado es aproximadamente {tamano_muestra_reuniones:.4f}.
# * El tamaño de muestra mínimo requerido (redondeado hacia arriba) es {int(tamano_muestra_reuniones_redondeado)}.
#
# ### Conclusiones o Próximos Pasos
# * Basándonos en los parámetros dados, se requiere una muestra de al menos {int(tamano_muestra_reuniones_redondeado)} reuniones para estimar la duración promedio con la precisión y confianza deseadas.
# * Asegurarse de que la muestra sea aleatoria y representativa de la población de reuniones es crucial para la validez de la estimación.

# %%
# Definir los parámetros dados para el ejercicio del puntaje del examen
desviacion_estandar_poblacional_examen = 12  # puntos
margen_error_examen = 3  # puntos
nivel_confianza_examen = 0.90  # como decimal

# %%
# Calcular el nivel de significancia (no estrictamente necesario para la fórmula pero buena práctica)
# alpha_examen = 1 - nivel_confianza_examen

# Calcular el valor crítico Z
# Para un nivel de confianza del 90%, necesitamos el valor Z que deja (1 - 0.90) / 2 = 0.05 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - (1 - nivel_confianza) / 2)
z_critico_examen = scipy.stats.norm.ppf(1 - (1 - nivel_confianza_examen) / 2)

# Calcular el tamaño de muestra necesario
# Fórmula: n = (Z_critico^2 * desviacion_estandar_poblacional^2) / Margen_Error^2
tamano_muestra_examen = (z_critico_examen**2 * desviacion_estandar_poblacional_examen**2) / (margen_error_examen**2)

# Dado que el tamaño de la muestra debe ser un número entero, redondeamos hacia arriba
tamano_muestra_examen_redondeado = np.ceil(tamano_muestra_examen)

# Imprimir los resultados
print(f"Valor crítico Z: {z_critico_examen:.4f}")
print(f"Tamaño de muestra calculado: {tamano_muestra_examen:.4f}")
print(f"Tamaño de muestra redondeado hacia arriba: {int(tamano_muestra_examen_redondeado)}")
# Out:
# Valor crítico Z: 1.6449
# Tamaño de muestra calculado: 43.2887
# Tamaño de muestra redondeado hacia arriba: 44

# %%
print("Explicación del Nivel de Confianza y Parámetros:")

print("\nNivel de Confianza (90%):")
print(f"Un nivel de confianza del {nivel_confianza_examen*100:.0f}% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de estudiantes y construir un intervalo de confianza para el puntaje promedio del examen muchas veces, esperaríamos que aproximadamente el {nivel_confianza_examen*100:.0f}% de esos intervalos contuvieran el verdadero puntaje promedio de todos los estudiantes que tomaron el examen estandarizado.")
print(f"NO significa que haya un {nivel_confianza_examen*100:.0f}% de probabilidad de que la verdadera media poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.")

print("\nParámetros Utilizados en el Cálculo del Tamaño de Muestra:")
print(f"- Desviación Estándar Poblacional ({desviacion_estandar_poblacional_examen} puntos): Esta es una medida de la dispersión o variabilidad de los puntajes del examen entre TODOS los estudiantes en la población. Asumimos que este valor es conocido históricamente para este ejercicio. Una mayor desviación estándar indica más variabilidad y requiere un tamaño de muestra más grande para lograr la misma precisión.")
print(f"- Margen de Error Deseado ({margen_error_examen} puntos): Es la máxima diferencia aceptable entre el puntaje promedio que obtengamos en nuestra muestra y el verdadero puntaje promedio poblacional. Un margen de error menor requiere un tamaño de muestra más grande.")
print(f"- Nivel de Confianza ({nivel_confianza_examen*100:.0f}%): Es el grado de seguridad que queremos tener en que el intervalo de confianza construido a partir de la muestra contenga el verdadero puntaje promedio poblacional. Un nivel de confianza más alto (como el 90% utilizado aquí) requiere un tamaño de muestra más grande debido a un valor crítico Z mayor.")
print(f"- Valor Crítico Z ({z_critico_examen:.4f}): Es un valor de la distribución normal estándar que corresponde al nivel de confianza deseado. Para un nivel de confianza del {nivel_confianza_examen*100:.0f}%, este valor delimita el {nivel_confianza_examen*100:.0f}% central del área bajo la curva, dejando {(1 - nivel_confianza_examen) / 2:.2f} en cada cola. Se utiliza para calcular el margen de error.")
# Out:
# Explicación del Nivel de Confianza y Parámetros:
#
# Nivel de Confianza (90%):
# Un nivel de confianza del 90% significa que si repitiéramos el proceso de seleccionar muestras aleatorias de estudiantes y construir un intervalo de confianza para el puntaje promedio del examen muchas veces, esperaríamos que aproximadamente el 90% de esos intervalos contuvieran el verdadero puntaje promedio de todos los estudiantes que tomaron el examen estandarizado.
# NO significa que haya un 90% de probabilidad de que la verdadera media poblacional caiga dentro de un intervalo calculado específico. En cambio, refleja la fiabilidad del método de estimación a lo largo de muchas muestras repetidas.
#
# Parámetros Utilizados en el Cálculo del Tamaño de Muestra:
# ...

# %% [markdown]
# **Paso 5: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo el código, explicaciones y el resumen.
#
# ## Resultados y Documentación del Cálculo del Tamaño de Muestra
#
# ### Resumen del Problema
# El objetivo de este ejercicio fue calcular el tamaño de muestra necesario para estimar el puntaje promedio de un examen estandarizado con un margen de error de 3 puntos y un nivel de confianza del 90%, sabiendo que la desviación estándar poblacional es de 12 puntos.
#
# ### Parámetros Clave
# - Desviación Estándar Poblacional: {desviacion_estandar_poblacional_examen} puntos
# - Margen de Error Deseado: {margen_error_examen} puntos
# - Nivel de Confianza: {nivel_confianza_examen*100:.0f}%
# - Valor Crítico Z para {nivel_confianza_examen*100:.0f}% de Confianza: {z_critico_examen:.4f}
#
# ### Hallazgos Clave
# * Tamaño de muestra calculado: {tamano_muestra_examen:.4f}
# * Tamaño de muestra mínimo requerido (redondeado hacia arriba): {int(tamano_muestra_examen_redondeado)}
#
# ### Conclusión
# Para estimar el puntaje promedio del examen estandarizado con un margen de error de {margen_error_examen} puntos y un nivel de confianza del {nivel_confianza_examen*100:.0f}%, se necesita una muestra de al menos {int(tamano_muestra_examen_redondeado)} estudiantes.
#
# ## Resumen Final:
#
# ### Hallazgos Clave del Análisis de Datos
# * La desviación estándar poblacional de los puntajes del examen es de {desviacion_estandar_poblacional_examen} puntos.
# * El margen de error deseado es de {margen_error_examen} puntos.
# * El nivel de confianza es del {nivel_confianza_examen*100:.0f}%.
# * El valor crítico Z para un nivel de confianza del {nivel_confianza_examen*100:.0f}% es aproximadamente {z_critico_examen:.4f}.
# * El tamaño de muestra calculado es aproximadamente {tamano_muestra_examen:.4f}.
# * El tamaño de muestra mínimo requerido (redondeado hacia arriba) es {int(tamano_muestra_examen_redondeado)}.
#
# ### Conclusiones o Próximos Pasos
# * Basándonos en los parámetros dados, se requiere una muestra de al menos {int(tamano_muestra_examen_redondeado)} estudiantes para estimar el puntaje promedio del examen con la precisión y confianza deseadas.
# * Asegurarse de que la muestra sea aleatoria y representativa de la población de estudiantes es crucial para la validez de la estimación.

# %% [markdown]
# # Task
# Realiza un análisis de hipótesis para determinar si el peso promedio de los paquetes de cereal es menor a 500 g, utilizando una muestra de 40 paquetes con una media de 495 g y una desviación estándar poblacional de 15 g, con un nivel de significancia de 0.05. Incluye el planteamiento de hipótesis, cálculo del estadístico Z, determinación de la región crítica y conclusión, utilizando scipy.stats y graficando los resultados.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que el peso promedio poblacional es igual o mayor a 500 g.
# H0: μ >= 500 g
# La hipótesis alternativa (H1) es que el peso promedio poblacional es menor a 500 g.
# H1: μ < 500 g

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): El peso promedio de los paquetes de cereal es igual o mayor a 500 g (μ >= 500)")
print("Hipótesis Alternativa (H1): El peso promedio de los paquetes de cereal es menor a 500 g (μ < 500)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): El peso promedio de los paquetes de cereal es igual o mayor a 500 g (μ >= 500)
# Hipótesis Alternativa (H1): El peso promedio de los paquetes de cereal es menor a 500 g (μ < 500)

# %%
# Asignar los parámetros dados
media_poblacional_h0 = 500  # Media poblacional hipotetizada (g)
media_muestral = 495  # Media muestral observada (g)
desviacion_estandar_poblacional = 15  # Desviación estándar poblacional (g)
tamano_muestra = 40  # Tamaño de la muestra (paquetes)
nivel_significancia = 0.05  # Nivel de significancia

print(f"Media poblacional hipotetizada (H0): {media_poblacional_h0} g")
print(f"Media muestral: {media_muestral} g")
print(f"Desviación estándar poblacional: {desviacion_estandar_poblacional} g")
print(f"Tamaño de la muestra: {tamano_muestra} paquetes")
print(f"Nivel de significancia: {nivel_significancia}")
# Out:
# Media poblacional hipotetizada (H0): 500 g
# Media muestral: 495 g
# Desviación estándar poblacional: 15 g
# Tamaño de la muestra: 40 paquetes
# Nivel de significancia: 0.05

# %%
# Calcular el error estándar de la media
# Fórmula: Error Estándar = Desviación Estándar Poblacional / sqrt(Tamaño de la Muestra)
error_estandar = desviacion_estandar_poblacional / np.sqrt(tamano_muestra)

# Calcular el estadístico de prueba Z
# Fórmula: Z = (Media Muestral - Media Poblacional H0) / Error Estándar
z_estadistico = (media_muestral - media_poblacional_h0) / error_estandar

print(f"Error estándar de la media: {error_estandar:.4f}")
print(f"Estadístico de prueba Z: {z_estadistico:.4f}")
# Out:
# Error estándar de la media: 2.3717
# Estadístico de prueba Z: -2.1082

# %%
# Determinar el valor crítico Z para una prueba de cola izquierda
# Para un nivel de significancia alpha, el valor crítico Z es el valor Z tal que P(Z < z_critico) = alpha
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(nivel_significancia)
z_critical = stats.norm.ppf(nivel_significancia)

# Definir la región crítica
# Para una prueba de cola izquierda, la región crítica son todos los valores de Z menores que el valor crítico Z.
# Región Crítica: Z < z_critico

print(f"Valor crítico Z (para alpha={nivel_significancia}): {z_critical:.4f}")
print(f"Región Crítica: Z < {z_critical:.4f}")
# Out:
# Valor crítico Z (para alpha=0.05): -1.6449
# Región Crítica: Z < -1.6449

# %%
# Comparar el estadístico de prueba Z con el valor crítico Z
# Si Z_estadistico < z_critico, rechazamos la hipótesis nula.
# Si Z_estadistico >= z_critico, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if z_estadistico < z_critical:
    print(f"El estadístico de prueba Z ({z_estadistico:.4f}) es menor que el valor crítico Z ({z_critical:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print("Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de 0.05, para concluir que el peso promedio de los paquetes de cereal es menor a 500 g.")
else:
    print(f"El estadístico de prueba Z ({z_estadistico:.4f}) es mayor o igual que el valor crítico Z ({z_critical:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print("Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de 0.05, para concluir que el peso promedio de los paquetes de cereal es menor a 500 g.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba Z (-2.1082) es menor que el valor crítico Z (-1.6449).
# Por lo tanto, rechazamos la hipótesis nula (H0).
# Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de 0.05, para concluir que el peso promedio de los paquetes de cereal es menor a 500 g.

# %%
# Graficar la distribución normal estándar
plt.figure(figsize=(10, 6))
x = np.linspace(-4, 4, 1000)
plt.plot(x, stats.norm.pdf(x, 0, 1), label='Distribución Normal Estándar (Z)')

# Rellenar la región crítica (cola izquierda)
x_critical = np.linspace(-4, z_critical, 1000)
plt.fill_between(x_critical, 0, stats.norm.pdf(x_critical, 0, 1), color='red', alpha=0.5, label='Región Crítica (alpha=0.05)')

# Marcar el valor crítico Z
plt.axvline(z_critical, color='red', linestyle='--', label=f'Valor Crítico Z = {z_critical:.4f}')

# Marcar el estadístico de prueba Z
plt.axvline(z_estadistico, color='green', linestyle='-', label=f'Estadístico Z = {z_estadistico:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para el Peso Promedio del Cereal (Prueba de Cola Izquierda)')
plt.xlabel('Valor Z')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Documentar y organizar la respuesta

print("## Resultados de la Prueba de Hipótesis")

print("\n### Planteamiento de Hipótesis")
print("Hipótesis Nula (H0): El peso promedio de los paquetes de cereal es igual o mayor a 500 g (μ >= 500)")
print("Hipótesis Alternativa (H1): El peso promedio de los paquetes de cereal es menor a 500 g (μ < 500)")

print("\n### Parámetros Utilizados")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0} g")
print(f"- Media muestral: {media_muestral} g")
print(f"- Desviación estándar poblacional: {desviacion_estandar_poblacional} g")
print(f"- Tamaño de la muestra: {tamano_muestra} paquetes")
print(f"- Nivel de significancia (alpha): {nivel_significancia}")

print("\n### Cálculos Clave")
print(f"- Error estándar de la media: {error_estandar:.4f}")
print(f"- Estadístico de prueba Z: {z_estadistico:.4f}")
print(f"- Valor crítico Z (para alpha={nivel_significancia}): {z_critical:.4f}")
print(f"- Región Crítica: Z < {z_critical:.4f}")

print("\n### Decisión y Conclusión")
if z_estadistico < z_critical:
    print(f"El estadístico de prueba Z ({z_estadistico:.4f}) cae en la región crítica (es menor que el valor crítico Z de {z_critical:.4f}).")
    print("Por lo tanto, **rechazamos la hipótesis nula (H0)**.")
    print("Conclusión: Con un nivel de significancia de 0.05, hay suficiente evidencia estadística para concluir que el peso promedio de los paquetes de cereal es **menor a 500 g**.")
else:
    print(f"El estadístico de prueba Z ({z_estadistico:.4f}) no cae en la región crítica (es mayor o igual que el valor crítico Z de {z_critical:.4f}).")
    print("Por lo tanto, **no rechazamos la hipótesis nula (H0)**.")
    print("Conclusión: Con un nivel de significancia de 0.05, no hay suficiente evidencia estadística para concluir que el peso promedio de los paquetes de cereal es menor a 500 g.")

print("\n### Visualización")
print("El gráfico anterior ilustra la distribución normal estándar, la región crítica en la cola izquierda y la posición del estadístico de prueba Z en relación con el valor crítico.")
# Out:
# ## Resultados de la Prueba de Hipótesis
#
# ### Planteamiento de Hipótesis
# Hipótesis Nula (H0): El peso promedio de los paquetes de cereal es igual o mayor a 500 g (μ >= 500)
# Hipótesis Alternativa (H1): El peso promedio de los paquetes de cereal es menor a 500 g (μ < 500)
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): 500 g
# - Media muestral: 495 g
# - Desviación estándar poblacional: 15 g
# - Tamaño de la muestra: 40 paquetes
# - Nivel de significancia (alpha): 0.05
#
# ### Cálculos Clave
# - Error estándar de la media: 2.3717
# - Estadístico de prueba Z: -2.1082
# - Valor crítico Z (para alpha=0.05): -1.6449
# - Región Crítica: Z < -1.6449
#
# ### Decisión y Conclusión
# El estadístico de prueba Z (-2.1082) cae en la región crítica (es menor que el valor crítico Z de -1.6449).
# Por lo tanto, **rechazamos la hipótesis nula (H0)**.
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The null hypothesis ($H_0$) was stated as the average weight being equal to or greater than 500 g ($ \mu \ge 500$), and the alternative hypothesis ($H_1$) was that the average weight is less than 500 g ($ \mu < 500$).
# *   The calculated Z-statistic for the sample is -2.1082.
# *   For a significance level of 0.05 in a left-tailed test, the critical Z-value is -1.6449.
# *   The critical region for rejecting the null hypothesis is when the Z-statistic is less than -1.6449.
# *   Since the calculated Z-statistic of -2.1082 is less than the critical Z-value of -1.6449, it falls within the critical region.
#
# ### Insights or Next Steps
#
# *   Based on the analysis, there is sufficient statistical evidence at the 0.05 significance level to conclude that the average weight of the cereal packages is less than 500 g.

# %%
# Importar las librerías necesarias
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que la duración promedio poblacional es igual o mayor a 1200 horas.
# H0: μ >= 1200 horas
# La hipótesis alternativa (H1) es que la duración promedio poblacional es menor a 1200 horas.
# H1: μ < 1200 horas

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): La duración promedio de las baterías es igual o mayor a 1200 horas (μ >= 1200)")
print("Hipótesis Alternativa (H1): La duración promedio de las baterías es menor a 1200 horas (μ < 1200)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): La duración promedio de las baterías es igual o mayor a 1200 horas (μ >= 1200)
# Hipótesis Alternativa (H1): La duración promedio de las baterías es menor a 1200 horas (μ < 1200)

# %%
# Asignar los parámetros dados
media_poblacional_h0_baterias = 1200  # Media poblacional hipotetizada (horas)
media_muestral_baterias = 1180  # Media muestral observada (horas)
desviacion_estandar_poblacional_baterias = 100  # Desviación estándar poblacional (horas)
tamano_muestra_baterias = 50  # Tamaño de la muestra (baterías)
nivel_significancia_baterias = 0.01  # Nivel de significancia

print(f"Media poblacional hipotetizada (H0): {media_poblacional_h0_baterias} horas")
print(f"Media muestral: {media_muestral_baterias} horas")
print(f"Desviación estándar poblacional: {desviacion_estandar_poblacional_baterias} horas")
print(f"Tamaño de la muestra: {tamano_muestra_baterias} baterías")
print(f"Nivel de significancia: {nivel_significancia_baterias}")
# Out:
# Media poblacional hipotetizada (H0): 1200 horas
# Media muestral: 1180 horas
# Desviación estándar poblacional: 100 horas
# Tamaño de la muestra: 50 baterías
# Nivel de significancia: 0.01

# %%
# Calcular el error estándar de la media
# Fórmula: Error Estándar = Desviación Estándar Poblacional / sqrt(Tamaño de la Muestra)
error_estandar_baterias = desviacion_estandar_poblacional_baterias / np.sqrt(tamano_muestra_baterias)

# Calcular el estadístico de prueba Z
# Fórmula: Z = (Media Muestral - Media Poblacional H0) / Error Estándar
z_estadistico_baterias = (media_muestral_baterias - media_poblacional_h0_baterias) / error_estandar_baterias

print(f"Error estándar de la media: {error_estandar_baterias:.4f}")
print(f"Estadístico de prueba Z: {z_estadistico_baterias:.4f}")
# Out:
# Error estándar de la media: 14.1421
# Estadístico de prueba Z: -1.4142

# %%
# Determinar el valor crítico Z para una prueba de cola izquierda
# Para un nivel de significancia alpha, el valor crítico Z es el valor Z tal que P(Z < z_critico) = alpha
# Usamos scipy.stats.norm.ppf para encontrar este valor.
# Fórmula: z_critico = scipy.stats.norm.ppf(nivel_significancia)
z_critical_baterias = scipy.stats.norm.ppf(nivel_significancia_baterias)

# Definir la región crítica
# Para una prueba de cola izquierda, la región crítica son todos los valores de Z menores que el valor crítico Z.
# Región Crítica: Z < z_critico

print(f"Valor crítico Z (para alpha={nivel_significancia_baterias}): {z_critical_baterias:.4f}")
print(f"Región Crítica: Z < {z_critical_baterias:.4f}")
# Out:
# Valor crítico Z (para alpha=0.01): -2.3263
# Región Crítica: Z < -2.3263

# %%
# Graficar la distribución normal estándar
plt.figure(figsize=(10, 6))
x = np.linspace(-4, 4, 1000)
plt.plot(x, scipy.stats.norm.pdf(x, 0, 1), label='Distribución Normal Estándar (Z)')

# Rellenar la región crítica (cola izquierda)
x_critical_baterias = np.linspace(-4, z_critical_baterias, 1000)
plt.fill_between(x_critical_baterias, 0, scipy.stats.norm.pdf(x_critical_baterias, 0, 1), color='red', alpha=0.5, label=f'Región Crítica (alpha={nivel_significancia_baterias})')

# Marcar el valor crítico Z
plt.axvline(z_critical_baterias, color='red', linestyle='--', label=f'Valor Crítico Z = {z_critical_baterias:.4f}')

# Marcar el estadístico de prueba Z
plt.axvline(z_estadistico_baterias, color='green', linestyle='-', label=f'Estadístico Z = {z_estadistico_baterias:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para la Duración Promedio de las Baterías (Prueba de Cola Izquierda)')
plt.xlabel('Valor Z')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparar el estadístico de prueba Z con el valor crítico Z
# Si Z_estadistico < z_critico, rechazamos la hipótesis nula.
# Si Z_estadistico >= z_critico, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if z_estadistico_baterias < z_critical_baterias:
    print(f"El estadístico de prueba Z ({z_estadistico_baterias:.4f}) es menor que el valor crítico Z ({z_critical_baterias:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_baterias}, para concluir que la duración promedio de las baterías es menor a {media_poblacional_h0_baterias} horas.")
else:
    print(f"El estadístico de prueba Z ({z_estadistico_baterias:.4f}) es mayor o igual que el valor crítico Z ({z_critical_baterias:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_baterias}, para concluir que la duración promedio de las baterías es menor a {media_poblacional_h0_baterias} horas.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba Z (-1.4142) es mayor o igual que el valor crítico Z (-2.3263).
# Por lo tanto, no rechazamos la hipótesis nula (H0).
# Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de 0.01, para concluir que la duración promedio de las baterías es menor a 1200 horas.

# %% [markdown]
# **Paso 8: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo las hipótesis, parámetros, cálculos, la decisión y la conclusión.
#
# ## Resultados de la Prueba de Hipótesis
#
# ### Planteamiento de Hipótesis
# Hipótesis Nula (H0): La duración promedio de las baterías es igual o mayor a 1200 horas (μ >= 1200)
# Hipótesis Alternativa (H1): La duración promedio de las baterías es menor a 1200 horas (μ < 1200)
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): {media_poblacional_h0_baterias} horas
# - Media muestral: {media_muestral_baterias} horas
# - Desviación estándar poblacional: {desviacion_estandar_poblacional_baterias} horas
# - Tamaño de la muestra: {tamano_muestra_baterias} baterías
# - Nivel de significancia (alpha): {nivel_significancia_baterias}
#
# ### Cálculos Clave
# - Error estándar de la media: {error_estandar_baterias:.4f}
# - Estadístico de prueba Z: {z_estadistico_baterias:.4f}
# - Valor crítico Z (para alpha={nivel_significancia_baterias}): {z_critical_baterias:.4f}
# - Región Crítica: Z < {z_critical_baterias:.4f}
#
# ### Decisión y Conclusión
# Según el análisis, el estadístico de prueba Z ({z_estadistico_baterias:.4f}) se compara con el valor crítico Z ({z_critical_baterias:.4f}) para el nivel de significancia de {nivel_significancia_baterias}.
# Dado que {z_estadistico_baterias:.4f} es menor que {z_critical_baterias:.4f}, el estadístico de prueba cae en la región crítica.
# Por lo tanto, **rechazamos la hipótesis nula (H0)**.
# Conclusión: Con un nivel de significancia de {nivel_significancia_baterias}, hay suficiente evidencia estadística para concluir que la duración promedio de las baterías es **menor a {media_poblacional_h0_baterias} horas**.
#
# ### Visualización
# El gráfico anterior ilustra la distribución normal estándar, la región crítica en la cola izquierda y la posición del estadístico de prueba Z en relación con el valor crítico.

# %%
# Importar las librerías necesarias
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que el promedio de la clase es igual al promedio nacional.
# H0: μ = 75 puntos
# La hipótesis alternativa (H1) es que el promedio de la clase es diferente al promedio nacional.
# H1: μ != 75 puntos

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): El promedio de la clase es igual al promedio nacional (μ = 75)")
print("Hipótesis Alternativa (H1): El promedio de la clase es diferente al promedio nacional (μ != 75)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): El promedio de la clase es igual al promedio nacional (μ = 75)
# Hipótesis Alternativa (H1): El promedio de la clase es diferente al promedio nacional (μ != 75)

# %%
# Asignar los parámetros dados
media_poblacional_h0_clase = 75  # Media poblacional hipotetizada (promedio nacional)
media_muestral_clase = 78  # Media muestral observada (promedio de la clase)
desviacion_estandar_poblacional_clase = 12  # Desviación estándar poblacional
tamano_muestra_clase = 36  # Tamaño de la muestra (estudiantes)
nivel_significancia_clase = 0.05  # Nivel de significancia

print(f"Media poblacional hipotetizada (H0): {media_poblacional_h0_clase} puntos")
print(f"Media muestral: {media_muestral_clase} puntos")
print(f"Desviación estándar poblacional: {desviacion_estandar_poblacional_clase} puntos")
print(f"Tamaño de la muestra: {tamano_muestra_clase} estudiantes")
print(f"Nivel de significancia (alpha): {nivel_significancia_clase}")
# Out:
# Media poblacional hipotetizada (H0): 75 puntos
# Media muestral: 78 puntos
# Desviación estándar poblacional: 12 puntos
# Tamaño de la muestra: 36 estudiantes
# Nivel de significancia (alpha): 0.05

# %%
# Calcular el error estándar de la media
# Fórmula: Error Estándar = Desviación Estándar Poblacional / sqrt(Tamaño de la Muestra)
error_estandar_clase = desviacion_estandar_poblacional_clase / np.sqrt(tamano_muestra_clase)

# Calcular el estadístico de prueba Z
# Fórmula: Z = (Media Muestral - Media Poblacional H0) / Error Estándar
z_estadistico_clase = (media_muestral_clase - media_poblacional_h0_clase) / error_estandar_clase

print(f"Error estándar de la media: {error_estandar_clase:.4f}")
print(f"Estadístico de prueba Z: {z_estadistico_clase:.4f}")
# Out:
# Error estándar de la media: 2.0000
# Estadístico de prueba Z: 1.5000

# %%
# Determinar los valores críticos Z para una prueba de dos colas
# Para un nivel de significancia alpha, necesitamos el valor Z que deja alpha/2 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar estos valores.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - alpha / 2) para la cola derecha
# Y -z_critico para la cola izquierda
z_critical_clase_derecha = scipy.stats.norm.ppf(1 - nivel_significancia_clase / 2)
z_critical_clase_izquierda = -z_critical_clase_derecha

# Definir la región crítica
# Para una prueba de dos colas, la región crítica son todos los valores de Z menores que -z_critico O mayores que +z_critico.
# Región Crítica: Z < -z_critico O Z > +z_critico

print(f"Valores críticos Z (para alpha={nivel_significancia_clase}): ±{z_critical_clase_derecha:.4f}")
print(f"Región Crítica: Z < {z_critical_clase_izquierda:.4f} O Z > {z_critical_clase_derecha:.4f}")
# Out:
# Valores críticos Z (para alpha=0.05): ±1.9600
# Región Crítica: Z < -1.9600 O Z > 1.9600

# %%
# Graficar la distribución normal estándar
plt.figure(figsize=(10, 6))
x = np.linspace(-4, 4, 1000)
plt.plot(x, scipy.stats.norm.pdf(x, 0, 1), label='Distribución Normal Estándar (Z)')

# Rellenar la región crítica (colas izquierda y derecha)
x_critical_izquierda = np.linspace(-4, z_critical_clase_izquierda, 1000)
plt.fill_between(x_critical_izquierda, 0, scipy.stats.norm.pdf(x_critical_izquierda, 0, 1), color='red', alpha=0.5, label=f'Región Crítica (alpha/2 = {nivel_significancia_clase/2:.3f})')

x_critical_derecha = np.linspace(z_critical_clase_derecha, 4, 1000)
plt.fill_between(x_critical_derecha, 0, scipy.stats.norm.pdf(x_critical_derecha, 0, 1), color='red', alpha=0.5)


# Marcar los valores críticos Z
plt.axvline(z_critical_clase_izquierda, color='red', linestyle='--', label=f'Valores Críticos Z = ±{z_critical_clase_derecha:.4f}')
plt.axvline(z_critical_clase_derecha, color='red', linestyle='--')


# Marcar el estadístico de prueba Z
plt.axvline(z_estadistico_clase, color='green', linestyle='-', label=f'Estadístico Z = {z_estadistico_clase:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para el Puntaje Promedio de la Clase (Prueba de Dos Colas)')
plt.xlabel('Valor Z')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparar el estadístico de prueba Z con los valores críticos Z
# Si Z_estadistico < -z_critico O Z_estadistico > +z_critico, rechazamos la hipótesis nula.
# De lo contrario, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if z_estadistico_clase < z_critical_clase_izquierda or z_estadistico_clase > z_critical_clase_derecha:
    print(f"El estadístico de prueba Z ({z_estadistico_clase:.4f}) cae en la región crítica (es menor que {z_critical_clase_izquierda:.4f} o mayor que {z_critical_clase_derecha:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_clase}, para concluir que el promedio de la clase en el examen nacional es diferente a {media_poblacional_h0_clase} puntos.")
else:
    print(f"El estadístico de prueba Z ({z_estadistico_clase:.4f}) no cae en la región crítica (está entre {z_critical_clase_izquierda:.4f} y {z_critical_clase_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_clase}, para concluir que el promedio de la clase en el examen nacional es diferente a {media_poblacional_h0_clase} puntos.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba Z (1.5000) no cae en la región crítica (está entre -1.9600 y 1.9600).
# Por lo tanto, no rechazamos la hipótesis nula (H0).
# Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de 0.05, para concluir que el promedio de la clase en el examen nacional es diferente a 75 puntos.

# %% [markdown]
# **Paso 8: Documentar y organizar la respuesta**
# Presentar los resultados de manera clara, incluyendo las hipótesis, parámetros, cálculos, la decisión y la conclusión.
#
# ## Resultados de la Prueba de Hipótesis
#
# ### Planteamiento de Hipótesis
# Hipótesis Nula (H0): El promedio de la clase en el examen nacional es igual al promedio nacional de {media_poblacional_h0_clase} puntos (μ = {media_poblacional_h0_clase})
# Hipótesis Alternativa (H1): El promedio de la clase en el examen nacional es diferente al promedio nacional de {media_poblacional_h0_clase} puntos (μ != {media_poblacional_h0_clase})
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): {media_poblacional_h0_clase} puntos
# - Media muestral: {media_muestral_clase} puntos
# - Desviación estándar poblacional: {desviacion_estandar_poblacional_clase} puntos
# - Tamaño de la muestra: {tamano_muestra_clase} estudiantes
# - Nivel de significancia (alpha): {nivel_significancia_clase}
#
# ### Cálculos Clave
# - Error estándar de la media: {error_estandar_clase:.4f}
# - Estadístico de prueba Z: {z_estadistico_clase:.4f}
# - Valores críticos Z (para alpha={nivel_significancia_clase}): ±{z_critical_clase_derecha:.4f}
# - Región Crítica: Z < {z_critical_clase_izquierda:.4f} O Z > {z_critical_clase_derecha:.4f}
#
# ### Decisión y Conclusión
# Según el análisis, el estadístico de prueba Z ({z_estadistico_clase:.4f}) se compara con los valores críticos Z (±{z_critical_clase_derecha:.4f}) para el nivel de significancia de {nivel_significancia_clase}.
# Dado que |{z_estadistico_clase:.4f}| ({abs(z_estadistico_clase):.4f}) es mayor que el valor crítico Z ({z_critical_clase_derecha:.4f}) (o el estadístico Z cae fuera del rango [-{z_critical_clase_derecha:.4f}, {z_critical_clase_derecha:.4f}]), el estadístico de prueba cae en la región crítica.
# Por lo tanto, **rechazamos la hipótesis nula (H0)**.
# Conclusión: Con un nivel de significancia de {nivel_significancia_clase}, hay suficiente evidencia estadística para concluir que el promedio de la clase en el examen nacional es **diferente a {media_poblacional_h0_clase} puntos**.
#
# ### Visualización
# El gráfico anterior ilustra la distribución normal estándar, la región crítica en ambas colas y la posición del estadístico de prueba Z en relación con los valores críticos.

# %% [markdown]
# # Task
# Realiza una prueba de hipótesis Z para una muestra para determinar si la reducción promedio de la presión arterial de un medicamento es significativamente diferente de 10 mmHg, dado que una muestra de 25 pacientes mostró una reducción promedio de 8 mmHg con una desviación estándar poblacional de 3 mmHg, utilizando un nivel de significancia de 0.05. Incluye el planteamiento de hipótesis, cálculo del estadístico Z, determinación de la región crítica y conclusión, todo en español, con comentarios en el código, usando scipy.stats y graficando los resultados.

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que la reducción promedio de la presión arterial es igual a 10 mmHg.
# H0: μ = 10 mmHg
# La hipótesis alternativa (H1) es que la reducción promedio de la presión arterial es diferente de 10 mmHg.
# H1: μ != 10 mmHg

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): La reducción promedio de la presión arterial es igual a 10 mmHg (μ = 10)")
print("Hipótesis Alternativa (H1): La reducción promedio de la presión arterial es diferente de 10 mmHg (μ != 10)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): La reducción promedio de la presión arterial es igual a 10 mmHg (μ = 10)
# Hipótesis Alternativa (H1): La reducción promedio de la presión arterial es diferente de 10 mmHg (μ != 10)

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# Asignar los parámetros dados
media_poblacional_h0_presion = 10  # Media poblacional hipotetizada (mmHg)
media_muestral_presion = 8  # Media muestral observada (mmHg)
desviacion_estandar_poblacional_presion = 3  # Desviación estándar poblacional (mmHg)
tamano_muestra_presion = 25  # Tamaño de la muestra (pacientes)
nivel_significancia_presion = 0.05  # Nivel de significancia

print(f"\nParámetros Utilizados:")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_presion} mmHg")
print(f"- Media muestral: {media_muestral_presion} mmHg")
print(f"- Desviación estándar poblacional: {desviacion_estandar_poblacional_presion} mmHg")
print(f"- Tamaño de la muestra: {tamano_muestra_presion} pacientes")
print(f"- Nivel de significancia (alpha): {nivel_significancia_presion}")

# Calcular el error estándar de la media
# Fórmula: Error Estándar = Desviación Estándar Poblacional / sqrt(Tamaño de la Muestra)
error_estandar_presion = desviacion_estandar_poblacional_presion / np.sqrt(tamano_muestra_presion)

# Calcular el estadístico de prueba Z
# Fórmula: Z = (Media Muestral - Media Poblacional H0) / Error Estándar
z_estadistico_presion = (media_muestral_presion - media_poblacional_h0_presion) / error_estandar_presion

print(f"\nCálculos Clave:")
print(f"- Error estándar de la media: {error_estandar_presion:.4f}")
print(f"- Estadístico de prueba Z: {z_estadistico_presion:.4f}")

# Determinar los valores críticos Z para una prueba de dos colas
# Para un nivel de significancia alpha, necesitamos el valor Z que deja alpha/2 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar estos valores.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - alpha / 2) para la cola derecha
# Y -z_critico para la cola izquierda
z_critical_presion_derecha = scipy.stats.norm.ppf(1 - nivel_significancia_presion / 2)
z_critical_presion_izquierda = -z_critical_presion_derecha

# Definir la región crítica
# Para una prueba de dos colas, la región crítica son todos los valores de Z menores que -z_critico O mayores que +z_critico.
# Región Crítica: Z < -z_critico O Z > +z_critico

print(f"- Valores críticos Z (para alpha={nivel_significancia_presion}): ±{z_critical_presion_derecha:.4f}")
print(f"- Región Crítica: Z < {z_critical_presion_izquierda:.4f} O Z > {z_critical_presion_derecha:.4f}")

# Comparar el estadístico de prueba Z con los valores críticos Z
# Si Z_estadistico < -z_critico O Z_estadistico > +z_critico, rechazamos la hipótesis nula.
# De lo contrario, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if z_estadistico_presion < z_critical_presion_izquierda or z_estadistico_presion > z_critical_presion_derecha:
    print(f"El estadístico de prueba Z ({z_estadistico_presion:.4f}) cae en la región crítica (es menor que {z_critical_presion_izquierda:.4f} o mayor que {z_critical_presion_derecha:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_presion}, para concluir que la reducción promedio de la presión arterial del medicamento es significativamente diferente de {media_poblacional_h0_presion} mmHg.")
else:
    print(f"El estadístico de prueba Z ({z_estadistico_presion:.4f}) no cae en la región crítica (está entre {z_critical_presion_izquierda:.4f} y {z_critical_presion_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_presion}, para concluir que la reducción promedio de la presión arterial del medicamento es significativamente diferente de {media_poblacional_h0_presion} mmHg.")
# Out:
# Parámetros Utilizados:
# - Media poblacional hipotetizada (H0): 10 mmHg
# - Media muestral: 8 mmHg
# - Desviación estándar poblacional: 3 mmHg
# - Tamaño de la muestra: 25 pacientes
# - Nivel de significancia (alpha): 0.05
#
# Cálculos Clave:
# - Error estándar de la media: 0.6000
# - Estadístico de prueba Z: -3.3333
# - Valores críticos Z (para alpha=0.05): ±1.9600
# - Región Crítica: Z < -1.9600 O Z > 1.9600
#
# Decisión y Conclusión:
# El estadístico de prueba Z (-3.3333) cae en la región crítica (es menor que -1.9600 o mayor que 1.9600).
# Por lo tanto, rechazamos la hipótesis nula (H0).
# Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de 0.05, para concluir que la reducción promedio de la presión arterial del medicamento es significativamente diferente de 10 mmHg.

# %%
import numpy as np
import scipy.stats

# Asignar los parámetros dados
media_poblacional_h0_presion = 10  # Media poblacional hipotetizada (mmHg)
media_muestral_presion = 8  # Media muestral observada (mmHg)
desviacion_estandar_poblacional_presion = 3  # Desviación estándar poblacional (mmHg)
tamano_muestra_presion = 25  # Tamaño de la muestra (pacientes)
nivel_significancia_presion = 0.05  # Nivel de significancia

print(f"\nParámetros Utilizados:")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_presion} mmHg")
print(f"- Media muestral: {media_muestral_presion} mmHg")
print(f"- Desviación estándar poblacional: {desviacion_estandar_poblacional_presion} mmHg")
print(f"- Tamaño de la muestra: {tamano_muestra_presion} pacientes")
print(f"- Nivel de significancia (alpha): {nivel_significancia_presion}")

# Calcular el error estándar de la media
# Fórmula: Error Estándar = Desviación Estándar Poblacional / sqrt(Tamaño de la Muestra)
error_estandar_presion = desviacion_estandar_poblacional_presion / np.sqrt(tamano_muestra_presion)

# Calcular el estadístico de prueba Z
# Fórmula: Z = (Media Muestral - Media Poblacional H0) / Error Estándar
z_estadistico_presion = (media_muestral_presion - media_poblacional_h0_presion) / error_estandar_presion

print(f"\nCálculos Clave:")
print(f"- Error estándar de la media: {error_estandar_presion:.4f}")
print(f"- Estadístico de prueba Z: {z_estadistico_presion:.4f}")

# Determinar los valores críticos Z para una prueba de dos colas
# Para un nivel de significancia alpha, necesitamos el valor Z que deja alpha/2 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar estos valores.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - alpha / 2) para la cola derecha
# Y -z_critico para la cola izquierda
z_critical_presion_derecha = scipy.stats.norm.ppf(1 - nivel_significancia_presion / 2)
z_critical_presion_izquierda = -z_critical_presion_derecha

# Definir la región crítica
# Para una prueba de dos colas, la región crítica son todos los valores de Z menores que -z_critico O mayores que +z_critico.
# Región Crítica: Z < -z_critico O Z > +z_critico

print(f"- Valores críticos Z (para alpha={nivel_significancia_presion}): ±{z_critical_presion_derecha:.4f}")
print(f"- Región Crítica: Z < {z_critical_presion_izquierda:.4f} O Z > {z_critical_presion_derecha:.4f}")

# Comparar el estadístico de prueba Z con los valores críticos Z
# Si Z_estadistico < -z_critico O Z_estadistico > +z_critico, rechazamos la hipótesis nula.
# De lo contrario, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if z_estadistico_presion < z_critical_presion_izquierda or z_estadistico_presion > z_critical_presion_derecha:
    print(f"El estadístico de prueba Z ({z_estadistico_presion:.4f}) cae en la región crítica (es menor que {z_critical_presion_izquierda:.4f} o mayor que {z_critical_presion_derecha:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_presion}, para concluir que la reducción promedio de la presión arterial del medicamento es significativamente diferente de {media_poblacional_h0_presion} mmHg.")
else:
    print(f"El estadístico de prueba Z ({z_estadistico_presion:.4f}) no cae en la región crítica (está entre {z_critical_presion_izquierda:.4f} y {z_critical_presion_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_presion}, para concluir que la reducción promedio de la presión arterial del medicamento es significativamente diferente de {media_poblacional_h0_presion} mmHg.")
# Out:
# Parámetros Utilizados:
# - Media poblacional hipotetizada (H0): 10 mmHg
# - Media muestral: 8 mmHg
# - Desviación estándar poblacional: 3 mmHg
# - Tamaño de la muestra: 25 pacientes
# - Nivel de significancia (alpha): 0.05
#
# Cálculos Clave:
# - Error estándar de la media: 0.6000
# - Estadístico de prueba Z: -3.3333
# - Valores críticos Z (para alpha=0.05): ±1.9600
# - Región Crítica: Z < -1.9600 O Z > 1.9600
#
# Decisión y Conclusión:
# El estadístico de prueba Z (-3.3333) cae en la región crítica (es menor que -1.9600 o mayor que 1.9600).
# Por lo tanto, rechazamos la hipótesis nula (H0).
# Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de 0.05, para concluir que la reducción promedio de la presión arterial del medicamento es significativamente diferente de 10 mmHg.

# %%
import matplotlib.pyplot as plt

# Graficar la distribución normal estándar
plt.figure(figsize=(10, 6))
x = np.linspace(-4, 4, 1000)
plt.plot(x, scipy.stats.norm.pdf(x, 0, 1), label='Distribución Normal Estándar (Z)')

# Rellenar la región crítica (colas izquierda y derecha)
x_critical_izquierda_plot = np.linspace(-4, z_critical_presion_izquierda, 1000)
plt.fill_between(x_critical_izquierda_plot, 0, scipy.stats.norm.pdf(x_critical_izquierda_plot, 0, 1), color='red', alpha=0.5, label=f'Región Crítica (alpha/2 = {nivel_significancia_presion/2:.3f})')

x_critical_derecha_plot = np.linspace(z_critical_presion_derecha, 4, 1000)
plt.fill_between(x_critical_derecha_plot, 0, scipy.stats.norm.pdf(x_critical_derecha_plot, 0, 1), color='red', alpha=0.5)


# Marcar los valores críticos Z
plt.axvline(z_critical_presion_izquierda, color='red', linestyle='--', label=f'Valores Críticos Z = ±{z_critical_presion_derecha:.4f}')
plt.axvline(z_critical_presion_derecha, color='red', linestyle='--')


# Marcar el estadístico de prueba Z
plt.axvline(z_estadistico_presion, color='green', linestyle='-', label=f'Estadístico Z = {z_estadistico_presion:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para la Reducción de la Presión Arterial (Prueba de Dos Colas)')
plt.xlabel('Valor Z')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Documentar y organizar la respuesta

print("## Resultados de la Prueba de Hipótesis Z")

print("\n### Planteamiento de Hipótesis")
print("Hipótesis Nula (H0): La reducción promedio de la presión arterial es igual a 10 mmHg (μ = 10)")
print("Hipótesis Alternativa (H1): La reducción promedio de la presión arterial es diferente de 10 mmHg (μ != 10)")

print("\n### Parámetros Utilizados")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_presion} mmHg")
print(f"- Media muestral: {media_muestral_presion} mmHg")
print(f"- Desviación estándar poblacional: {desviacion_estandar_poblacional_presion} mmHg")
print(f"- Tamaño de la muestra: {tamano_muestra_presion} pacientes")
print(f"- Nivel de significancia (alpha): {nivel_significancia_presion}")

print("\n### Cálculos Clave")
print(f"- Error estándar de la media: {error_estandar_presion:.4f}")
print(f"- Estadístico de prueba Z: {z_estadistico_presion:.4f}")
print(f"- Valores críticos Z (para alpha={nivel_significancia_presion}): ±{z_critical_presion_derecha:.4f}")
print(f"- Región Crítica: Z < {z_critical_presion_izquierda:.4f} O Z > {z_critical_presion_derecha:.4f}")

print("\n### Decisión y Conclusión")
if z_estadistico_presion < z_critical_presion_izquierda or z_estadistico_presion > z_critical_presion_derecha:
    print(f"El estadístico de prueba Z ({z_estadistico_presion:.4f}) cae en la región crítica (es menor que {z_critical_presion_izquierda:.4f} o mayor que {z_critical_presion_derecha:.4f}).")
    print("Por lo tanto, **rechazamos la hipótesis nula (H0)**.")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_presion}, hay suficiente evidencia estadística para concluir que la reducción promedio de la presión arterial del medicamento es **significativamente diferente de {media_poblacional_h0_presion} mmHg**.")
else:
    print(f"El estadístico de prueba Z ({z_estadistico_presion:.4f}) no cae en la región crítica (está entre {z_critical_presion_izquierda:.4f} y {z_critical_presion_derecha:.4f}).")
    print("Por lo tanto, **no rechazamos la hipótesis nula (H0)**.")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_presion}, no hay suficiente evidencia estadística para concluir que la reducción promedio de la presión arterial del medicamento es significativamente diferente de {media_poblacional_h0_presion} mmHg.")

print("\n### Visualización")
print("El gráfico anterior ilustra la distribución normal estándar, la región crítica en ambas colas y la posición del estadístico de prueba Z en relación con los valores críticos.")

print("\n## Summary:")
print("\n### Data Analysis Key Findings")
print(f"* The null hypothesis (H0) was stated as the average blood pressure reduction being equal to 10 mmHg (μ = 10), and the alternative hypothesis (H1) was that the average reduction is different from 10 mmHg (μ ≠ 10).")
print(f"* The calculated Z-statistic for the sample is {z_estadistico_presion:.4f}.")
print(f"* For a significance level of {nivel_significancia_presion} in a two-tailed test, the critical Z-values are ±{z_critical_presion_derecha:.4f}.")
print(f"* The critical region for rejecting the null hypothesis is when the Z-statistic is less than {z_critical_presion_izquierda:.4f} or greater than {z_critical_presion_derecha:.4f}.")
if z_estadistico_presion < z_critical_presion_izquierda or z_estadistico_presion > z_critical_presion_derecha:
    print(f"* Since the calculated Z-statistic of {z_estadistico_presion:.4f} falls outside the range of the critical values (±{z_critical_presion_derecha:.4f}), it is in the critical region.")
else:
    print(f"* Since the calculated Z-statistic of {z_estadistico_presion:.4f} falls within the range of the critical values (±{z_critical_presion_derecha:.4f}), it is not in the critical region.")

print("\n### Insights or Next Steps")
if z_estadistico_presion < z_critical_presion_izquierda or z_estadistico_presion > z_critical_presion_derecha:
    print(f"* Based on the analysis, there is sufficient statistical evidence at the {nivel_significancia_presion} significance level to conclude that the average blood pressure reduction of the medication is significantly different from {media_poblacional_h0_presion} mmHg.")
else:
    print(f"* Based on the analysis, there is not sufficient statistical evidence at the {nivel_significancia_presion} significance level to conclude that the average blood pressure reduction of the medication is significantly different from {media_poblacional_h0_presion} mmHg.")
# Out:
# ## Resultados de la Prueba de Hipótesis Z
#
# ### Planteamiento de Hipótesis
# Hipótesis Nula (H0): La reducción promedio de la presión arterial es igual a 10 mmHg (μ = 10)
# Hipótesis Alternativa (H1): La reducción promedio de la presión arterial es diferente de 10 mmHg (μ != 10)
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): 10 mmHg
# - Media muestral: 8 mmHg
# - Desviación estándar poblacional: 3 mmHg
# - Tamaño de la muestra: 25 pacientes
# - Nivel de significancia (alpha): 0.05
#
# ### Cálculos Clave
# - Error estándar de la media: 0.6000
# - Estadístico de prueba Z: -3.3333
# - Valores críticos Z (para alpha=0.05): ±1.9600
# - Región Crítica: Z < -1.9600 O Z > 1.9600
#
# ### Decisión y Conclusión
# El estadístico de prueba Z (-3.3333) cae en la región crítica (es menor que -1.9600 o mayor que 1.9600).
# Por lo tanto, **rechazamos la hipótesis nula (H0)**.
# ...

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que el volumen de llenado promedio poblacional es igual a 500 mL.
# H0: μ = 500 mL
# La hipótesis alternativa (H1) es que el volumen de llenado promedio poblacional es diferente de 500 mL.
# H1: μ != 500 mL

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): El volumen de llenado promedio de las botellas es igual a 500 mL (μ = 500)")
print("Hipótesis Alternativa (H1): El volumen de llenado promedio de las botellas es diferente de 500 mL (μ != 500)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): El volumen de llenado promedio de las botellas es igual a 500 mL (μ = 500)
# Hipótesis Alternativa (H1): El volumen de llenado promedio de las botellas es diferente de 500 mL (μ != 500)

# %%
# Importar las librerías necesarias (si no se han importado ya)
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# Asignar los parámetros dados
media_poblacional_h0_botellas = 500  # Media poblacional hipotetizada (mL)
media_muestral_botellas = 498  # Media muestral observada (mL)
desviacion_estandar_poblacional_botellas = 5  # Desviación estándar poblacional (mL)
tamano_muestra_botellas = 60  # Tamaño de la muestra (botellas)
nivel_significancia_botellas = 0.01  # Nivel de significancia

print(f"\nParámetros Utilizados:")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_botellas} mL")
print(f"- Media muestral: {media_muestral_botellas} mL")
print(f"- Desviación estándar poblacional: {desviacion_estandar_poblacional_botellas} mL")
print(f"- Tamaño de la muestra: {tamano_muestra_botellas} botellas")
print(f"- Nivel de significancia (alpha): {nivel_significancia_botellas}")
# Out:
# Parámetros Utilizados:
# - Media poblacional hipotetizada (H0): 500 mL
# - Media muestral: 498 mL
# - Desviación estándar poblacional: 5 mL
# - Tamaño de la muestra: 60 botellas
# - Nivel de significancia (alpha): 0.01

# %%
# Calcular el error estándar de la media
# Fórmula: Error Estándar = Desviación Estándar Poblacional / sqrt(Tamaño de la Muestra)
error_estandar_botellas = desviacion_estandar_poblacional_botellas / np.sqrt(tamano_muestra_botellas)

# Calcular el estadístico de prueba Z
# Fórmula: Z = (Media Muestral - Media Poblacional H0) / Error Estándar
z_estadistico_botellas = (media_muestral_botellas - media_poblacional_h0_botellas) / error_estandar_botellas

print(f"\nCálculos Clave:")
print(f"- Error estándar de la media: {error_estandar_botellas:.4f}")
print(f"- Estadístico de prueba Z: {z_estadistico_botellas:.4f}")
# Out:
# Cálculos Clave:
# - Error estándar de la media: 0.6455
# - Estadístico de prueba Z: -3.0984

# %%
# Determinar los valores críticos Z para una prueba de dos colas
# Para un nivel de significancia alpha, necesitamos el valor Z que deja alpha/2 en cada cola.
# Usamos scipy.stats.norm.ppf para encontrar estos valores.
# Fórmula: z_critico = scipy.stats.norm.ppf(1 - alpha / 2) para la cola derecha
# Y -z_critico para la cola izquierda
z_critical_botellas_derecha = scipy.stats.norm.ppf(1 - nivel_significancia_botellas / 2)
z_critical_botellas_izquierda = -z_critical_botellas_derecha

# Definir la región crítica
# Para una prueba de dos colas, la región crítica son todos los valores de Z menores que -z_critico O mayores que +z_critico.
# Región Crítica: Z < -z_critico O Z > +z_critico

print(f"\nDeterminación de la Región Crítica:")
print(f"- Valores críticos Z (para alpha={nivel_significancia_botellas}): ±{z_critical_botellas_derecha:.4f}")
print(f"- Región Crítica: Z < {z_critical_botellas_izquierda:.4f} O Z > {z_critical_botellas_derecha:.4f}")
# Out:
# Determinación de la Región Crítica:
# - Valores críticos Z (para alpha=0.01): ±2.5758
# - Región Crítica: Z < -2.5758 O Z > 2.5758

# %%
# Comparar el estadístico de prueba Z con los valores críticos Z
# Si Z_estadistico < -z_critico O Z_estadistico > +z_critico, rechazamos la hipótesis nula.
# De lo contrario, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if z_estadistico_botellas < z_critical_botellas_izquierda or z_estadistico_botellas > z_critical_botellas_derecha:
    print(f"El estadístico de prueba Z ({z_estadistico_botellas:.4f}) cae en la región crítica (es menor que {z_critical_botellas_izquierda:.4f} o mayor que {z_critical_botellas_derecha:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_botellas}, para concluir que el volumen de llenado promedio de las botellas es significativamente diferente de {media_poblacional_h0_botellas} mL.")
else:
    print(f"El estadístico de prueba Z ({z_estadistico_botellas:.4f}) no cae en la región crítica (está entre {z_critical_botellas_izquierda:.4f} y {z_critical_botellas_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_botellas}, para concluir que el volumen de llenado promedio de las botellas es significativamente diferente de {media_poblacional_h0_botellas} mL.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba Z (-3.0984) cae en la región crítica (es menor que -2.5758 o mayor que 2.5758).
# Por lo tanto, rechazamos la hipótesis nula (H0).
# Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de 0.01, para concluir que el volumen de llenado promedio de las botellas es significativamente diferente de 500 mL.

# %%
# Graficar la distribución normal estándar
plt.figure(figsize=(10, 6))
x = np.linspace(-4, 4, 1000)
plt.plot(x, scipy.stats.norm.pdf(x, 0, 1), label='Distribución Normal Estándar (Z)')

# Rellenar la región crítica (colas izquierda y derecha)
x_critical_izquierda_plot_botellas = np.linspace(-4, z_critical_botellas_izquierda, 1000)
plt.fill_between(x_critical_izquierda_plot_botellas, 0, scipy.stats.norm.pdf(x_critical_izquierda_plot_botellas, 0, 1), color='red', alpha=0.5, label=f'Región Crítica (alpha/2 = {nivel_significancia_botellas/2:.3f})')

x_critical_derecha_plot_botellas = np.linspace(z_critical_botellas_derecha, 4, 1000)
plt.fill_between(x_critical_derecha_plot_botellas, 0, scipy.stats.norm.pdf(x_critical_derecha_plot_botellas, 0, 1), color='red', alpha=0.5)


# Marcar los valores críticos Z
plt.axvline(z_critical_botellas_izquierda, color='red', linestyle='--', label=f'Valores Críticos Z = ±{z_critical_botellas_derecha:.4f}')
plt.axvline(z_critical_botellas_derecha, color='red', linestyle='--')


# Marcar el estadístico de prueba Z
plt.axvline(z_estadistico_botellas, color='green', linestyle='-', label=f'Estadístico Z = {z_estadistico_botellas:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para el Volumen de Llenado de Botellas (Prueba de Dos Colas)')
plt.xlabel('Valor Z')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Documentar y organizar la respuesta

print("## Resultados de la Prueba de Hipótesis Z para el Volumen de Llenado")

print("\n### Planteamiento de Hipótesis")
print("Hipótesis Nula (H0): El volumen de llenado promedio de las botellas es igual a 500 mL (μ = 500)")
print("Hipótesis Alternativa (H1): El volumen de llenado promedio de las botellas es diferente de 500 mL (μ != 500)")

print("\n### Parámetros Utilizados")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_botellas} mL")
print(f"- Media muestral: {media_muestral_botellas} mL")
print(f"- Desviación estándar poblacional: {desviacion_estandar_poblacional_botellas} mL")
print(f"- Tamaño de la muestra: {tamano_muestra_botellas} botellas")
print(f"- Nivel de significancia (alpha): {nivel_significancia_botellas}")

print("\n### Cálculos Clave")
print(f"- Error estándar de la media: {error_estandar_botellas:.4f}")
print(f"- Estadístico de prueba Z: {z_estadistico_botellas:.4f}")
print(f"- Valores críticos Z (para alpha={nivel_significancia_botellas}): ±{z_critical_botellas_derecha:.4f}")
print(f"- Región Crítica: Z < {z_critical_botellas_izquierda:.4f} O Z > {z_critical_botellas_derecha:.4f}")

print("\n### Decisión y Conclusión")
if z_estadistico_botellas < z_critical_botellas_izquierda or z_estadistico_botellas > z_critical_botellas_derecha:
    print(f"El estadístico de prueba Z ({z_estadistico_botellas:.4f}) cae en la región crítica (es menor que {z_critical_botellas_izquierda:.4f} o mayor que {z_critical_botellas_derecha:.4f}).")
    print("Por lo tanto, **rechazamos la hipótesis nula (H0)**.")
    print(f"Conclusión: Hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_botellas}, para concluir que el volumen de llenado promedio de las botellas es **significativamente diferente de {media_poblacional_h0_botellas} mL**.")
else:
    print(f"El estadístico de prueba Z ({z_estadistico_botellas:.4f}) no cae en la región crítica (está entre {z_critical_botellas_izquierda:.4f} y {z_critical_botellas_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_botellas}, para concluir que el volumen de llenado promedio de las botellas es significativamente diferente de {media_poblacional_h0_botellas} mL.")
# Out:
# ## Resultados de la Prueba de Hipótesis Z para el Volumen de Llenado
#
# ### Planteamiento de Hipótesis
# Hipótesis Nula (H0): El volumen de llenado promedio de las botellas es igual a 500 mL (μ = 500)
# Hipótesis Alternativa (H1): El volumen de llenado promedio de las botellas es diferente de 500 mL (μ != 500)
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): 500 mL
# - Media muestral: 498 mL
# - Desviación estándar poblacional: 5 mL
# - Tamaño de la muestra: 60 botellas
# - Nivel de significancia (alpha): 0.01
#
# ### Cálculos Clave
# - Error estándar de la media: 0.6455
# - Estadístico de prueba Z: -3.0984
# - Valores críticos Z (para alpha=0.01): ±2.5758
# - Región Crítica: Z < -2.5758 O Z > 2.5758
#
# ### Decisión y Conclusión
# El estadístico de prueba Z (-3.0984) cae en la región crítica (es menor que -2.5758 o mayor que 2.5758).
# Por lo tanto, **rechazamos la hipótesis nula (H0)**.
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * La hipótesis nula (H0) plantea que el volumen de llenado promedio de las botellas es igual a 500 mL ($\mu$ = 500), mientras que la hipótesis alternativa (H1) plantea que es diferente de 500 mL ($\mu \neq$ 500).
# * El tamaño de la muestra es de 60 botellas, con una media muestral de 498 mL y una desviación estándar poblacional conocida de 5 mL.
# * El nivel de significancia ($\alpha$) utilizado es de 0.01.
# * El error estándar de la media calculado es de ${error_estandar_botellas:.4f}$.
# * El estadístico de prueba Z calculado es de ${z_estadistico_botellas:.4f}$.
# * Para un nivel de significancia de 0.01 en una prueba de dos colas, los valores críticos de Z son $\pm${z_critical_botellas_derecha:.4f}.
# * La región crítica para rechazar la hipótesis nula se define como Z < ${z_critical_botellas_izquierda:.4f}$ o Z > ${z_critical_botellas_derecha:.4f}$.
# * Dado que el estadístico Z calculado (${z_estadistico_botellas:.4f}$) ${"es menor que el valor crítico izquierdo" if z_estadistico_botellas < z_critical_botellas_izquierda else ("es mayor que el valor crítico derecho" if z_estadistico_botellas > z_critical_botellas_derecha else "no cae en la región crítica")}$ (${z_critical_botellas_izquierda:.4f}$ o ${z_critical_botellas_derecha:.4f}$), ${"cae" if z_estadistico_botellas < z_critical_botellas_izquierda or z_estadistico_botellas > z_critical_botellas_derecha else "no cae"}$ dentro de la región crítica.
#
# ### Insights or Next Steps
#
# * Basándonos en la muestra y un nivel de significancia de 0.01, ${"hay suficiente evidencia estadística para concluir que el volumen de llenado promedio de las botellas es significativamente diferente de 500 mL." if z_estadistico_botellas < z_critical_botellas_izquierda or z_estadistico_botellas > z_critical_botellas_derecha else "no hay suficiente evidencia estadística para concluir que el volumen de llenado promedio de las botellas es significativamente diferente de 500 mL."}$
# * ${"Esto podría indicar un problema en el proceso de llenado de la máquina que necesita ser investigado." if z_estadistico_botellas < z_critical_botellas_izquierda or z_estadistico_botellas > z_critical_botellas_derecha else "Según esta prueba, no hay evidencia concluyente de que el volumen de llenado sea diferente de 500 mL. Sin embargo, siempre es recomendable monitorear el proceso."}$

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que el tiempo promedio de entrega es igual o menor a 25 minutos.
# H0: μ <= 25 minutos
# La hipótesis alternativa (H1) es que el tiempo promedio de entrega es mayor a 25 minutos.
# H1: μ > 25 minutos

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): El tiempo promedio de entrega es igual o menor a 25 minutos (μ <= 25)")
print("Hipótesis Alternativa (H1): El tiempo promedio de entrega es mayor a 25 minutos (μ > 25)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): El tiempo promedio de entrega es igual o menor a 25 minutos (μ <= 25)
# Hipótesis Alternativa (H1): El tiempo promedio de entrega es mayor a 25 minutos (μ > 25)

# %%
# Asignar los parámetros dados
media_poblacional_h0_entrega = 25  # Media poblacional hipotetizada (minutos)
media_muestral_entrega = 28  # Media muestral observada (minutos)
desviacion_estandar_muestral_entrega = 4  # Desviación estándar muestral (minutos)
tamano_muestra_entrega = 15  # Tamaño de la muestra (entregas)
nivel_significancia_entrega = 0.05  # Nivel de significancia

print(f"\nParámetros Utilizados:")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_entrega} minutos")
print(f"- Media muestral: {media_muestral_entrega} minutos")
print(f"- Desviación estándar muestral: {desviacion_estandar_muestral_entrega} minutos")
print(f"- Tamaño de la muestra: {tamano_muestra_entrega} entregas")
print(f"- Nivel de significancia (alpha): {nivel_significancia_entrega}")
# Out:
# Parámetros Utilizados:
# - Media poblacional hipotetizada (H0): 25 minutos
# - Media muestral: 28 minutos
# - Desviación estándar muestral: 4 minutos
# - Tamaño de la muestra: 15 entregas
# - Nivel de significancia (alpha): 0.05

# %%
# Calcular el error estándar de la media muestral
# Fórmula: Error Estándar = Desviación Estándar Muestral / sqrt(Tamaño de la Muestra)
error_estandar_entrega = desviacion_estandar_muestral_entrega / np.sqrt(tamano_muestra_entrega)

# Calcular el estadístico de prueba t
# Fórmula: t = (Media Muestral - Media Poblacional H0) / Error Estándar
t_estadistico_entrega = (media_muestral_entrega - media_poblacional_h0_entrega) / error_estandar_entrega

print(f"\nCálculos Clave:")
print(f"- Error estándar de la media muestral: {error_estandar_entrega:.4f}")
print(f"- Estadístico de prueba t: {t_estadistico_entrega:.4f}")
# Out:
# Cálculos Clave:
# - Error estándar de la media muestral: 1.0328
# - Estadístico de prueba t: 2.9047

# %%
# Determinar los grados de libertad
# Fórmula: df = n - 1
grados_libertad_entrega = tamano_muestra_entrega - 1

# Determinar el valor crítico t para una prueba de cola derecha
# Para un nivel de significancia alpha y df grados de libertad, necesitamos el valor t tal que P(T > t_critico) = alpha
# Usamos scipy.stats.t.ppf para encontrar este valor (1 - alpha)
# Fórmula: t_critico = scipy.stats.t.ppf(1 - nivel_significancia, df)
t_critical_entrega = scipy.stats.t.ppf(1 - nivel_significancia_entrega, grados_libertad_entrega)

# Definir la región crítica y la región de no rechazo
# Para una prueba de cola derecha, la región crítica son todos los valores de t mayores que el valor crítico t.
# Región Crítica: t > t_critico
# Región de No Rechazo: t <= t_critico

print(f"\nDeterminación de la Región Crítica y de No Rechazo:")
print(f"- Grados de libertad: {grados_libertad_entrega}")
print(f"- Valor crítico t (para alpha={nivel_significancia_entrega} y df={grados_libertad_entrega}): {t_critical_entrega:.4f}")
print(f"- Región Crítica: t > {t_critical_entrega:.4f}")
print(f"- Región de No Rechazo: t <= {t_critical_entrega:.4f}")
# Out:
# Determinación de la Región Crítica y de No Rechazo:
# - Grados de libertad: 14
# - Valor crítico t (para alpha=0.05 y df=14): 1.7613
# - Región Crítica: t > 1.7613
# - Región de No Rechazo: t <= 1.7613

# %%
# Comparar el estadístico de prueba t con el valor crítico t
# Si t_estadistico > t_critico, rechazamos la hipótesis nula.
# Si t_estadistico <= t_critico, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if t_estadistico_entrega > t_critical_entrega:
    print(f"El estadístico de prueba t ({t_estadistico_entrega:.4f}) cae en la región crítica (es mayor que el valor crítico t de {t_critical_entrega:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_entrega}, hay suficiente evidencia estadística para concluir que el tiempo promedio de entrega del restaurante es **mayor a {media_poblacional_h0_entrega} minutos**.")
else:
    print(f"El estadístico de prueba t ({t_estadistico_entrega:.4f}) no cae en la región crítica (es menor o igual que el valor crítico t de {t_critical_entrega:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_entrega}, no hay suficiente evidencia estadística para concluir que el tiempo promedio de entrega del restaurante es mayor a {media_poblacional_h0_entrega} minutos.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba t (2.9047) cae en la región crítica (es mayor que el valor crítico t de 1.7613).
# Por lo tanto, rechazamos la hipótesis nula (H0).
# Conclusión: Con un nivel de significancia de 0.05, hay suficiente evidencia estadística para concluir que el tiempo promedio de entrega del restaurante es **mayor a 25 minutos**.

# %%
# Graficar la distribución t de Student
plt.figure(figsize=(10, 6))
# Usar scipy.stats.t con los grados de libertad correctos
x = np.linspace(scipy.stats.t.ppf(0.001, grados_libertad_entrega), scipy.stats.t.ppf(0.999, grados_libertad_entrega), 1000)
plt.plot(x, scipy.stats.t.pdf(x, grados_libertad_entrega), label=f'Distribución t (df={grados_libertad_entrega})')

# Rellenar la región crítica (cola derecha)
x_critical_plot = np.linspace(t_critical_entrega, scipy.stats.t.ppf(0.999, grados_libertad_entrega), 1000)
plt.fill_between(x_critical_plot, 0, scipy.stats.t.pdf(x_critical_plot, grados_libertad_entrega), color='red', alpha=0.5, label=f'Región Crítica (alpha={nivel_significancia_entrega})')

# Marcar el valor crítico t
plt.axvline(t_critical_entrega, color='red', linestyle='--', label=f'Valor Crítico t = {t_critical_entrega:.4f}')

# Marcar el estadístico de prueba t
plt.axvline(t_estadistico_entrega, color='green', linestyle='-', label=f'Estadístico t = {t_estadistico_entrega:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para el Tiempo Promedio de Entrega (Prueba de Cola Derecha)')
plt.xlabel('Valor t')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Resultados de la Prueba de Hipótesis t para el Tiempo Promedio de Entrega
#
# ### Resumen del Problema
# Se realizó una prueba de hipótesis para determinar si el tiempo promedio de entrega a domicilio de un restaurante es significativamente mayor a 25 minutos, basándose en una muestra de 15 entregas.
#
# ### Planteamiento de Hipótesis
# - Hipótesis Nula (H0): El tiempo promedio de entrega es igual o menor a 25 minutos ($\mu \le 25$).
# - Hipótesis Alternativa (H1): El tiempo promedio de entrega es mayor a 25 minutos ($\mu > 25$).
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): {media_poblacional_h0_entrega} minutos
# - Media muestral: {media_muestral_entrega} minutos
# - Desviación estándar muestral: {desviacion_estandar_muestral_entrega} minutos
# - Tamaño de la muestra: {tamano_muestra_entrega} entregas
# - Nivel de significancia ($\alpha$): {nivel_significancia_entrega}
# - Grados de libertad (df): {grados_libertad_entrega}
#
# ### Cálculos Clave
# - Error estándar de la media muestral: {error_estandar_entrega:.4f}
# - Estadístico de prueba t: {t_estadistico_entrega:.4f}
# - Valor crítico t (para $\alpha$={nivel_significancia_entrega} y df={grados_libertad_entrega}): {t_critical_entrega:.4f}
# - Región Crítica (Región de Rechazo de H0): t > {t_critical_entrega:.4f}
# - Región de No Rechazo de H0: t $\le$ {t_critical_entrega:.4f}
#
# ### Decisión y Conclusión
# El estadístico de prueba t calculado ({t_estadistico_entrega:.4f}) se compara con el valor crítico t ({t_critical_entrega:.4f}).
# Dado que el estadístico de prueba t ({t_estadistico_entrega:.4f}) es **mayor** que el valor crítico t ({t_critical_entrega:.4f}), el estadístico cae en la región crítica.
# Por lo tanto, **rechazamos la hipótesis nula (H0)**.
#
# Conclusión: Con un nivel de significancia de 0.05, hay suficiente evidencia estadística para concluir que el tiempo promedio de entrega a domicilio del restaurante es **significativamente mayor a 25 minutos**.
#
# ### Visualización
# El gráfico anterior ilustra la distribución t de Student con {grados_libertad_entrega} grados de libertad, la región crítica en la cola derecha y la posición del estadístico de prueba t en relación con el valor crítico.

# %% [markdown]
# ## Prueba de Hipótesis t para una Muestra: Promedio de la Clase de Matemáticas
#
# **Problema:** Un colegio afirma que el promedio de su clase en matemáticas es 80/100. Se toma una muestra de 12 estudiantes, obteniendo una media de 75 y una desviación estándar muestral de 8. Con un nivel de significancia de $\alpha = 0.01$, determine si el promedio de la clase es significativamente diferente de 80.
#
# **Instrucciones:**
# 1. Plantear las hipótesis nula y alternativa.
# 2. Calcule el estadístico t.
# 3. Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# 4. Concluya si se rechaza H0.
# 5. Utilizar fórmulas estándar con explicaciones claras.
# 6. Usar `scipy.stats` para cálculos estadísticos.
# 7. Comentar todo el código indicando pasos y fórmulas.
# 8. Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# 9. Todo el resultado debe estar en español.
# 10. Graficar la distribución t, la región crítica y el estadístico de prueba.

# %%
# Importar las librerías necesarias
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que el promedio poblacional de la clase es igual a 80.
# H0: μ = 80 puntos
# La hipótesis alternativa (H1) es que el promedio poblacional de la clase es diferente de 80.
# H1: μ != 80 puntos

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): El promedio de la clase en matemáticas es igual a 80 (μ = 80)")
print("Hipótesis Alternativa (H1): El promedio de la clase en matemáticas es diferente de 80 (μ != 80)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): El promedio de la clase en matemáticas es igual a 80 (μ = 80)
# Hipótesis Alternativa (H1): El promedio de la clase en matemáticas es diferente de 80 (μ != 80)

# %%
# Asignar los parámetros dados
media_poblacional_h0_matematicas = 80  # Media poblacional hipotetizada
media_muestral_matematicas = 75  # Media muestral observada
desviacion_estandar_muestral_matematicas = 8  # Desviación estándar muestral
tamano_muestra_matematicas = 12  # Tamaño de la muestra
nivel_significancia_matematicas = 0.01  # Nivel de significancia (alpha)

print(f"\nParámetros Utilizados:")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_matematicas}")
print(f"- Media muestral: {media_muestral_matematicas}")
print(f"- Desviación estándar muestral: {desviacion_estandar_muestral_matematicas}")
print(f"- Tamaño de la muestra: {tamano_muestra_matematicas}")
print(f"- Nivel de significancia (alpha): {nivel_significancia_matematicas}")
# Out:
# Parámetros Utilizados:
# - Media poblacional hipotetizada (H0): 80
# - Media muestral: 75
# - Desviación estándar muestral: 8
# - Tamaño de la muestra: 12
# - Nivel de significancia (alpha): 0.01

# %%
# Calcular el error estándar de la media muestral
# Fórmula: Error Estándar = Desviación Estándar Muestral / sqrt(Tamaño de la Muestra)
error_estandar_matematicas = desviacion_estandar_muestral_matematicas / np.sqrt(tamano_muestra_matematicas)

# Calcular el estadístico de prueba t
# Fórmula: t = (Media Muestral - Media Poblacional H0) / Error Estándar
t_estadistico_matematicas = (media_muestral_matematicas - media_poblacional_h0_matematicas) / error_estandar_matematicas

print(f"\nCálculos Clave:")
print(f"- Error estándar de la media muestral: {error_estandar_matematicas:.4f}")
print(f"- Estadístico de prueba t: {t_estadistico_matematicas:.4f}")
# Out:
# Cálculos Clave:
# - Error estándar de la media muestral: 2.3094
# - Estadístico de prueba t: -2.1651

# %%
# Determinar los grados de libertad
# Fórmula: df = n - 1
grados_libertad_matematicas = tamano_muestra_matematicas - 1

# Determinar los valores críticos t para una prueba de dos colas
# Para un nivel de significancia alpha y df grados de libertad, necesitamos el valor t que deja alpha/2 en cada cola.
# Usamos scipy.stats.t.ppf para encontrar estos valores.
# Fórmula: t_critico = scipy.stats.t.ppf(1 - alpha / 2, df) para la cola derecha
# Y -t_critico para la cola izquierda
t_critical_matematicas_derecha = scipy.stats.t.ppf(1 - nivel_significancia_matematicas / 2, grados_libertad_matematicas)
t_critical_matematicas_izquierda = -t_critical_matematicas_derecha

# Definir la región crítica y la región de no rechazo
# Para una prueba de dos colas, la región crítica son todos los valores de t menores que -t_critico O mayores que +t_critico.
# Región Crítica: t < -t_critico O t > +t_critico
# Región de No Rechazo: -t_critico <= t <= +t_critico

print(f"\nDeterminación de la Región Crítica y de No Rechazo:")
print(f"- Grados de libertad: {grados_libertad_matematicas}")
print(f"- Valores críticos t (para alpha={nivel_significancia_matematicas} y df={grados_libertad_matematicas}): ±{t_critical_matematicas_derecha:.4f}")
print(f"- Región Crítica: t < {t_critical_matematicas_izquierda:.4f} O t > {t_critical_matematicas_derecha:.4f}")
print(f"- Región de No Rechazo: {t_critical_matematicas_izquierda:.4f} <= t <= {t_critical_matematicas_derecha:.4f}")
# Out:
# Determinación de la Región Crítica y de No Rechazo:
# - Grados de libertad: 11
# - Valores críticos t (para alpha=0.01 y df=11): ±3.1058
# - Región Crítica: t < -3.1058 O t > 3.1058
# - Región de No Rechazo: -3.1058 <= t <= 3.1058

# %%
# Graficar la distribución t de Student
plt.figure(figsize=(10, 6))
# Usar scipy.stats.t con los grados de libertad correctos
# Definir un rango de x que cubra bien las colas de la distribución t para los grados de libertad dados
x_min = scipy.stats.t.ppf(0.0001, grados_libertad_matematicas)
x_max = scipy.stats.t.ppf(0.9999, grados_libertad_matematicas)
x = np.linspace(x_min, x_max, 1000)

plt.plot(x, scipy.stats.t.pdf(x, grados_libertad_matematicas), label=f'Distribución t (df={grados_libertad_matematicas})')

# Rellenar la región crítica (colas izquierda y derecha)
x_critical_izquierda_plot = np.linspace(x_min, t_critical_matematicas_izquierda, 1000)
plt.fill_between(x_critical_izquierda_plot, 0, scipy.stats.t.pdf(x_critical_izquierda_plot, grados_libertad_matematicas), color='red', alpha=0.5, label=f'Región Crítica (alpha/2 = {nivel_significancia_matematicas/2:.3f})')

x_critical_derecha_plot = np.linspace(t_critical_matematicas_derecha, x_max, 1000)
plt.fill_between(x_critical_derecha_plot, 0, scipy.stats.t.pdf(x_critical_derecha_plot, grados_libertad_matematicas), color='red', alpha=0.5)


# Marcar los valores críticos t
plt.axvline(t_critical_matematicas_izquierda, color='red', linestyle='--', label=f'Valores Críticos t = ±{t_critical_matematicas_derecha:.4f}')
plt.axvline(t_critical_matematicas_derecha, color='red', linestyle='--')


# Marcar el estadístico de prueba t
plt.axvline(t_estadistico_matematicas, color='green', linestyle='-', label=f'Estadístico t = {t_estadistico_matematicas:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para el Promedio de la Clase de Matemáticas (Prueba de Dos Colas)')
plt.xlabel('Valor t')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparar el estadístico de prueba t con los valores críticos t
# Si t_estadistico < -t_critico O t_estadistico > +t_critico, rechazamos la hipótesis nula.
# De lo contrario, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if t_estadistico_matematicas < t_critical_matematicas_izquierda or t_estadistico_matematicas > t_critical_matematicas_derecha:
    print(f"El estadístico de prueba t ({t_estadistico_matematicas:.4f}) cae en la región crítica (es menor que {t_critical_matematicas_izquierda:.4f} o mayor que {t_critical_matematicas_derecha:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_matematicas}, hay suficiente evidencia estadística para concluir que el promedio de la clase en matemáticas es significativamente diferente de {media_poblacional_h0_matematicas}.")
else:
    print(f"El estadístico de prueba t ({t_estadistico_matematicas:.4f}) no cae en la región crítica (está entre {t_critical_matematicas_izquierda:.4f} y {t_critical_matematicas_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_matematicas}, para concluir que el promedio de la clase en matemáticas es significativamente diferente de {media_poblacional_h0_matematicas}.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba t (-2.1651) no cae en la región crítica (está entre -3.1058 y 3.1058).
# Por lo tanto, no rechazamos la hipótesis nula (H0).
# Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de 0.01, para concluir que el promedio de la clase en matemáticas es significativamente diferente de 80.

# %% [markdown]
# ## Resultados de la Prueba de Hipótesis t
#
# ### Resumen del Problema
# Se realizó una prueba de hipótesis para determinar si el promedio de la clase de matemáticas es significativamente diferente de 80, basándose en una muestra de 12 estudiantes.
#
# ### Planteamiento de Hipótesis
# - Hipótesis Nula (H0): El promedio poblacional de la clase en matemáticas es igual a 80 ($\mu = 80$).
# - Hipótesis Alternativa (H1): El promedio poblacional de la clase en matemáticas es diferente de 80 ($\mu \neq 80$).
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): {media_poblacional_h0_matematicas}
# - Media muestral: {media_muestral_matematicas}
# - Desviación estándar muestral: {desviacion_estandar_muestral_matematicas}
# - Tamaño de la muestra: {tamano_muestra_matematicas}
# - Nivel de significancia ($\alpha$): {nivel_significancia_matematicas}
# - Grados de libertad (df): {grados_libertad_matematicas}
#
# ### Cálculos Clave
# - Error estándar de la media muestral: {error_estandar_matematicas:.4f}
# - Estadístico de prueba t: {t_estadistico_matematicas:.4f}
# - Valores críticos t (para $\alpha$={nivel_significancia_matematicas} y df={grados_libertad_matematicas}): $\pm${t_critical_matematicas_derecha:.4f}
# - Región Crítica (Región de Rechazo de H0): t < {t_critical_matematicas_izquierda:.4f} O t > {t_critical_matematicas_derecha:.4f}
# - Región de No Rechazo de H0: {t_critical_matematicas_izquierda:.4f} $\le$ t $\le$ {t_critical_matematicas_derecha:.4f}
#
# ### Decisión y Conclusión
# El estadístico de prueba t calculado ({t_estadistico_matematicas:.4f}) se compara con los valores críticos t ($\pm${t_critical_matematicas_derecha:.4f}).
# Dado que el estadístico de prueba t ({t_estadistico_matematicas:.4f}) ${"es menor que el valor crítico izquierdo" if t_estadistico_matematicas < t_critical_matematicas_izquierda else ("es mayor que el valor crítico derecho" if t_estadistico_matematicas > t_critical_matematicas_derecha else "no cae en la región crítica")}$ ({t_critical_matematicas_izquierda:.4f} o {t_critical_matematicas_derecha:.4f}), ${"cae" if t_estadistico_matematicas < t_critical_matematicas_izquierda or t_estadistico_matematicas > t_critical_matematicas_derecha else "no cae"}$ dentro de la región crítica.
# Por lo tanto, ${"**rechazamos la hipótesis nula (H0)**" if t_estadistico_matematicas < t_critical_matematicas_izquierda or t_estadistico_matematicas > t_critical_matematicas_derecha else "**no rechazamos la hipótesis nula (H0)**"}$.
#
# Conclusión: Con un nivel de significancia de {nivel_significancia_matematicas}, ${"hay suficiente evidencia estadística para concluir que el promedio de la clase en matemáticas es significativamente diferente de" if t_estadistico_matematicas < t_critical_matematicas_izquierda or t_estadistico_matematicas > t_critical_matematicas_derecha else "no hay suficiente evidencia estadística para concluir que el promedio de la clase en matemáticas es significativamente diferente de"}$ {media_poblacional_h0_matematicas}.
#
# ### Visualización
# El gráfico anterior ilustra la distribución t de Student con {grados_libertad_matematicas} grados de libertad, la región crítica en ambas colas y la posición del estadístico de prueba t en relación con los valores críticos.

# %% [markdown]
# ## Prueba de Hipótesis t para una Muestra: Consumo Promedio de Combustible
#
# **Problema:** Un fabricante asegura que su auto consume 15 km/L. Una prueba con 10 autos muestra una media de 14 km/L y una desviación estándar muestral de 1.2 km/L. Con un nivel de significancia de $\alpha = 0.05$, determine si el consumo promedio es significativamente diferente de 15 km/L.
#
# **Instrucciones:**
# 1. Plantear las hipótesis nula y alternativa.
# 2. Calcule el estadístico t.
# 3. Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# 4. Concluya si se rechaza H0.
# 5. Utilizar fórmulas estándar con explicaciones claras.
# 6. Usar `scipy.stats` para cálculos estadísticos.
# 7. Comentar todo el código indicando pasos y fórmulas.
# 8. Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# 9. Todo el resultado debe estar en español.
# 10. Graficar la distribución t, la región crítica y el estadístico de prueba.

# %%
# Importar las librerías necesarias
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que el consumo promedio poblacional es igual a 15 km/L.
# H0: μ = 15 km/L
# La hipótesis alternativa (H1) es que el consumo promedio poblacional es diferente de 15 km/L.
# H1: μ != 15 km/L

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): El consumo promedio de combustible es igual a 15 km/L (μ = 15)")
print("Hipótesis Alternativa (H1): El consumo promedio de combustible es diferente de 15 km/L (μ != 15)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): El consumo promedio de combustible es igual a 15 km/L (μ = 15)
# Hipótesis Alternativa (H1): El consumo promedio de combustible es diferente de 15 km/L (μ != 15)

# %%
# Asignar los parámetros dados
media_poblacional_h0_combustible = 15  # Media poblacional hipotetizada
media_muestral_combustible = 14  # Media muestral observada
desviacion_estandar_muestral_combustible = 1.2  # Desviación estándar muestral
tamano_muestra_combustible = 10  # Tamaño de la muestra
nivel_significancia_combustible = 0.05  # Nivel de significancia (alpha)

print(f"\nParámetros Utilizados:")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_combustible} km/L")
print(f"- Media muestral: {media_muestral_combustible} km/L")
print(f"- Desviación estándar muestral: {desviacion_estandar_muestral_combustible} km/L")
print(f"- Tamaño de la muestra: {tamano_muestra_combustible} autos")
print(f"- Nivel de significancia (alpha): {nivel_significancia_combustible}")
# Out:
# Parámetros Utilizados:
# - Media poblacional hipotetizada (H0): 15 km/L
# - Media muestral: 14 km/L
# - Desviación estándar muestral: 1.2 km/L
# - Tamaño de la muestra: 10 autos
# - Nivel de significancia (alpha): 0.05

# %%
# Calcular el error estándar de la media muestral
# Fórmula: Error Estándar = Desviación Estándar Muestral / sqrt(Tamaño de la Muestra)
error_estandar_combustible = desviacion_estandar_muestral_combustible / np.sqrt(tamano_muestra_combustible)

# Calcular el estadístico de prueba t
# Fórmula: t = (Media Muestral - Media Poblacional H0) / Error Estándar
t_estadistico_combustible = (media_muestral_combustible - media_poblacional_h0_combustible) / error_estandar_combustible

print(f"\nCálculos Clave:")
print(f"- Error estándar de la media muestral: {error_estandar_combustible:.4f}")
print(f"- Estadístico de prueba t: {t_estadistico_combustible:.4f}")
# Out:
# Cálculos Clave:
# - Error estándar de la media muestral: 0.3795
# - Estadístico de prueba t: -2.6352

# %%
# Determinar los grados de libertad
# Fórmula: df = n - 1
grados_libertad_combustible = tamano_muestra_combustible - 1

# Determinar los valores críticos t para una prueba de dos colas
# Para un nivel de significancia alpha y df grados de libertad, necesitamos el valor t que deja alpha/2 en cada cola.
# Usamos scipy.stats.t.ppf para encontrar estos valores.
# Fórmula: t_critico = scipy.stats.t.ppf(1 - alpha / 2, df) para la cola derecha
# Y -t_critico para la cola izquierda
t_critical_combustible_derecha = scipy.stats.t.ppf(1 - nivel_significancia_combustible / 2, grados_libertad_combustible)
t_critical_combustible_izquierda = -t_critical_combustible_derecha

# Definir la región crítica y la región de no rechazo
# Para una prueba de dos colas, la región crítica son todos los valores de t menores que -t_critico O mayores que +t_critico.
# Región Crítica: t < -t_critico O t > +t_critico
# Región de No Rechazo: -t_critico <= t <= +t_critico

print(f"\nDeterminación de la Región Crítica y de No Rechazo:")
print(f"- Grados de libertad: {grados_libertad_combustible}")
print(f"- Valores críticos t (para alpha={nivel_significancia_combustible} y df={grados_libertad_combustible}): ±{t_critical_combustible_derecha:.4f}")
print(f"- Región Crítica: t < {t_critical_combustible_izquierda:.4f} O t > {t_critical_combustible_derecha:.4f}")
print(f"- Región de No Rechazo: {t_critical_combustible_izquierda:.4f} <= t <= {t_critical_combustible_derecha:.4f}")
# Out:
# Determinación de la Región Crítica y de No Rechazo:
# - Grados de libertad: 9
# - Valores críticos t (para alpha=0.05 y df=9): ±2.2622
# - Región Crítica: t < -2.2622 O t > 2.2622
# - Región de No Rechazo: -2.2622 <= t <= 2.2622

# %%
# Graficar la distribución t de Student
plt.figure(figsize=(10, 6))
# Usar scipy.stats.t con los grados de libertad correctos
# Definir un rango de x que cubra bien las colas de la distribución t para los grados de libertad dados
x_min = scipy.stats.t.ppf(0.0001, grados_libertad_combustible)
x_max = scipy.stats.t.ppf(0.9999, grados_libertad_combustible)
x = np.linspace(x_min, x_max, 1000)

plt.plot(x, scipy.stats.t.pdf(x, grados_libertad_combustible), label=f'Distribución t (df={grados_libertad_combustible})')

# Rellenar la región crítica (colas izquierda y derecha)
x_critical_izquierda_plot = np.linspace(x_min, t_critical_combustible_izquierda, 1000)
plt.fill_between(x_critical_izquierda_plot, 0, scipy.stats.t.pdf(x_critical_izquierda_plot, grados_libertad_combustible), color='red', alpha=0.5, label=f'Región Crítica (alpha/2 = {nivel_significancia_combustible/2:.3f})')

x_critical_derecha_plot = np.linspace(t_critical_combustible_derecha, x_max, 1000)
plt.fill_between(x_critical_derecha_plot, 0, scipy.stats.t.pdf(x_critical_derecha_plot, grados_libertad_combustible), color='red', alpha=0.5)


# Marcar los valores críticos t
plt.axvline(t_critical_combustible_izquierda, color='red', linestyle='--', label=f'Valores Críticos t = ±{t_critical_combustible_derecha:.4f}')
plt.axvline(t_critical_combustible_derecha, color='red', linestyle='--')


# Marcar el estadístico de prueba t
plt.axvline(t_estadistico_combustible, color='green', linestyle='-', label=f'Estadístico t = {t_estadistico_combustible:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para el Consumo Promedio de Combustible (Prueba de Dos Colas)')
plt.xlabel('Valor t')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparar el estadístico de prueba t con los valores críticos t
# Si t_estadistico < -t_critico O t_estadistico > +t_critico, rechazamos la hipótesis nula.
# De lo contrario, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if t_estadistico_combustible < t_critical_combustible_izquierda or t_estadistico_combustible > t_critical_combustible_derecha:
    print(f"El estadístico de prueba t ({t_estadistico_combustible:.4f}) cae en la región crítica (es menor que {t_critical_combustible_izquierda:.4f} o mayor que {t_critical_combustible_derecha:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_combustible}, hay suficiente evidencia estadística para concluir que el consumo promedio de combustible es significativamente diferente de {media_poblacional_h0_combustible} km/L.")
else:
    print(f"El estadístico de prueba t ({t_estadistico_combustible:.4f}) no cae en la región crítica (está entre {t_critical_combustible_izquierda:.4f} y {t_critical_combustible_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_combustible}, para concluir que el consumo promedio de combustible es significativamente diferente de {media_poblacional_h0_combustible} km/L.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba t (-2.6352) cae en la región crítica (es menor que -2.2622 o mayor que 2.2622).
# Por lo tanto, rechazamos la hipótesis nula (H0).
# Conclusión: Con un nivel de significancia de 0.05, hay suficiente evidencia estadística para concluir que el consumo promedio de combustible es significativamente diferente de 15 km/L.

# %% [markdown]
# ## Resultados de la Prueba de Hipótesis t
#
# ### Resumen del Problema
# Se realizó una prueba de hipótesis para determinar si el consumo promedio de combustible de un auto es significativamente diferente de 15 km/L, basándose en una muestra de 10 autos.
#
# ### Planteamiento de Hipótesis
# - Hipótesis Nula (H0): El consumo promedio poblacional de combustible es igual a 15 km/L ($\mu = 15$).
# - Hipótesis Alternativa (H1): El consumo promedio poblacional de combustible es diferente de 15 km/L ($\mu \neq 15$).
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): {media_poblacional_h0_combustible} km/L
# - Media muestral: {media_muestral_combustible} km/L
# - Desviación estándar muestral: {desviacion_estandar_muestral_combustible} km/L
# - Tamaño de la muestra: {tamano_muestra_combustible} autos
# - Nivel de significancia ($\alpha$): {nivel_significancia_combustible}
# - Grados de libertad (df): {grados_libertad_combustible}
#
# ### Cálculos Clave
# - Error estándar de la media muestral: {error_estandar_combustible:.4f}
# - Estadístico de prueba t: {t_estadistico_combustible:.4f}
# - Valores críticos t (para $\alpha$={nivel_significancia_combustible} y df={grados_libertad_combustible}): $\pm${t_critical_combustible_derecha:.4f}
# - Región Crítica (Región de Rechazo de H0): t < {t_critical_combustible_izquierda:.4f} O t > {t_critical_combustible_derecha:.4f}
# - Región de No Rechazo de H0: {t_critical_combustible_izquierda:.4f} $\le$ t $\le$ {t_critical_combustible_derecha:.4f}
#
# ### Decisión y Conclusión
# El estadístico de prueba t calculado ({t_estadistico_combustible:.4f}) se compara con los valores críticos t ($\pm${t_critical_combustible_derecha:.4f}).
# Dado que el estadístico de prueba t ({t_estadistico_combustible:.4f}) ${"es menor que el valor crítico izquierdo" if t_estadistico_combustible < t_critical_combustible_izquierda else ("es mayor que el valor crítico derecho" if t_estadistico_combustible > t_critical_combustible_derecha else "no cae en la región crítica")}$ ({t_critical_combustible_izquierda:.4f} o {t_critical_combustible_derecha:.4f}), ${"cae" if t_estadistico_combustible < t_critical_combustible_izquierda or t_estadistico_combustible > t_critical_combustible_derecha else "no cae"}$ dentro de la región crítica.
# Por lo tanto, ${"**rechazamos la hipótesis nula (H0)**" if t_estadistico_combustible < t_critical_combustible_izquierda or t_estadistico_combustible > t_critical_combustible_derecha else "**no rechazamos la hipótesis nula (H0)**"}$.
#
# Conclusión: Con un nivel de significancia de {nivel_significancia_combustible}, ${"hay suficiente evidencia estadística para concluir que el consumo promedio de combustible es significativamente diferente de" if t_estadistico_combustible < t_critical_combustible_izquierda or t_estadistico_combustible > t_critical_combustible_derecha else "no hay suficiente evidencia estadística para concluir que el consumo promedio de combustible es significativamente diferente de"}$ {media_poblacional_h0_combustible} km/L.
#
# ### Visualización
# El gráfico anterior ilustra la distribución t de Student con {grados_libertad_combustible} grados de libertad, la región crítica en ambas colas y la posición del estadístico de prueba t en relación con los valores críticos.

# %% [markdown]
# ## Prueba de Hipótesis t para una Muestra: Aumento del Nivel de Hierro
#
# **Problema:** Un suplemento promete aumentar el nivel de hierro en la sangre en 2 mg/dL. En 8 pacientes, el aumento promedio fue 1.5 mg/dL con una desviación estándar muestral de 0,6 mg/dL. Con un nivel de significancia de $\alpha = 0.10$, determine si el aumento promedio es significativamente diferente de 2 mg/dL.
#
# **Instrucciones:**
# 1. Plantear las hipótesis nula y alternativa.
# 2. Calcule el estadístico t.
# 3. Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# 4. Concluya si se rechaza H0.
# 5. Utilizar fórmulas estándar con explicaciones claras.
# 6. Usar `scipy.stats` para cálculos estadísticos.
# 7. Comentar todo el código indicando pasos y fórmulas.
# 8. Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# 9. Todo el resultado debe estar en español.
# 10. Graficar la distribución t, la región crítica y el estadístico de prueba.

# %%
# Importar las librerías necesarias
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que el aumento promedio poblacional es igual a 2 mg/dL.
# H0: μ = 2 mg/dL
# La hipótesis alternativa (H1) es que el aumento promedio poblacional es diferente de 2 mg/dL.
# H1: μ != 2 mg/dL

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): El aumento promedio del nivel de hierro es igual a 2 mg/dL (μ = 2)")
print("Hipótesis Alternativa (H1): El aumento promedio del nivel de hierro es diferente de 2 mg/dL (μ != 2)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): El aumento promedio del nivel de hierro es igual a 2 mg/dL (μ = 2)
# Hipótesis Alternativa (H1): El aumento promedio del nivel de hierro es diferente de 2 mg/dL (μ != 2)

# %%
# Asignar los parámetros dados
media_poblacional_h0_hierro = 2  # Media poblacional hipotetizada (mg/dL)
media_muestral_hierro = 1.5  # Media muestral observada (mg/dL)
desviacion_estandar_muestral_hierro = 0.6  # Desviación estándar muestral (mg/dL)
tamano_muestra_hierro = 8  # Tamaño de la muestra (pacientes)
nivel_significancia_hierro = 0.10  # Nivel de significancia (alpha)

print(f"\nParámetros Utilizados:")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_hierro} mg/dL")
print(f"- Media muestral: {media_muestral_hierro} mg/dL")
print(f"- Desviación estándar muestral: {desviacion_estandar_muestral_hierro} mg/dL")
print(f"- Tamaño de la muestra: {tamano_muestra_hierro} pacientes")
print(f"- Nivel de significancia (alpha): {nivel_significancia_hierro}")
# Out:
# Parámetros Utilizados:
# - Media poblacional hipotetizada (H0): 2 mg/dL
# - Media muestral: 1.5 mg/dL
# - Desviación estándar muestral: 0.6 mg/dL
# - Tamaño de la muestra: 8 pacientes
# - Nivel de significancia (alpha): 0.1

# %%
# Calcular el error estándar de la media muestral
# Fórmula: Error Estándar = Desviación Estándar Muestral / sqrt(Tamaño de la Muestra)
error_estandar_hierro = desviacion_estandar_muestral_hierro / np.sqrt(tamano_muestra_hierro)

# Calcular el estadístico de prueba t
# Fórmula: t = (Media Muestral - Media Poblacional H0) / Error Estándar
t_estadistico_hierro = (media_muestral_hierro - media_poblacional_h0_hierro) / error_estandar_hierro

print(f"\nCálculos Clave:")
print(f"- Error estándar de la media muestral: {error_estandar_hierro:.4f}")
print(f"- Estadístico de prueba t: {t_estadistico_hierro:.4f}")
# Out:
# Cálculos Clave:
# - Error estándar de la media muestral: 0.2121
# - Estadístico de prueba t: -2.3570

# %%
# Determinar los grados de libertad
# Fórmula: df = n - 1
grados_libertad_hierro = tamano_muestra_hierro - 1

# Determinar los valores críticos t para una prueba de dos colas
# Para un nivel de significancia alpha y df grados de libertad, necesitamos el valor t que deja alpha/2 en cada cola.
# Usamos scipy.stats.t.ppf para encontrar estos valores.
# Fórmula: t_critico = scipy.stats.t.ppf(1 - alpha / 2, df) para la cola derecha
# Y -t_critico para la cola izquierda
t_critical_hierro_derecha = scipy.stats.t.ppf(1 - nivel_significancia_hierro / 2, grados_libertad_hierro)
t_critical_hierro_izquierda = -t_critical_hierro_derecha

# Definir la región crítica y la región de no rechazo
# Para una prueba de dos colas, la región crítica son todos los valores de t menores que -t_critico O mayores que +t_critico.
# Región Crítica: t < -t_critico O t > +t_critico
# Región de No Rechazo: -t_critico <= t <= +t_critico

print(f"\nDeterminación de la Región Crítica y de No Rechazo:")
print(f"- Grados de libertad: {grados_libertad_hierro}")
print(f"- Valores críticos t (para alpha={nivel_significancia_hierro} y df={grados_libertad_hierro}): ±{t_critical_hierro_derecha:.4f}")
print(f"- Región Crítica: t < {t_critical_hierro_izquierda:.4f} O t > {t_critical_hierro_derecha:.4f}")
print(f"- Región de No Rechazo: {t_critical_hierro_izquierda:.4f} <= t <= {t_critical_hierro_derecha:.4f}")
# Out:
# Determinación de la Región Crítica y de No Rechazo:
# - Grados de libertad: 7
# - Valores críticos t (para alpha=0.1 y df=7): ±1.8946
# - Región Crítica: t < -1.8946 O t > 1.8946
# - Región de No Rechazo: -1.8946 <= t <= 1.8946

# %%
# Graficar la distribución t de Student
plt.figure(figsize=(10, 6))
# Usar scipy.stats.t con los grados de libertad correctos
# Definir un rango de x que cubra bien las colas de la distribución t para los grados de libertad dados
x_min = scipy.stats.t.ppf(0.0001, grados_libertad_hierro)
x_max = scipy.stats.t.ppf(0.9999, grados_libertad_hierro)
x = np.linspace(x_min, x_max, 1000)

plt.plot(x, scipy.stats.t.pdf(x, grados_libertad_hierro), label=f'Distribución t (df={grados_libertad_hierro})')

# Rellenar la región crítica (colas izquierda y derecha)
x_critical_izquierda_plot = np.linspace(x_min, t_critical_hierro_izquierda, 1000)
plt.fill_between(x_critical_izquierda_plot, 0, scipy.stats.t.pdf(x_critical_izquierda_plot, grados_libertad_hierro), color='red', alpha=0.5, label=f'Región Crítica (alpha/2 = {nivel_significancia_hierro/2:.3f})')

x_critical_derecha_plot = np.linspace(t_critical_hierro_derecha, x_max, 1000)
plt.fill_between(x_critical_derecha_plot, 0, scipy.stats.t.pdf(x_critical_derecha_plot, grados_libertad_hierro), color='red', alpha=0.5)


# Marcar los valores críticos t
plt.axvline(t_critical_hierro_izquierda, color='red', linestyle='--', label=f'Valores Críticos t = ±{t_critical_hierro_derecha:.4f}')
plt.axvline(t_critical_hierro_derecha, color='red', linestyle='--')


# Marcar el estadístico de prueba t
plt.axvline(t_estadistico_hierro, color='green', linestyle='-', label=f'Estadístico t = {t_estadistico_hierro:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para el Aumento del Nivel de Hierro (Prueba de Dos Colas)')
plt.xlabel('Valor t')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparar el estadístico de prueba t con los valores críticos t
# Si t_estadistico < -t_critico O t_estadistico > +t_critico, rechazamos la hipótesis nula.
# De lo contrario, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if t_estadistico_hierro < t_critical_hierro_izquierda or t_estadistico_hierro > t_critical_hierro_derecha:
    print(f"El estadístico de prueba t ({t_estadistico_hierro:.4f}) cae en la región crítica (es menor que {t_critical_hierro_izquierda:.4f} o mayor que {t_critical_hierro_derecha:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_hierro}, hay suficiente evidencia estadística para concluir que el aumento promedio del nivel de hierro es significativamente diferente de {media_poblacional_h0_hierro} mg/dL.")
else:
    print(f"El estadístico de prueba t ({t_estadistico_hierro:.4f}) no cae en la región crítica (está entre {t_critical_hierro_izquierda:.4f} y {t_critical_hierro_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_hierro}, para concluir que el aumento promedio del nivel de hierro es significativamente diferente de {media_poblacional_h0_hierro} mg/dL.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba t (-2.3570) cae en la región crítica (es menor que -1.8946 o mayor que 1.8946).
# Por lo tanto, rechazamos la hipótesis nula (H0).
# Conclusión: Con un nivel de significancia de 0.1, hay suficiente evidencia estadística para concluir que el aumento promedio del nivel de hierro es significativamente diferente de 2 mg/dL.

# %% [markdown]
# ## Resultados de la Prueba de Hipótesis t
#
# ### Resumen del Problema
# Se realizó una prueba de hipótesis para determinar si el aumento promedio del nivel de hierro en la sangre es significativamente diferente de 2 mg/dL, basándose en una muestra de 8 pacientes que tomaron un suplemento.
#
# ### Planteamiento de Hipótesis
# - Hipótesis Nula (H0): El aumento promedio poblacional del nivel de hierro es igual a 2 mg/dL ($\mu = 2$).
# - Hipótesis Alternativa (H1): El aumento promedio poblacional del nivel de hierro es diferente de 2 mg/dL ($\mu \neq 2$).
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): {media_poblacional_h0_hierro} mg/dL
# - Media muestral: {media_muestral_hierro} mg/dL
# - Desviación estándar muestral: {desviacion_estandar_muestral_hierro} mg/dL
# - Tamaño de la muestra: {tamano_muestra_hierro} pacientes
# - Nivel de significancia ($\alpha$): {nivel_significancia_hierro}
# - Grados de libertad (df): {grados_libertad_hierro}
#
# ### Cálculos Clave
# - Error estándar de la media muestral: {error_estandar_hierro:.4f}
# - Estadístico de prueba t: {t_estadistico_hierro:.4f}
# - Valores críticos t (para $\alpha$={nivel_significancia_hierro} y df={grados_libertad_hierro}): $\pm${t_critical_hierro_derecha:.4f}
# - Región Crítica (Región de Rechazo de H0): t < {t_critical_hierro_izquierda:.4f} O t > {t_critical_hierro_derecha:.4f}
# - Región de No Rechazo de H0: {t_critical_hierro_izquierda:.4f} $\le$ t $\le$ {t_critical_hierro_derecha:.4f}
#
# ### Decisión y Conclusión
# El estadístico de prueba t calculado ({t_estadistico_hierro:.4f}) se compara con los valores críticos t ($\pm${t_critical_hierro_derecha:.4f}).
# Dado que el estadístico de prueba t ({t_estadistico_hierro:.4f}) ${"es menor que el valor crítico izquierdo" if t_estadistico_hierro < t_critical_hierro_izquierda else ("es mayor que el valor crítico derecho" if t_estadistico_hierro > t_critical_hierro_derecha else "no cae en la región crítica")}$ ({t_critical_hierro_izquierda:.4f} o {t_critical_hierro_derecha:.4f}), ${"cae" if t_estadistico_hierro < t_critical_hierro_izquierda or t_estadistico_hierro > t_critical_hierro_derecha else "no cae"}$ dentro de la región crítica.
# Por lo tanto, ${"**rechazamos la hipótesis nula (H0)**" if t_estadistico_hierro < t_critical_hierro_izquierda or t_estadistico_hierro > t_critical_hierro_derecha else "**no rechazamos la hipótesis nula (H0)**"}$.
#
# Conclusión: Con un nivel de significancia de {nivel_significancia_hierro}, ${"hay suficiente evidencia estadística para concluir que el aumento promedio del nivel de hierro es significativamente diferente de" if t_estadistico_hierro < t_critical_hierro_izquierda or t_estadistico_hierro > t_critical_hierro_derecha else "no hay suficiente evidencia estadística para concluir que el aumento promedio del nivel de hierro es significativamente diferente de"}$ {media_poblacional_h0_hierro} mg/dL.
#
# ### Visualización
# El gráfico anterior ilustra la distribución t de Student con {grados_libertad_hierro} grados de libertad, la región crítica en ambas colas y la posición del estadístico de prueba t en relación con los valores críticos.

# %% [markdown]
# ## Prueba de Hipótesis t para una Muestra: Duración Promedio de Focos
#
# **Problema:** Un fabricante asegura que sus focos duran 10,000 horas. En 20 focos probados, la media fue 9,800 horas con una desviación estándar muestral de 300 horas. Con un nivel de significancia de $\alpha = 0.05$, determine si la duración promedio es significativamente diferente de 10,000 horas.
#
# **Instrucciones:**
# 1. Plantear las hipótesis nula y alternativa.
# 2. Calcule el estadístico t.
# 3. Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# 4. Concluya si se rechaza H0.
# 5. Utilizar fórmulas estándar con explicaciones claras.
# 6. Usar `scipy.stats` para cálculos estadísticos.
# 7. Comentar todo el código indicando pasos y fórmulas.
# 8. Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# 9. Todo el resultado debe estar en español.
# 10. Graficar la distribución t, la región crítica y el estadístico de prueba.

# %%
# Importar las librerías necesarias
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que la duración promedio poblacional es igual a 10,000 horas.
# H0: μ = 10000 horas
# La hipótesis alternativa (H1) es que la duración promedio poblacional es diferente de 10,000 horas.
# H1: μ != 10000 horas

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): La duración promedio de los focos es igual a 10,000 horas (μ = 10000)")
print("Hipótesis Alternativa (H1): La duración promedio de los focos es diferente de 10,000 horas (μ != 10000)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): La duración promedio de los focos es igual a 10,000 horas (μ = 10000)
# Hipótesis Alternativa (H1): La duración promedio de los focos es diferente de 10,000 horas (μ != 10000)

# %%
# Asignar los parámetros dados
media_poblacional_h0_focos = 10000  # Media poblacional hipotetizada (horas)
media_muestral_focos = 9800  # Media muestral observada (horas)
desviacion_estandar_muestral_focos = 300  # Desviación estándar muestral (horas)
tamano_muestra_focos = 20  # Tamaño de la muestra (focos)
nivel_significancia_focos = 0.05  # Nivel de significancia (alpha)

print(f"\nParámetros Utilizados:")
print(f"- Media poblacional hipotetizada (H0): {media_poblacional_h0_focos} horas")
print(f"- Media muestral: {media_muestral_focos} horas")
print(f"- Desviación estándar muestral: {desviacion_estandar_muestral_focos} horas")
print(f"- Tamaño de la muestra: {tamano_muestra_focos} focos")
print(f"- Nivel de significancia (alpha): {nivel_significancia_focos}")
# Out:
# Parámetros Utilizados:
# - Media poblacional hipotetizada (H0): 10000 horas
# - Media muestral: 9800 horas
# - Desviación estándar muestral: 300 horas
# - Tamaño de la muestra: 20 focos
# - Nivel de significancia (alpha): 0.05

# %%
# Calcular el error estándar de la media muestral
# Fórmula: Error Estándar = Desviación Estándar Muestral / sqrt(Tamaño de la Muestra)
error_estandar_focos = desviacion_estandar_muestral_focos / np.sqrt(tamano_muestra_focos)

# Calcular el estadístico de prueba t
# Fórmula: t = (Media Muestral - Media Poblacional H0) / Error Estándar
t_estadistico_focos = (media_muestral_focos - media_poblacional_h0_focos) / error_estandar_focos

print(f"\nCálculos Clave:")
print(f"- Error estándar de la media muestral: {error_estandar_focos:.4f}")
print(f"- Estadístico de prueba t: {t_estadistico_focos:.4f}")
# Out:
# Cálculos Clave:
# - Error estándar de la media muestral: 67.0820
# - Estadístico de prueba t: -2.9814

# %%
# Determinar los grados de libertad
# Fórmula: df = n - 1
grados_libertad_focos = tamano_muestra_focos - 1

# Determinar los valores críticos t para una prueba de dos colas
# Para un nivel de significancia alpha y df grados de libertad, necesitamos el valor t que deja alpha/2 en cada cola.
# Usamos scipy.stats.t.ppf para encontrar estos valores.
# Fórmula: t_critico = scipy.stats.t.ppf(1 - alpha / 2, df) para la cola derecha
# Y -t_critico para la cola izquierda
t_critical_focos_derecha = scipy.stats.t.ppf(1 - nivel_significancia_focos / 2, grados_libertad_focos)
t_critical_focos_izquierda = -t_critical_focos_derecha

# Definir la región crítica y la región de no rechazo
# Para una prueba de dos colas, la región crítica son todos los valores de t menores que -t_critico O mayores que +t_critico.
# Región Crítica: t < -t_critico O t > +t_critico
# Región de No Rechazo: -t_critico <= t <= +t_critico

print(f"\nDeterminación de la Región Crítica y de No Rechazo:")
print(f"- Grados de libertad: {grados_libertad_focos}")
print(f"- Valores críticos t (para alpha={nivel_significancia_focos} y df={grados_libertad_focos}): ±{t_critical_focos_derecha:.4f}")
print(f"- Región Crítica: t < {t_critical_focos_izquierda:.4f} O t > {t_critical_focos_derecha:.4f}")
print(f"- Región de No Rechazo: {t_critical_focos_izquierda:.4f} <= t <= {t_critical_focos_derecha:.4f}")
# Out:
# Determinación de la Región Crítica y de No Rechazo:
# - Grados de libertad: 19
# - Valores críticos t (para alpha=0.05 y df=19): ±2.0930
# - Región Crítica: t < -2.0930 O t > 2.0930
# - Región de No Rechazo: -2.0930 <= t <= 2.0930

# %%
# Graficar la distribución t de Student
plt.figure(figsize=(10, 6))
# Usar scipy.stats.t con los grados de libertad correctos
# Definir un rango de x que cubra bien las colas de la distribución t para los grados de libertad dados
x_min = scipy.stats.t.ppf(0.0001, grados_libertad_focos)
x_max = scipy.stats.t.ppf(0.9999, grados_libertad_focos)
x = np.linspace(x_min, x_max, 1000)

plt.plot(x, scipy.stats.t.pdf(x, grados_libertad_focos), label=f'Distribución t (df={grados_libertad_focos})')

# Rellenar la región crítica (colas izquierda y derecha)
x_critical_izquierda_plot = np.linspace(x_min, t_critical_focos_izquierda, 1000)
plt.fill_between(x_critical_izquierda_plot, 0, scipy.stats.t.pdf(x_critical_izquierda_plot, grados_libertad_focos), color='red', alpha=0.5, label=f'Región Crítica (alpha/2 = {nivel_significancia_focos/2:.3f})')

x_critical_derecha_plot = np.linspace(t_critical_focos_derecha, x_max, 1000)
plt.fill_between(x_critical_derecha_plot, 0, scipy.stats.t.pdf(x_critical_derecha_plot, grados_libertad_focos), color='red', alpha=0.5)


# Marcar los valores críticos t
plt.axvline(t_critical_focos_izquierda, color='red', linestyle='--', label=f'Valores Críticos t = ±{t_critical_focos_derecha:.4f}')
plt.axvline(t_critical_focos_derecha, color='red', linestyle='--')


# Marcar el estadístico de prueba t
plt.axvline(t_estadistico_focos, color='green', linestyle='-', label=f'Estadístico t = {t_estadistico_focos:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para la Duración Promedio de Focos (Prueba de Dos Colas)')
plt.xlabel('Valor t')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparar el estadístico de prueba t con los valores críticos t
# Si t_estadistico < -t_critico O t_estadistico > +t_critico, rechazamos la hipótesis nula.
# De lo contrario, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if t_estadistico_focos < t_critical_focos_izquierda or t_estadistico_focos > t_critical_focos_derecha:
    print(f"El estadístico de prueba t ({t_estadistico_focos:.4f}) cae en la región crítica (es menor que {t_critical_focos_izquierda:.4f} o mayor que {t_critical_focos_derecha:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_focos}, hay suficiente evidencia estadística para concluir que la duración promedio de los focos es significativamente diferente de {media_poblacional_h0_focos} horas.")
else:
    print(f"El estadístico de prueba t ({t_estadistico_focos:.4f}) no cae en la región crítica (está entre {t_critical_focos_izquierda:.4f} y {t_critical_focos_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_focos}, para concluir que la duración promedio de los focos es significativamente diferente de {media_poblacional_h0_focos} horas.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba t (-2.9814) cae en la región crítica (es menor que -2.0930 o mayor que 2.0930).
# Por lo tanto, rechazamos la hipótesis nula (H0).
# Conclusión: Con un nivel de significancia de 0.05, hay suficiente evidencia estadística para concluir que la duración promedio de los focos es significativamente diferente de 10000 horas.

# %% [markdown]
# ## Resultados de la Prueba de Hipótesis t
#
# ### Resumen del Problema
# Se realizó una prueba de hipótesis para determinar si la duración promedio de los focos es significativamente diferente de 10,000 horas, basándose en una muestra de 20 focos.
#
# ### Planteamiento de Hipótesis
# - Hipótesis Nula (H0): La duración promedio poblacional de los focos es igual a 10,000 horas ($\mu = 10000$).
# - Hipótesis Alternativa (H1): La duración promedio poblacional de los focos es diferente de 10,000 horas ($\mu \neq 10000$).
#
# ### Parámetros Utilizados
# - Media poblacional hipotetizada (H0): {media_poblacional_h0_focos} horas
# - Media muestral: {media_muestral_focos} horas
# - Desviación estándar muestral: {desviacion_estandar_muestral_focos} horas
# - Tamaño de la muestra: {tamano_muestra_focos} focos
# - Nivel de significancia ($\alpha$): {nivel_significancia_focos}
# - Grados de libertad (df): {grados_libertad_focos}
#
# ### Cálculos Clave
# - Error estándar de la media muestral: {error_estandar_focos:.4f}
# - Estadístico de prueba t: {t_estadistico_focos:.4f}
# - Valores críticos t (para $\alpha$={nivel_significancia_focos} y df={grados_libertad_focos}): $\pm${t_critical_focos_derecha:.4f}
# - Región Crítica (Región de Rechazo de H0): t < {t_critical_focos_izquierda:.4f} O t > {t_critical_focos_derecha:.4f}
# - Región de No Rechazo de H0: {t_critical_focos_izquierda:.4f} $\le$ t $\le$ {t_critical_focos_derecha:.4f}
#
# ### Decisión y Conclusión
# El estadístico de prueba t calculado ({t_estadistico_focos:.4f}) se compara con los valores críticos t ($\pm${t_critical_focos_derecha:.4f}).
# Dado que el estadístico de prueba t ({t_estadistico_focos:.4f}) ${"es menor que el valor crítico izquierdo" if t_estadistico_focos < t_critical_focos_izquierda else ("es mayor que el valor crítico derecho" if t_estadistico_focos > t_critical_focos_derecha else "no cae en la región crítica")}$ ({t_critical_focos_izquierda:.4f} o {t_critical_focos_derecha:.4f}), ${"cae" if t_estadistico_focos < t_critical_focos_izquierda or t_estadistico_focos > t_critical_focos_derecha else "no cae"}$ dentro de la región crítica.
# Por lo tanto, ${"**rechazamos la hipótesis nula (H0)**" if t_estadistico_focos < t_critical_focos_izquierda or t_estadistico_focos > t_critical_focos_derecha else "**no rechazamos la hipótesis nula (H0)**"}$.
#
# Conclusión: Con un nivel de significancia de {nivel_significancia_focos}, ${"hay suficiente evidencia estadística para concluir que la duración promedio de los focos es significativamente diferente de" if t_estadistico_focos < t_critical_focos_izquierda or t_estadistico_focos > t_critical_focos_derecha else "no hay suficiente evidencia estadística para concluir que la duración promedio de los focos es significativamente diferente de"}$ {media_poblacional_h0_focos} horas.
#
# ### Visualización
# El gráfico anterior ilustra la distribución t de Student con {grados_libertad_focos} grados de libertad, la región crítica en ambas colas y la posición del estadístico de prueba t en relación con los valores críticos.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * La hipótesis nula (H0) plantea que la duración promedio de los focos es igual a 10,000 horas ($\mu$ = 10000), mientras que la hipótesis alternativa (H1) plantea que es diferente de 10,000 horas ($\mu \neq$ 10000).
# * El tamaño de la muestra es de 20 focos, con una media muestral de 9,800 horas y una desviación estándar muestral de 300 horas.
# * El nivel de significancia ($\alpha$) utilizado es de 0.05.
# * Los grados de libertad (df) son 19.
# * El error estándar de la media muestral calculado es de {error_estandar_focos:.4f}.
# * El estadístico de prueba t calculado es de {t_estadistico_focos:.4f}.
# * Para un nivel de significancia de 0.05 en una prueba de dos colas con 19 grados de libertad, los valores críticos de t son $\pm${t_critical_focos_derecha:.4f}.
# * La región crítica para rechazar la hipótesis nula se define como t < {t_critical_focos_izquierda:.4f} o t > {t_critical_focos_derecha:.4f}.
# * Dado que el estadístico t calculado ({t_estadistico_focos:.4f}) es menor que el valor crítico izquierdo ({t_critical_focos_izquierda:.4f}), cae dentro de la región crítica.
#
# ### Insights or Next Steps
#
# * Basándonos en la muestra y un nivel de significancia de 0.05, hay suficiente evidencia estadística para concluir que la duración promedio de los focos es significativamente diferente de 10,000 horas.
# * Esto sugiere que la afirmación del fabricante sobre la duración promedio de 10,000 horas podría no ser precisa según esta muestra. Se podría considerar realizar más pruebas o investigar el proceso de fabricación.

# %% [markdown]
# ## Prueba de Hipótesis de Chi-Cuadrado ($\chi^2$) para la Varianza: Tiempo de Duración de Llamadas
#
# **Problema:** Una compañía de telefonía afirma que la varianza del tiempo de duración de las llamadas es de $\sigma^2 = 2,5$ minutos$^2$. Se toma una muestra de $n = 16$ llamadas y se obtiene una varianza muestral de $s^2 = 4$. ¿Hay evidencia al 5 % de significancia de que la varianza poblacional difiere de 2.5?
#
# **Instrucciones:**
# 1. Plantear las hipótesis nula y alternativa.
# 2. Calcule el estadístico $\chi^2$.
# 3. Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# 4. Concluya si se rechaza H0.
# 5. Utilizar fórmulas estándar con explicaciones claras.
# 6. Usar `scipy.stats` para cálculos estadísticos.
# 7. Comentar todo el código indicando pasos y fórmulas.
# 8. Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# 9. Todo el resultado debe estar en español.
# 10. Graficar la distribución $\chi^2$, la región crítica y el estadístico de prueba.

# %%
# Importar las librerías necesarias
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que la varianza poblacional es igual a 2.5 minutos^2.
# H0: σ^2 = 2.5
# La hipótesis alternativa (H1) es que la varianza poblacional es diferente de 2.5 minutos^2.
# H1: σ^2 != 2.5

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): La varianza del tiempo de duración de las llamadas es igual a 2.5 minutos^2 (σ^2 = 2.5)")
print("Hipótesis Alternativa (H1): La varianza del tiempo de duración de las llamadas es diferente de 2.5 minutos^2 (σ^2 != 2.5)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): La varianza del tiempo de duración de las llamadas es igual a 2.5 minutos^2 (σ^2 = 2.5)
# Hipótesis Alternativa (H1): La varianza del tiempo de duración de las llamadas es diferente de 2.5 minutos^2 (σ^2 != 2.5)

# %%
# Asignar los parámetros dados
varianza_poblacional_h0 = 2.5  # Varianza poblacional hipotetizada (minutos^2)
varianza_muestral = 4  # Varianza muestral observada (minutos^2)
tamano_muestra = 16  # Tamaño de la muestra (llamadas)
nivel_significancia = 0.05  # Nivel de significancia (alpha)

print(f"\nParámetros Utilizados:")
print(f"- Varianza poblacional hipotetizada (H0): {varianza_poblacional_h0} minutos^2")
print(f"- Varianza muestral: {varianza_muestral} minutos^2")
print(f"- Tamaño de la muestra: {tamano_muestra} llamadas")
print(f"- Nivel de significancia (alpha): {nivel_significancia}")
# Out:
# Parámetros Utilizados:
# - Varianza poblacional hipotetizada (H0): 2.5 minutos^2
# - Varianza muestral: 4 minutos^2
# - Tamaño de la muestra: 16 llamadas
# - Nivel de significancia (alpha): 0.05

# %%
# Calcular los grados de libertad
# Fórmula: df = n - 1
grados_libertad = tamano_muestra - 1

# Calcular el estadístico de prueba Chi-Cuadrado
# Fórmula: χ^2 = ((n - 1) * s^2) / σ^2
# Donde n es el tamaño de la muestra, s^2 es la varianza muestral y σ^2 es la varianza poblacional hipotetizada.
chi2_estadistico = ((tamano_muestra - 1) * varianza_muestral) / varianza_poblacional_h0

print(f"\nCálculos Clave:")
print(f"- Grados de libertad: {grados_libertad}")
print(f"- Estadístico de prueba Chi-Cuadrado (χ^2): {chi2_estadistico:.4f}")
# Out:
# Cálculos Clave:
# - Grados de libertad: 15
# - Estadístico de prueba Chi-Cuadrado (χ^2): 24.0000

# %%
# Determinar los valores críticos Chi-Cuadrado para una prueba de dos colas
# Para un nivel de significancia alpha y df grados de libertad, necesitamos los valores χ^2 que dejan alpha/2 en cada cola.
# Usamos scipy.stats.chi2.ppf para encontrar estos valores.
# Fórmula: χ^2_critico_izquierda = scipy.stats.chi2.ppf(alpha / 2, df)
# Fórmula: χ^2_critico_derecha = scipy.stats.chi2.ppf(1 - alpha / 2, df)
chi2_critical_izquierda = scipy.stats.chi2.ppf(nivel_significancia / 2, grados_libertad)
chi2_critical_derecha = scipy.stats.chi2.ppf(1 - nivel_significancia / 2, grados_libertad)

# Definir la región crítica y la región de no rechazo
# Para una prueba de dos colas, la región crítica son todos los valores de χ^2 menores que χ^2_critico_izquierda O mayores que χ^2_critico_derecha.
# Región Crítica: χ^2 < χ^2_critico_izquierda O χ^2 > χ^2_critico_derecha
# Región de No Rechazo: χ^2_critico_izquierda <= χ^2 <= χ^2_critico_derecha

print(f"\nDeterminación de la Región Crítica y de No Rechazo:")
print(f"- Valores críticos Chi-Cuadrado (para alpha={nivel_significancia} y df={grados_libertad}): {chi2_critical_izquierda:.4f} y {chi2_critical_derecha:.4f}")
print(f"- Región Crítica: χ^2 < {chi2_critical_izquierda:.4f} O χ^2 > {chi2_critical_derecha:.4f}")
print(f"- Región de No Rechazo: {chi2_critical_izquierda:.4f} <= χ^2 <= {chi2_critical_derecha:.4f}")
# Out:
# Determinación de la Región Crítica y de No Rechazo:
# - Valores críticos Chi-Cuadrado (para alpha=0.05 y df=15): 6.2621 y 27.4884
# - Región Crítica: χ^2 < 6.2621 O χ^2 > 27.4884
# - Región de No Rechazo: 6.2621 <= χ^2 <= 27.4884

# %%
# Graficar la distribución Chi-Cuadrado
plt.figure(figsize=(10, 6))
# Definir un rango de x que cubra la distribución Chi-Cuadrado para los grados de libertad dados
# Usar un rango desde 0 hasta un valor que cubra bien la cola derecha
x_max_plot = scipy.stats.chi2.ppf(0.999, grados_libertad)
x = np.linspace(0, x_max_plot, 1000)

plt.plot(x, scipy.stats.chi2.pdf(x, grados_libertad), label=f'Distribución χ^2 (df={grados_libertad})')

# Rellenar la región crítica (colas izquierda y derecha)
x_critical_izquierda_plot = np.linspace(0, chi2_critical_izquierda, 1000)
plt.fill_between(x_critical_izquierda_plot, 0, scipy.stats.chi2.pdf(x_critical_izquierda_plot, grados_libertad), color='red', alpha=0.5, label=f'Región Crítica (alpha/2 = {nivel_significancia/2:.3f})')

x_critical_derecha_plot = np.linspace(chi2_critical_derecha, x_max_plot, 1000)
plt.fill_between(x_critical_derecha_plot, 0, scipy.stats.chi2.pdf(x_critical_derecha_plot, grados_libertad), color='red', alpha=0.5)


# Marcar los valores críticos Chi-Cuadrado
plt.axvline(chi2_critical_izquierda, color='red', linestyle='--', label=f'Valores Críticos χ^2 = {chi2_critical_izquierda:.4f}, {chi2_critical_derecha:.4f}')
plt.axvline(chi2_critical_derecha, color='red', linestyle='--')


# Marcar el estadístico de prueba Chi-Cuadrado
plt.axvline(chi2_estadistico, color='green', linestyle='-', label=f'Estadístico χ^2 = {chi2_estadistico:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para la Varianza del Tiempo de Llamada (Prueba de Dos Colas)')
plt.xlabel('Valor χ^2')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparar el estadístico de prueba Chi-Cuadrado con los valores críticos
# Si chi2_estadistico < chi2_critical_izquierda O chi2_estadistico > chi2_critical_derecha, rechazamos la hipótesis nula.
# De lo contrario, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if chi2_estadistico < chi2_critical_izquierda or chi2_estadistico > chi2_critical_derecha:
    print(f"El estadístico de prueba χ^2 ({chi2_estadistico:.4f}) cae en la región crítica (es menor que {chi2_critical_izquierda:.4f} o mayor que {chi2_critical_derecha:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia}, hay suficiente evidencia estadística para concluir que la varianza poblacional del tiempo de duración de las llamadas es significativamente diferente de {varianza_poblacional_h0} minutos^2.")
else:
    print(f"El estadístico de prueba χ^2 ({chi2_estadistico:.4f}) no cae en la región crítica (está entre {chi2_critical_izquierda:.4f} y {chi2_critical_derecha:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia}, para concluir que la varianza poblacional del tiempo de duración de las llamadas es significativamente diferente de {varianza_poblacional_h0} minutos^2.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba χ^2 (24.0000) no cae en la región crítica (está entre 6.2621 y 27.4884).
# Por lo tanto, no rechazamos la hipótesis nula (H0).
# Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de 0.05, para concluir que la varianza poblacional del tiempo de duración de las llamadas es significativamente diferente de 2.5 minutos^2.

# %% [markdown]
# ## Resultados de la Prueba de Hipótesis de Chi-Cuadrado ($\chi^2$) para la Varianza
#
# ### Resumen del Problema
# Se realizó una prueba de hipótesis para determinar si la varianza poblacional del tiempo de duración de las llamadas es significativamente diferente de 2.5 minutos$^2$, basándose en una muestra de 16 llamadas.
#
# ### Planteamiento de Hipótesis
# - Hipótesis Nula (H0): La varianza poblacional del tiempo de duración de las llamadas es igual a 2.5 minutos$^2$ ($\sigma^2 = 2.5$).
# - Hipótesis Alternativa (H1): La varianza poblacional del tiempo de duración de las llamadas es diferente de 2.5 minutos$^2$ ($\sigma^2 \neq 2.5$).
#
# ### Parámetros Utilizados
# - Varianza poblacional hipotetizada (H0): {varianza_poblacional_h0} minutos$^2$
# - Varianza muestral: {varianza_muestral} minutos$^2$
# - Tamaño de la muestra: {tamano_muestra} llamadas
# - Nivel de significancia ($\alpha$): {nivel_significancia}
# - Grados de libertad (df): {grados_libertad}
#
# ### Cálculos Clave
# - Estadístico de prueba Chi-Cuadrado ($\chi^2$): {chi2_estadistico:.4f}
# - Valores críticos Chi-Cuadrado (para $\alpha$={nivel_significancia} y df={grados_libertad}): {chi2_critical_izquierda:.4f} (izquierda) y {chi2_critical_derecha:.4f} (derecha)
# - Región Crítica (Región de Rechazo de H0): $\chi^2$ < {chi2_critical_izquierda:.4f} O $\chi^2$ > {chi2_critical_derecha:.4f}
# - Región de No Rechazo de H0: {chi2_critical_izquierda:.4f} $\le$ $\chi^2$ $\le$ {chi2_critical_derecha:.4f}
#
# ### Decisión y Conclusión
# El estadístico de prueba $\chi^2$ calculado ({chi2_estadistico:.4f}) se compara con los valores críticos $\chi^2$ ({chi2_critical_izquierda:.4f} y {chi2_critical_derecha:.4f}).
# Dado que el estadístico de prueba $\chi^2$ ({chi2_estadistico:.4f}) ${"es menor que el valor crítico izquierdo" if chi2_estadistico < chi2_critical_izquierda else ("es mayor que el valor crítico derecho" if chi2_estadistico > chi2_critical_derecha else "no cae en la región crítica")}$ ({chi2_critical_izquierda:.4f} o {chi2_critical_derecha:.4f}), ${"cae" if chi2_estadistico < chi2_critical_izquierda or chi2_estadistico > chi2_critical_derecha else "no cae"}$ dentro de la región crítica.
# Por lo tanto, ${"**rechazamos la hipótesis nula (H0)**" if chi2_estadistico < chi2_critical_izquierda or chi2_estadistico > chi2_critical_derecha else "**no rechazamos la hipótesis nula (H0)**"}$.
#
# Conclusión: Con un nivel de significancia de {nivel_significancia}, ${"hay suficiente evidencia estadística para concluir que la varianza poblacional del tiempo de duración de las llamadas es significativamente diferente de" if chi2_estadistico < chi2_critical_izquierda or chi2_estadistico > chi2_critical_derecha else "no hay suficiente evidencia estadística para concluir que la varianza poblacional del tiempo de duración de las llamadas es significativamente diferente de"}$ {varianza_poblacional_h0} minutos$^2$.
#
# ### Visualización
# El gráfico anterior ilustra la distribución $\chi^2$ con {grados_libertad} grados de libertad, la región crítica en ambas colas y la posición del estadístico de prueba $\chi^2$ en relación con los valores críticos.

# %% [markdown]
# ## Prueba de Hipótesis de Chi-Cuadrado ($\chi^2$) para la Varianza: Volumen de Llenado de Botellas
#
# **Problema:** Una máquina embotelladora debe mantener la varianza del llenado en $\sigma^2 = 1,2$ ml$^2$. Se toma una muestra de $n = 20$ botellas y se encuentra $s^2 = 2,0$. ¿Existe evidencia al 1 % de que la varianza es mayor?
#
# **Instrucciones:**
# 1. Plantear las hipótesis nula y alternativa.
# 2. Calcule el estadístico $\chi^2$.
# 3. Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# 4. Concluya si se rechaza H0.
# 5. Utilizar fórmulas estándar con explicaciones claras.
# 6. Usar `scipy.stats` para cálculos estadísticos.
# 7. Comentar todo el código indicando pasos y fórmulas.
# 8. Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# 9. Todo el resultado debe estar en español.
# 10. Graficar la distribución $\chi^2$, la región crítica y el estadístico de prueba.

# %%
# Importar las librerías necesarias
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# %%
# Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que la varianza poblacional es igual o menor a 1.2 ml^2.
# H0: σ^2 <= 1.2
# La hipótesis alternativa (H1) es que la varianza poblacional es mayor a 1.2 ml^2.
# H1: σ^2 > 1.2

print("Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): La varianza del llenado es igual o menor a 1.2 ml^2 (σ^2 <= 1.2)")
print("Hipótesis Alternativa (H1): La varianza del llenado es mayor a 1.2 ml^2 (σ^2 > 1.2)")
# Out:
# Planteamiento de Hipótesis:
# Hipótesis Nula (H0): La varianza del llenado es igual o menor a 1.2 ml^2 (σ^2 <= 1.2)
# Hipótesis Alternativa (H1): La varianza del llenado es mayor a 1.2 ml^2 (σ^2 > 1.2)

# %%
# Asignar los parámetros dados
varianza_poblacional_h0_llenado = 1.2  # Varianza poblacional hipotetizada (ml^2)
varianza_muestral_llenado = 2.0  # Varianza muestral observada (ml^2)
tamano_muestra_llenado = 20  # Tamaño de la muestra (botellas)
nivel_significancia_llenado = 0.01  # Nivel de significancia (alpha)

print(f"\nParámetros Utilizados:")
print(f"- Varianza poblacional hipotetizada (H0): {varianza_poblacional_h0_llenado} ml^2")
print(f"- Varianza muestral: {varianza_muestral_llenado} ml^2")
print(f"- Tamaño de la muestra: {tamano_muestra_llenado} botellas")
print(f"- Nivel de significancia (alpha): {nivel_significancia_llenado}")
# Out:
# Parámetros Utilizados:
# - Varianza poblacional hipotetizada (H0): 1.2 ml^2
# - Varianza muestral: 2.0 ml^2
# - Tamaño de la muestra: 20 botellas
# - Nivel de significancia (alpha): 0.01

# %%
# Calcular los grados de libertad
# Fórmula: df = n - 1
grados_libertad_llenado = tamano_muestra_llenado - 1

# Calcular el estadístico de prueba Chi-Cuadrado
# Fórmula: χ^2 = ((n - 1) * s^2) / σ^2
# Donde n es el tamaño de la muestra, s^2 es la varianza muestral y σ^2 es la varianza poblacional hipotetizada.
chi2_estadistico_llenado = ((tamano_muestra_llenado - 1) * varianza_muestral_llenado) / varianza_poblacional_h0_llenado

print(f"\nCálculos Clave:")
print(f"- Grados de libertad: {grados_libertad_llenado}")
print(f"- Estadístico de prueba Chi-Cuadrado (χ^2): {chi2_estadistico_llenado:.4f}")
# Out:
# Cálculos Clave:
# - Grados de libertad: 19
# - Estadístico de prueba Chi-Cuadrado (χ^2): 31.6667

# %%
# Determinar el valor crítico Chi-Cuadrado para una prueba de cola derecha
# Para un nivel de significancia alpha y df grados de libertad, necesitamos el valor χ^2 que deja alpha en la cola derecha.
# Usamos scipy.stats.chi2.ppf para encontrar este valor (1 - alpha).
# Fórmula: χ^2_critico_derecha = scipy.stats.chi2.ppf(1 - alpha, df)
chi2_critical_llenado = scipy.stats.chi2.ppf(1 - nivel_significancia_llenado, grados_libertad_llenado)

# Definir la región crítica y la región de no rechazo
# Para una prueba de cola derecha, la región crítica son todos los valores de χ^2 mayores que el valor crítico χ^2.
# Región Crítica: χ^2 > χ^2_critico
# Región de No Rechazo: χ^2 <= χ^2_critico

print(f"\nDeterminación de la Región Crítica y de No Rechazo:")
print(f"- Grados de libertad: {grados_libertad_llenado}")
print(f"- Valor crítico Chi-Cuadrado (para alpha={nivel_significancia_llenado} y df={grados_libertad_llenado}): {chi2_critical_llenado:.4f}")
print(f"- Región Crítica: χ^2 > {chi2_critical_llenado:.4f}")
print(f"- Región de No Rechazo: χ^2 <= {chi2_critical_llenado:.4f}")
# Out:
# Determinación de la Región Crítica y de No Rechazo:
# - Grados de libertad: 19
# - Valor crítico Chi-Cuadrado (para alpha=0.01 y df=19): 36.1909
# - Región Crítica: χ^2 > 36.1909
# - Región de No Rechazo: χ^2 <= 36.1909

# %%
# Graficar la distribución Chi-Cuadrado
plt.figure(figsize=(10, 6))
# Definir un rango de x que cubra la distribución Chi-Cuadrado para los grados de libertad dados
# Usar un rango desde 0 hasta un valor que cubra bien la cola derecha
x_max_plot_llenado = scipy.stats.chi2.ppf(0.999, grados_libertad_llenado)
x_llenado = np.linspace(0, x_max_plot_llenado, 1000)

plt.plot(x_llenado, scipy.stats.chi2.pdf(x_llenado, grados_libertad_llenado), label=f'Distribución χ^2 (df={grados_libertad_llenado})')

# Rellenar la región crítica (cola derecha)
x_critical_plot_llenado = np.linspace(chi2_critical_llenado, x_max_plot_llenado, 1000)
plt.fill_between(x_critical_plot_llenado, 0, scipy.stats.chi2.pdf(x_critical_plot_llenado, grados_libertad_llenado), color='red', alpha=0.5, label=f'Región Crítica (alpha = {nivel_significancia_llenado})')


# Marcar el valor crítico Chi-Cuadrado
plt.axvline(chi2_critical_llenado, color='red', linestyle='--', label=f'Valor Crítico χ^2 = {chi2_critical_llenado:.4f}')


# Marcar el estadístico de prueba Chi-Cuadrado
plt.axvline(chi2_estadistico_llenado, color='green', linestyle='-', label=f'Estadístico χ^2 = {chi2_estadistico_llenado:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para la Varianza del Volumen de Llenado (Prueba de Cola Derecha)')
plt.xlabel('Valor χ^2')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparar el estadístico de prueba Chi-Cuadrado con el valor crítico
# Si chi2_estadistico > chi2_critico, rechazamos la hipótesis nula.
# Si chi2_estadistico <= chi2_critico, no rechazamos la hipótesis nula.

print("\nDecisión y Conclusión:")
if chi2_estadistico_llenado > chi2_critical_llenado:
    print(f"El estadístico de prueba χ^2 ({chi2_estadistico_llenado:.4f}) cae en la región crítica (es mayor que el valor crítico χ^2 de {chi2_critical_llenado:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_llenado}, hay suficiente evidencia estadística para concluir que la varianza poblacional del volumen de llenado es significativamente mayor que {varianza_poblacional_h0_llenado} ml^2.")
else:
    print(f"El estadístico de prueba χ^2 ({chi2_estadistico_llenado:.4f}) no cae en la región crítica (es menor o igual que el valor crítico χ^2 de {chi2_critical_llenado:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_llenado}, para concluir que la varianza poblacional del volumen de llenado es significativamente mayor que {varianza_poblacional_h0_llenado} ml^2.")
# Out:
# Decisión y Conclusión:
# El estadístico de prueba χ^2 (31.6667) no cae en la región crítica (es menor o igual que el valor crítico χ^2 de 36.1909).
# Por lo tanto, no rechazamos la hipótesis nula (H0).
# Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de 0.01, para concluir que la varianza poblacional del volumen de llenado es significativamente mayor que 1.2 ml^2.

# %% [markdown]
# ## Resultados de la Prueba de Hipótesis de Chi-Cuadrado ($\chi^2$) para la Varianza
#
# ### Resumen del Problema
# Se realizó una prueba de hipótesis para determinar si la varianza poblacional del volumen de llenado de botellas es significativamente mayor que 1.2 ml$^2$, basándose en una muestra de 20 botellas.
#
# ### Planteamiento de Hipótesis
# - Hipótesis Nula (H0): La varianza poblacional del volumen de llenado es igual o menor a 1.2 ml$^2$ ($\sigma^2 \le 1.2$).
# - Hipótesis Alternativa (H1): La varianza poblacional del volumen de llenado es mayor a 1.2 ml$^2$ ($\sigma^2 > 1.2$).
#
# ### Parámetros Utilizados
# - Varianza poblacional hipotetizada (H0): {varianza_poblacional_h0_llenado} ml$^2$
# - Varianza muestral: {varianza_muestral_llenado} ml$^2$
# - Tamaño de la muestra: {tamano_muestra_llenado} botellas
# - Nivel de significancia ($\alpha$): {nivel_significancia_llenado}
# - Grados de libertad (df): {grados_libertad_llenado}
#
# ### Cálculos Clave
# - Estadístico de prueba Chi-Cuadrado ($\chi^2$): {chi2_estadistico_llenado:.4f}
# - Valor crítico Chi-Cuadrado (para $\alpha$={nivel_significancia_llenado} y df={grados_libertad_llenado}): {chi2_critical_llenado:.4f}
# - Región Crítica (Región de Rechazo de H0): $\chi^2$ > {chi2_critical_llenado:.4f}
# - Región de No Rechazo de H0: $\chi^2$ $\le$ {chi2_critical_llenado:.4f}
#
# ### Decisión y Conclusión
# El estadístico de prueba $\chi^2$ calculado ({chi2_estadistico_llenado:.4f}) se compara con el valor crítico $\chi^2$ ({chi2_critical_llenado:.4f}).
# Dado que el estadístico de prueba $\chi^2$ ({chi2_estadistico_llenado:.4f}) ${"es mayor que el valor crítico" if chi2_estadistico_llenado > chi2_critical_llenado else "es menor o igual que el valor crítico"}$ ({chi2_critical_llenado:.4f}), ${"cae" if chi2_estadistico_llenado > chi2_critical_llenado else "no cae"}$ dentro de la región crítica.
# Por lo tanto, ${"**rechazamos la hipótesis nula (H0)**" if chi2_estadistico_llenado > chi2_critical_llenado else "**no rechazamos la hipótesis nula (H0)**"}$.
#
# Conclusión: Con un nivel de significancia de {nivel_significancia_llenado}, ${"hay suficiente evidencia estadística para concluir que la varianza poblacional del volumen de llenado es significativamente mayor que" if chi2_estadistico_llenado > chi2_critical_llenado else "no hay suficiente evidencia estadística para concluir que la varianza poblacional del volumen de llenado es significativamente mayor que"}$ {varianza_poblacional_h0_llenado} ml$^2$.
#
# ### Visualización
# El gráfico anterior ilustra la distribución $\chi^2$ con {grados_libertad_llenado} grados de libertad, la región crítica en la cola derecha y la posición del estadístico de prueba $\chi^2$ en relación con el valor crítico.

# %% [markdown]
# ## Prueba de Hipótesis de Chi-Cuadrado ($\chi^2$) para la Varianza: Grosor de Piezas Metálicas
#
# **Problema:** El control de calidad de una fábrica sostiene que la varianza en el grosor de piezas metálicas es de al menos $\sigma^2 = 0,5$ mm$^2$. Una muestra de $n = 12$ piezas dio una varianza $s^2 = 0,3$. ¿Se puede concluir al 5 % de significancia de que la varianza poblacional es menor que la garantizada?
#
# **Instrucciones:**
# 1. Plantear las hipótesis nula y alternativa.
# 2. Calcule el estadístico $\chi^2$.
# 3. Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# 4. Concluya si se rechaza H0.
# 5. Utilizar fórmulas estándar con explicaciones claras.
# 6. Usar `scipy.stats` para cálculos estadísticos.
# 7. Comentar todo el código indicando pasos y fórmulas.
# 8. Organizar y documentar todas las respuestas con claridad y texto interpretativo.
# 9. Todo el resultado debe estar en español.
# 10. Graficar la distribución $\chi^2$, la región crítica y el estadístico de prueba.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * La hipótesis nula (H0) plantea que la varianza en el grosor de las piezas metálicas es igual o mayor a 0.5 mm$^2$ ($\sigma^2 \ge 0.5$). La hipótesis alternativa (H1) plantea que la varianza poblacional es menor a 0.5 mm$^2$ ($\sigma^2 < 0.5$).
# * El tamaño de la muestra fue de 12 piezas, con una varianza muestral de 0.3 mm$^2$.
# * El nivel de significancia ($\alpha$) utilizado fue de 0.05.
# * Los grados de libertad (df) son 11.
# * El estadístico de prueba Chi-Cuadrado ($\chi^2$) calculado fue de {chi2_estadistico_metal:.4f}.
# * Para un nivel de significancia de 0.05 en una prueba de cola izquierda con 11 grados de libertad, el valor crítico de $\chi^2$ es {chi2_critical_metal:.4f}.
# * La región crítica para rechazar la hipótesis nula es cuando $\chi^2 < {chi2_critical_metal:.4f}$.
# * Dado que el estadístico $\chi^2$ calculado ({chi2_estadistico_metal:.4f}) es mayor que el valor crítico ({chi2_critical_metal:.4f}), no cae en la región crítica.
#
# ### Insights or Next Steps
#
# * Basándonos en la muestra y un nivel de significancia de 0.05, no hay suficiente evidencia estadística para concluir que la varianza poblacional en el grosor de las piezas metálicas es significativamente menor que 0.5 mm$^2$.
# * Esto sugiere que, según esta prueba, la afirmación del control de calidad de que la varianza es de al menos 0.5 mm$^2$ no puede ser refutada con la evidencia de la muestra.
# * Para aumentar la potencia de la prueba y tener una mayor capacidad para detectar una diferencia si realmente existe, se podría considerar aumentar el tamaño de la muestra en futuras inspecciones.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * La hipótesis nula (H0) plantea que la varianza en el grosor de las piezas metálicas es igual o mayor a 0.5 mm$^2$ ($\sigma^2 \ge 0.5$). La hipótesis alternativa (H1) plantea que la varianza poblacional es menor a 0.5 mm$^2$ ($\sigma^2 < 0.5$).
# * El tamaño de la muestra fue de 12 piezas, con una varianza muestral de 0.3 mm$^2$.
# * El nivel de significancia ($\alpha$) utilizado fue de 0.05.
# * Los grados de libertad (df) son 11.
# * El estadístico de prueba Chi-Cuadrado ($\chi^2$) calculado fue de {chi2_estadistico_metal:.4f}.
# * Para un nivel de significancia de 0.05 en una prueba de cola izquierda con 11 grados de libertad, el valor crítico de $\chi^2$ es {chi2_critical_metal:.4f}.
# * La región crítica para rechazar la hipótesis nula es cuando $\chi^2 < {chi2_critical_metal:.4f}$.
# * Dado que el estadístico $\chi^2$ calculado ({chi2_estadistico_metal:.4f}) es mayor que el valor crítico ({chi2_critical_metal:.4f}), no cae en la región crítica.
#
# ### Insights or Next Steps
#
# * Basándonos en la muestra y un nivel de significancia de 0.05, no hay suficiente evidencia estadística para concluir que la varianza poblacional en el grosor de las piezas metálicas es significativamente menor que 0.5 mm$^2$.
# * Esto sugiere que, según esta prueba, la afirmación del control de calidad de que la varianza es de al menos 0.5 mm$^2$ no puede ser refutada con la evidencia de la muestra.
# * Para aumentar la potencia de la prueba y tener una mayor capacidad para detectar una diferencia si realmente existe, se podría considerar aumentar el tamaño de la muestra en futuras inspecciones.

# %%
# Graficar la distribución Chi-Cuadrado
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
# Definir un rango de x que cubra la distribución Chi-Cuadrado para los grados de libertad dados
# Usar un rango desde 0 hasta un valor que cubra bien la cola derecha (por ejemplo, hasta el percentil 99.9)
x_max_plot_metal = scipy.stats.chi2.ppf(0.999, grados_libertad_metal)
x_metal = np.linspace(0, x_max_plot_metal, 1000)

plt.plot(x_metal, scipy.stats.chi2.pdf(x_metal, grados_libertad_metal), label=f'Distribución χ^2 (df={grados_libertad_metal})')

# Rellenar la región crítica (cola izquierda)
x_critical_plot_metal = np.linspace(0, chi2_critical_metal, 1000)
plt.fill_between(x_critical_plot_metal, 0, scipy.stats.chi2.pdf(x_critical_plot_metal, grados_libertad_metal), color='red', alpha=0.5, label=f'Región Crítica (alpha = {nivel_significancia_metal})')


# Marcar el valor crítico Chi-Cuadrado
plt.axvline(chi2_critical_metal, color='red', linestyle='--', label=f'Valor Crítico χ^2 = {chi2_critical_metal:.4f}')


# Marcar el estadístico de prueba Chi-Cuadrado
plt.axvline(chi2_estadistico_metal, color='green', linestyle='-', label=f'Estadístico χ^2 = {chi2_estadistico_metal:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para la Varianza del Grosor de Piezas Metálicas (Prueba de Cola Izquierda)')
plt.xlabel('Valor χ^2')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * La hipótesis nula (H0) plantea que la varianza en el grosor de las piezas metálicas es igual o mayor a 0.5 mm$^2$ ($\sigma^2 \ge 0.5$). La hipótesis alternativa (H1) plantea que la varianza poblacional es menor a 0.5 mm$^2$ ($\sigma^2 < 0.5$).
# * El tamaño de la muestra fue de 12 piezas, con una varianza muestral de 0.3 mm$^2$.
# * El nivel de significancia ($\alpha$) utilizado fue de 0.05.
# * Los grados de libertad (df) son 11.
# * El estadístico de prueba Chi-Cuadrado ($\chi^2$) calculado fue de {chi2_estadistico_metal:.4f}.
# * Para un nivel de significancia de 0.05 en una prueba de cola izquierda con 11 grados de libertad, el valor crítico de $\chi^2$ es {chi2_critical_metal:.4f}.
# * La región crítica para rechazar la hipótesis nula es cuando $\chi^2 < {chi2_critical_metal:.4f}$.
# * Dado que el estadístico $\chi^2$ calculado ({chi2_estadistico_metal:.4f}) es mayor que el valor crítico ({chi2_critical_metal:.4f}), no cae en la región crítica.
#
# ### Insights or Next Steps
#
# * Basándonos en la muestra y un nivel de significancia de 0.05, no hay suficiente evidencia estadística para concluir que la varianza poblacional en el grosor de las piezas metálicas es significativamente menor que 0.5 mm$^2$.
# * Esto sugiere que, según esta prueba, la afirmación del control de calidad de que la varianza es de al menos 0.5 mm$^2$ no puede ser refutada con la evidencia de la muestra.
# * Para aumentar la potencia de la prueba y tener una mayor capacidad para detectar una diferencia si realmente existe, se podría considerar aumentar el tamaño de la muestra en futuras inspecciones.

# %%
# Importar las librerías necesarias
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

# Asignar los parámetros dados
varianza_poblacional_h0_metal = 0.5  # Varianza poblacional hipotetizada (mm^2)
varianza_muestral_metal = 0.3  # Varianza muestral observada (mm^2)
tamano_muestra_metal = 12  # Tamaño de la muestra (piezas)
nivel_significancia_metal = 0.05  # Nivel de significancia (alpha)

# Calcular los grados de libertad
# Fórmula: df = n - 1
grados_libertad_metal = tamano_muestra_metal - 1

# Calcular el estadístico de prueba Chi-Cuadrado
# Fórmula: χ^2 = ((n - 1) * s^2) / σ^2
# Donde n es el tamaño de la muestra, s^2 es la varianza muestral y σ^2 es la varianza poblacional hipotetizada.
chi2_estadistico_metal = ((tamano_muestra_metal - 1) * varianza_muestral_metal) / varianza_poblacional_h0_metal

# Determinar el valor crítico Chi-Cuadrado para una prueba de cola izquierda
# Para un nivel de significancia alpha y df grados de libertad, necesitamos el valor χ^2 que deja alpha en la cola izquierda.
# Usamos scipy.stats.chi2.ppf para encontrar este valor (alpha).
# Fórmula: χ^2_critico_izquierda = scipy.stats.chi2.ppf(alpha, df)
chi2_critical_metal = scipy.stats.chi2.ppf(nivel_significancia_metal, grados_libertad_metal)


# Graficar la distribución Chi-Cuadrado
plt.figure(figsize=(10, 6))
# Definir un rango de x que cubra la distribución Chi-Cuadrado para los grados de libertad dados
# Usar un rango desde 0 hasta un valor que cubra bien la cola derecha (por ejemplo, hasta el percentil 99.9)
x_max_plot_metal = scipy.stats.chi2.ppf(0.999, grados_libertad_metal)
x_metal = np.linspace(0, x_max_plot_metal, 1000)

plt.plot(x_metal, scipy.stats.chi2.pdf(x_metal, grados_libertad_metal), label=f'Distribución χ^2 (df={grados_libertad_metal})')

# Rellenar la región crítica (cola izquierda)
x_critical_plot_metal = np.linspace(0, chi2_critical_metal, 1000)
plt.fill_between(x_critical_plot_metal, 0, scipy.stats.chi2.pdf(x_critical_plot_metal, grados_libertad_metal), color='red', alpha=0.5, label=f'Región Crítica (alpha = {nivel_significancia_metal})')


# Marcar el valor crítico Chi-Cuadrado
plt.axvline(chi2_critical_metal, color='red', linestyle='--', label=f'Valor Crítico χ^2 = {chi2_critical_metal:.4f}')


# Marcar el estadístico de prueba Chi-Cuadrado
plt.axvline(chi2_estadistico_metal, color='green', linestyle='-', label=f'Estadístico χ^2 = {chi2_estadistico_metal:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para la Varianza del Grosor de Piezas Metálicas (Prueba de Cola Izquierda)')
plt.xlabel('Valor χ^2')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 1. Plantear las hipótesis nula y alternativa
# La hipótesis nula (H0) es que la varianza poblacional es igual o mayor a 0.5 mm^2 (lo que garantiza la fábrica).
# H0: σ^2 >= 0.5
# La hipótesis alternativa (H1) es que la varianza poblacional es menor a 0.5 mm^2 (lo que se quiere probar).
# H1: σ^2 < 0.5

print("1. Planteamiento de Hipótesis:")
print("Hipótesis Nula (H0): La varianza en el grosor de las piezas metálicas es igual o mayor a 0.5 mm^2 (σ^2 >= 0.5)")
print("Hipótesis Alternativa (H1): La varianza en el grosor de las piezas metálicas es menor a 0.5 mm^2 (σ^2 < 0.5)")

# %%
# Asignar los parámetros dados
varianza_poblacional_h0_metal = 0.5  # Varianza poblacional hipotetizada (mm^2)
varianza_muestral_metal = 0.3  # Varianza muestral observada (mm^2)
tamano_muestra_metal = 12  # Tamaño de la muestra (piezas)
nivel_significancia_metal = 0.05  # Nivel de significancia (alpha)

print(f"\nParámetros Utilizados:")
print(f"- Varianza poblacional hipotetizada (H0): {varianza_poblacional_h0_metal} mm^2")
print(f"- Varianza muestral: {varianza_muestral_metal} mm^2")
print(f"- Tamaño de la muestra: {tamano_muestra_metal} piezas")
print(f"- Nivel de significancia (alpha): {nivel_significancia_metal}")

# %%
# 2. Calcule el estadístico Chi-Cuadrado
# Fórmula: χ^2 = ((n - 1) * s^2) / σ^2
# Donde n es el tamaño de la muestra, s^2 es la varianza muestral y σ^2 es la varianza poblacional hipotetizada.
chi2_estadistico_metal = ((tamano_muestra_metal - 1) * varianza_muestral_metal) / varianza_poblacional_h0_metal

print(f"\n2. Cálculo del Estadístico Chi-Cuadrado:")
print(f"- Estadístico de prueba Chi-Cuadrado (χ^2): {chi2_estadistico_metal:.4f}")

# %%
# 3. Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# Calcular los grados de libertad
# Fórmula: df = n - 1
grados_libertad_metal = tamano_muestra_metal - 1

# Determinar el valor crítico Chi-Cuadrado para una prueba de cola izquierda
# Para un nivel de significancia alpha y df grados de libertad, necesitamos el valor χ^2 que deja alpha en la cola izquierda.
# Usamos scipy.stats.chi2.ppf para encontrar este valor (alpha).
# Fórmula: χ^2_critico_izquierda = scipy.stats.chi2.ppf(alpha, df)
chi2_critical_metal = scipy.stats.chi2.ppf(nivel_significancia_metal, grados_libertad_metal)

# Definir la región crítica y la región de no rechazo
# Para una prueba de cola izquierda, la región crítica son todos los valores de χ^2 menores que el valor crítico χ^2.
# Región Crítica: χ^2 < χ^2_critico
# Región de No Rechazo: χ^2 >= χ^2_critico

print(f"\n3. Determinación de la Región Crítica y de No Rechazo:")
print(f"- Grados de libertad: {grados_libertad_metal}")
print(f"- Valor crítico Chi-Cuadrado (para alpha={nivel_significancia_metal} y df={grados_libertad_metal}): {chi2_critical_metal:.4f}")
print(f"- Región Crítica: χ^2 < {chi2_critical_metal:.4f}")
print(f"- Región de No Rechazo: χ^2 >= {chi2_critical_metal:.4f}")

# %%
# 4. Concluya si se rechaza H0.
# Comparar el estadístico de prueba Chi-Cuadrado con el valor crítico
# Si chi2_estadistico < chi2_critico, rechazamos la hipótesis nula.
# Si chi2_estadistico >= chi2_critico, no rechazamos la hipótesis nula.

print("\n4. Decisión y Conclusión:")
if chi2_estadistico_metal < chi2_critical_metal:
    print(f"El estadístico de prueba χ^2 ({chi2_estadistico_metal:.4f}) cae en la región crítica (es menor que el valor crítico χ^2 de {chi2_critical_metal:.4f}).")
    print("Por lo tanto, rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: Con un nivel de significancia de {nivel_significancia_metal}, hay suficiente evidencia estadística para concluir que la varianza poblacional en el grosor de las piezas metálicas es significativamente menor que {varianza_poblacional_h0_metal} mm^2.")
else:
    print(f"El estadístico de prueba χ^2 ({chi2_estadistico_metal:.4f}) no cae en la región crítica (es mayor o igual que el valor crítico χ^2 de {chi2_critical_metal:.4f}).")
    print("Por lo tanto, no rechazamos la hipótesis nula (H0).")
    print(f"Conclusión: No hay suficiente evidencia estadística, con un nivel de significancia de {nivel_significancia_metal}, para concluir que la varianza poblacional en el grosor de las piezas metálicas es significativamente menor que {varianza_poblacional_h0_metal} mm^2.")

# %%
# 10. Graficar la distribución Chi-Cuadrado, la región crítica y el estadístico de prueba.
plt.figure(figsize=(10, 6))
# Definir un rango de x que cubra la distribución Chi-Cuadrado para los grados de libertad dados
# Usar un rango desde 0 hasta un valor que cubra bien la cola derecha (por ejemplo, hasta el percentil 99.9)
x_max_plot_metal = scipy.stats.chi2.ppf(0.999, grados_libertad_metal)
x_metal = np.linspace(0, x_max_plot_metal, 1000)

plt.plot(x_metal, scipy.stats.chi2.pdf(x_metal, grados_libertad_metal), label=f'Distribución χ^2 (df={grados_libertad_metal})')

# Rellenar la región crítica (cola izquierda)
x_critical_plot_metal = np.linspace(0, chi2_critical_metal, 1000)
plt.fill_between(x_critical_plot_metal, 0, scipy.stats.chi2.pdf(x_critical_plot_metal, grados_libertad_metal), color='red', alpha=0.5, label=f'Región Crítica (alpha = {nivel_significancia_metal})')


# Marcar el valor crítico Chi-Cuadrado
plt.axvline(chi2_critical_metal, color='red', linestyle='--', label=f'Valor Crítico χ^2 = {chi2_critical_metal:.4f}')


# Marcar el estadístico de prueba Chi-Cuadrado
plt.axvline(chi2_estadistico_metal, color='green', linestyle='-', label=f'Estadístico χ^2 = {chi2_estadistico_metal:.4f}')

# Añadir etiquetas y título
plt.title('Prueba de Hipótesis para la Varianza del Grosor de Piezas Metálicas (Prueba de Cola Izquierda)')
plt.xlabel('Valor χ^2')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Resultados de la Prueba de Hipótesis de Chi-Cuadrado ($\chi^2$) para la Varianza
#
# ### Resumen del Problema
# Se realizó una prueba de hipótesis para determinar si la varianza poblacional en el grosor de las piezas metálicas es significativamente menor que 0.5 mm$^2$, basándose en una muestra de 12 piezas.
#
# ### Planteamiento de Hipótesis
# - Hipótesis Nula (H0): La varianza poblacional en el grosor de las piezas metálicas es igual o mayor a 0.5 mm$^2$ ($\sigma^2 \ge 0.5$).
# - Hipótesis Alternativa (H1): La varianza poblacional en el grosor de las piezas metálicas es menor a 0.5 mm$^2$ ($\sigma^2 < 0.5$).
#
# ### Parámetros Utilizados
# - Varianza poblacional hipotetizada (H0): {varianza_poblacional_h0_metal} mm$^2$
# - Varianza muestral: {varianza_muestral_metal} mm$^2$
# - Tamaño de la muestra: {tamano_muestra_metal} piezas
# - Nivel de significancia ($\alpha$): {nivel_significancia_metal}
# - Grados de libertad (df): {grados_libertad_metal}
#
# ### Cálculos Clave
# - Estadístico de prueba Chi-Cuadrado ($\chi^2$): {chi2_estadistico_metal:.4f}
# - Valor crítico Chi-Cuadrado (para $\alpha$={nivel_significancia_metal} y df={grados_libertad_metal}): {chi2_critical_metal:.4f}
# - Región Crítica (Región de Rechazo de H0): $\chi^2$ < {chi2_critical_metal:.4f}
# - Región de No Rechazo de H0: $\chi^2$ $\ge$ {chi2_critical_metal:.4f}
#
# ### Decisión y Conclusión
# El estadístico de prueba $\chi^2$ calculado ({chi2_estadistico_metal:.4f}) se compara con el valor crítico $\chi^2$ ({chi2_critical_metal:.4f}).
# Dado que el estadístico de prueba $\chi^2$ ({chi2_estadistico_metal:.4f}) ${"es menor que el valor crítico" if chi2_estadistico_metal < chi2_critical_metal else "es mayor o igual que el valor crítico"}$ ({chi2_critical_metal:.4f}), ${"cae" if chi2_estadistico_metal < chi2_critical_metal else "no cae"}$ dentro de la región crítica.
# Por lo tanto, ${"**rechazamos la hipótesis nula (H0)**" if chi2_estadistico_metal < chi2_critical_metal else "**no rechazamos la hipótesis nula (H0)**"}$.
#
# Conclusión: Con un nivel de significancia de {nivel_significancia_metal}, ${"hay suficiente evidencia estadística para concluir que la varianza poblacional en el grosor de las piezas metálicas es significativamente menor que" if chi2_estadistico_metal < chi2_critical_metal else "no hay suficiente evidencia estadística para concluir que la varianza poblacional en el grosor de las piezas metálicas es significativamente menor que"}$ {varianza_poblacional_h0_metal} mm$^2$.
#
# ### Visualización
# El gráfico anterior ilustra la distribución $\chi^2$ con {grados_libertad_metal} grados de libertad, la región crítica en la cola izquierda y la posición del estadístico de prueba $\chi^2$ en relación con el valor crítico.
